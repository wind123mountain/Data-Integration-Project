# %%
import pandas as pd
import numpy as np

# %%
phone_df = pd.read_csv("Data\Cellphones\Cellphones_data.csv")
phone_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   type_id                 274 non-null    object
#  1   entity_id               274 non-null    int64
#  2   name                    274 non-null    object
#  3   url                     274 non-null    object
#  4   price                   274 non-null    int64
#  5   final_price             274 non-null    int64
#  6   small_image             274 non-null    object
#  7   promotion_information   132 non-null    object
#  8   count_all_reviews       274 non-null    float64
#  9   average_ratings         274 non-null    float64
#  10  attribute_black_friday  274 non-null    bool
#  11  attribute_uu_dai_tet    274 non-null    object
#  12  attribute_doc_quyen     274 non-null    object
#  13  stock_available         274 non-null    int64
# ...

# %%
config_df = pd.read_csv("Data\Cellphones\Cellphones_specification_data.csv")
config_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         274 non-null    object
#  1   Kích thước màn hình         271 non-null    object
#  2   Công nghệ màn hình          211 non-null    object
#  3   Độ phân giải màn hình       256 non-null    object
#  4   Tính năng màn hình          183 non-null    object
#  5   Camera sau                  266 non-null    object
#  6   Quay video                  249 non-null    object
#  7   Tính năng camera            93 non-null     object
#  8   Camera trước                263 non-null    object
#  9   Chipset                     265 non-null    object
#  10  Loại CPU                    225 non-null    object
#  11  GPU                         244 non-null    object
#  12  Dung lượng RAM              255 non-null    object
# ...

# %%
config_df.isnull().sum().sort_values()
# Out:
# url                             0
# Pin                             2
# Kích thước màn hình             3
# Bộ nhớ trong                    5
# Camera sau                      8
# Chipset                         9
# Thẻ SIM                        10
# Kích thước                     11
# Bluetooth                      11
# Camera trước                   11
# Wi-Fi                          12
# Hệ điều hành                   14
# Độ phân giải màn hình          18
# Trọng lượng                    18
# Dung lượng RAM                 19
# GPS                            20
# Quay video                     25
# GPU                            30
# Loại CPU                       49
# Hỗ trợ mạng                    58
# Cổng sạc                       62
# Công nghệ màn hình             63
# Công nghệ sạc                  76
# Cảm biến vân tay               81
# Các loại cảm biến              89
# Tính năng màn hình             91
# Jack tai nghe 3.5              93
# ...

# %%
intergration_df = pd.DataFrame()

# %%
intergration_df['Tên sản phẩm'] = phone_df['name']

# %%
import re

for i in list(intergration_df.index):
    intergration_df.loc[i, ['Tên sản phẩm']] = re.split('[|I]',str(intergration_df['Tên sản phẩm'].iloc[i]))[0].split("Chính hãng")[0].strip()

# %%
intergration_df['Giá gốc'] = phone_df['price']
intergration_df['Giá bán'] = phone_df['final_price']
intergration_df['Kích thước màn hình'] = config_df['Kích thước màn hình']
intergration_df['RAM'] = config_df['Dung lượng RAM']
intergration_df['Bộ nhớ'] = config_df['Bộ nhớ trong']
intergration_df['Chipset'] = config_df['Chipset']
intergration_df['Pin'] = config_df['Pin']
intergration_df['Kích thước'] = config_df['Kích thước']
intergration_df['Bluetooth'] = config_df['Bluetooth']
intergration_df['Camera trước'] = config_df['Camera trước']
intergration_df['Wi-Fi'] = config_df['Wi-Fi']
intergration_df['Hệ điều hành'] = config_df['Hệ điều hành']
intergration_df['Độ phân giải màn hình'] = config_df['Độ phân giải màn hình']
intergration_df['Tần số quét'] = config_df['Tần số quét']
intergration_df['Trọng lượng'] = config_df['Trọng lượng']
intergration_df['Quay video'] = config_df['Quay video']
intergration_df['GPU'] = config_df['GPU']
intergration_df['Cổng sạc'] = config_df['Cổng sạc']
intergration_df['url'] = phone_df['url']
intergration_df['image_url'] = phone_df['small_image']

# %%
id_list = (intergration_df.query("`Giá bán` == 0").index)

intergration_df['Giá bán'].iloc[id_list] = intergration_df['Giá gốc'].iloc[id_list]

intergration_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Tên sản phẩm           274 non-null    object
#  1   Giá gốc                274 non-null    int64
#  2   Giá bán                274 non-null    int64
#  3   Kích thước màn hình    271 non-null    object
#  4   RAM                    255 non-null    object
#  5   Bộ nhớ                 269 non-null    object
#  6   Chipset                265 non-null    object
#  7   Pin                    272 non-null    object
#  8   Kích thước             263 non-null    object
#  9   Bluetooth              263 non-null    object
#  10  Camera trước           263 non-null    object
#  11  Wi-Fi                  262 non-null    object
#  12  Hệ điều hành           260 non-null    object
#  13  Độ phân giải màn hình  256 non-null    object
# ...

# %%
intergration_df.to_csv (r'Data\Cellphones\Cellphones_processed_data.csv', index=False, header=True)

# %%
df = pd.read_csv("Data\Cellphones\Cellphones_processed_data.csv")

# %%
with pd.option_context('display.max_colwidth', None, 'display.max_columns', None):
  display(df.head(10))
# Out:
#                              Tên sản phẩm   Giá gốc   Giá bán  \
# 0                 Samsung Galaxy A73 (5G)  12990000  10190000
# 1                          iPhone 11 64GB  18000000  11490000
# 2                 iPhone 13 Pro Max 128GB  34990000  34990000
# 3                    Xiaomi Redmi Note 11   4690000   4490000
# 4                 iPhone 12 Pro Max 128GB  32990000  27000000
# 5  Samsung Galaxy S22 Ultra (8GB - 128GB)  30990000  29190000
# 6   Nubia Red Magic 7 Obsidian 12GB 128GB  18990000  18990000
# 7        Xiaomi Redmi Note 11 Pro Plus 5G   9990000   9200000
# 8   Samsung Galaxy S22 Plus (8GB + 128GB)  25990000  24490000
# 9                              Xiaomi 11T  10990000   9900000
#
#   Kích thước màn hình    RAM  Bộ nhớ                             Chipset  \
# 0          6.7 inches   8 GB  256 GB           Snapdragon 778G 5G 8 nhân
# 1          6.1 inches   4 GB   64 GB                          A13 Bionic
# ...

# %%
for i in list(df.index):
    if len(str(df['Kích thước màn hình'].iloc[i]).split()) < 3:
        df.loc[i, ['Kích thước màn hình']] = str(df['Kích thước màn hình'].iloc[i]).split("inches")[0].strip()
    else:
        df.loc[i, ['Kích thước màn hình']] = ''.join(df['Kích thước màn hình'].iloc[i].split("inches"))

# %%
df['RAM'].unique()
# Out:
# array(['8 GB', '4 GB', '6 GB', '12 GB', '4GB + Mở rộng 3GB',
#        '4GB + Mở rộng 1GB', '16 GB', '2 GB', '3 GB', '6GB + Mở rộng 5GB',
#        nan, '18 GB', '12 GB + 3 GB (RAM bổ sung)', '1 GB'], dtype=object)

# %%
for i in list(df.index):
    if len(str(df['RAM'].iloc[i]).split()) < 3:
        df.loc[i, ['RAM']] = ''.join(str(df['RAM'].iloc[i]).split())

# %%
df['RAM'].unique()
# Out:
# array(['8GB', '4GB', '6GB', '12GB', '4GB + Mở rộng 3GB',
#        '4GB + Mở rộng 1GB', '16GB', '2GB', '3GB', '6GB + Mở rộng 5GB',
#        'nan', '18GB', '12 GB + 3 GB (RAM bổ sung)', '1GB'], dtype=object)

# %%
df['Bộ nhớ'].unique()
# Out:
# array(['256 GB', '64 GB', '128 GB', '512 GB', '32 GB', nan, '128 MB',
#        '16 GB', '1 TB', '4 GB'], dtype=object)

# %%
for i in list(df.index):
    if len(str(df['Bộ nhớ'].iloc[i]).split()) < 3:
        df.loc[i, ['Bộ nhớ']] = ''.join(str(df['Bộ nhớ'].iloc[i]).split())

# %%
# for i in list(df.index):
#     # df.loc[i, ['Kích thước màn hình']] = str(df['Kích thước màn hình'].iloc[i]).split()[0].strip()
#     # if len(str(df['Pin'].iloc[i]).split()) < 3:
#         # print(''.join(re.split('[,.]',str(df['Pin'].iloc[i]).split('mAh')[0].strip())))
#         print(str(df['Pin'].iloc[i]).split('mAh'))
#     # else:
#     #     print(df['Bộ nhớ'].iloc[i])
# Out:
# ['5000 ', '']
# ['3110 ', '']
# ['4,325', '']
# ['Li-Po 5000 ', '']
# ['Li-Ion, sạc nhanh 20W, sạc không dây 15W, USB Power Delivery 2.0']
# ['Li-Ion 5000 ', '']
# ['Li-Po 4500 ', '']
# ['Li-Po 4500 ', '']
# ['4500 ', '']
# ['5000 ', '']
# ['Non-removable Li-Ion 4500 ', ' battery Fast charging 25W USB Power Delivery 3.0 Fast Qi/PMA wireless charging Reverse wireless charging 9W']
# ['Khoảng 3.200', '']
# ['Li-Ion, sạc nhanh 20W, sạc không dây 15W, USB Power Delivery 2.0']
# ['4,500 ', '']
# ['6000 ', '']
# ['3110 ', '']
# ['Li-Po 4250 ', '']
# ['5000 ', '']
# ['5000', ' (typ)']
# ['4310', ' (Typ)']
# ['1.820', '']
# ['4,000', ', sạc nhanh Quick Charge 3.0 18W']
# ['Li-Po 7000 ', '']
# ['Li-Po 5000 ', '']
# ['3,095', '']
# ['Li-Po 4500 ', '']
# ['6000 ', '']
# ['4500', '']
# ['6000 ', '']
# ['Li-Po 5000 ', '']
# ['5000', '']
# ['6000 ', '']
# ['Li-Po 5000 ', '']
# ['Li-Ion, sạc nhanh 20W, sạc không dây 15W, USB Power Delivery 2.0']
# ['Li-Ion 5000 ', '']
# ['4,325', '']
# ...

# %%
df.to_csv (r'Data/Cellphones.csv', index=False, header=True)

# %%
df.Bluetooth.unique()
# Out:
# array(['v5.0', '5.0', '5.0, A2DP, LE', '5.2, A2DP, LE', '5.2', 'A2DP, LE',
#        'Bluetooth 5.2', '5.0, A2DP, LE, aptX', ' v5.1', ' 5.0', 'v5.2',
#        '5.1, A2DP, LE, aptX HD', '5.1, A2DP, LE',
#        '5.2, A2DP, LE, aptX HD', '5.2, A2DP, LE, aptX HD, aptX Adaptive',
#        ' 5.2', 'Có', '5.1', 'v 5.1', '5.2, A2DP, aptX, LE', 'v5.1',
#        'Bluetooth v5.0', nan, 'v 5.0', '5.1, A2DP, LE5.2, A2DP, LE',
#        'v5.0, A2DP, LE', 'v5.1，BLE',
#        '5.1, A2DP, LE, aptX HD, aptX Adaptive', '5.1, A2DP, aptX, LE',
#        'v4.2, A2DP, LE', 'v 5.2', 'LE, A2DP, v5.0', 'LE v5.1 A2DP',
#        ' v5.0', '4.2, A2DP', 'LE, A2DP, apt-X, v5.0',
#        '5.0, A2DP, LE, aptX HD', 'Wi-Fi 802.11 b/g/n, hotspot',
#        ' A2DP,  LE,  v5.2', 'v5.0, apt-X, A2DP, LE, EDR',
#        'Bluetooth v5.1', 'Bluetooth 5.0', 'LE, A2DP, v4.2',
#        'Bluetooth® 5.0', '4.1, A2DP, LE', '4.0, A2DP',
#        '4.2, A2DP, aptX Adaptive',
# ...
