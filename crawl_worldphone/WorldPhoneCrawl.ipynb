# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
r = requests.get('https://worldphone.vn/htc-u12-plus-moi')
soup = bs(r.content)
contents = soup.prettify()

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="vi">
# <head>
# <!-- Global site tag (gtag.js) - Google Ads: 956216482 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-956216482"></script>
# <script>
# 			window.dataLayer = window.dataLayer || [];
# 			function gtag(){dataLayer.push(arguments);}
# 			gtag('js', new Date());
#
# 			gtag('config', 'AW-956216482');
# 		</script>
# <script>
# 			gtag('event', 'page_view', {
# 				'send_to': 'AW-956216482',
# 				'value': 'replace with value',
# 				'items': [{
# 					'id': 'replace with value',
# 					'google_business_vertical': 'retail'
# 				}]
# 			});
# 		</script>
# <!-- End Google Tag Manager -->
# <!-- Global site tag (gtag.js) - Google Ads: 956216482 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-956216482"></script>
# <script>
# 			window.dataLayer = window.dataLayer || [];
# 			function gtag(){dataLayer.push(arguments);}
# 			gtag('js', new Date());
#
# 			gtag('config', 'AW-956216482');
# 		</script>
# <meta charset="utf-8"/>
# <meta content="v6iOO873edjgJvSwIcqWGo3YYU0kS58QWxIf85Asg1w" name="google-site-verification"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <title>HOT: HTC U12 Plus [U12+] Mới Xách Tay Chính Hãng Giá Rẻ Uy Tín | WORLDPHONE.VN</title>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/defer_plus.js?1654105636388" type="text/javascript"></script>
# <script>deferscript('//bizweb.dktcdn.net/100/168/366/themes/713148/assets/polyfill.js?1654105636388', 'polyfill-js', 1)</script>
# <meta content="Worldphone - Mua bán điện thoại HTC U12 Plus (U12+)mới xách tay chính hãng giá rẻ uy tín nhất Hà Nội, TPHCM, Đà Nẵng. Ưu đãi cực lớn-Mua ngay!" name="description"/>
# <meta content="HTC U12 Plus (Brandnew - Seabox), ĐIỆN THOẠI TRÊN 6 TRIỆU, ĐIỆN THOẠI TỪ 5 TRIỆU ĐẾN 10 TRIỆU, Tất cả sản phẩm, ĐIỆN THOẠI ANDROID, ĐIỆN THOẠI HTC, htc, htc10, htcm10, WORLDPHONE.VN, worldphone.vn" name="keywords"/>
# <link href="https://worldphone.vn/htc-u12-plus-moi" rel="canonical"/>
# <meta content="1 days" name="revisit-after"/>
# <meta content="noodp,index,follow" name="robots"/>
# <link href="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/favicon.png?1654105636388" rel="icon" type="image/x-icon"/>
# <meta content="product" property="og:type"/><meta content="HTC U12 Plus (Brandnew - Seabox)" property="og:title"/>
# <meta content="https://bizweb.dktcdn.net/thumb/grande/100/168/366/products/sp.jpg?v=1546232067460" property="og:image"/><meta content="https://bizweb.dktcdn.net/thumb/grande/100/168/366/products/sp.jpg?v=1546232067460" property="og:image:secure_url"/>
# <meta content="8.690.000" property="og:price:amount"/><meta content="VND" property="og:price:currency"/>
# <meta content="Worldphone - Mua bán điện thoại HTC U12 Plus (U12+)mới xách tay chính hãng giá rẻ uy tín nhất Hà Nội, TPHCM, Đà Nẵng. Ưu đãi cực lớn-Mua ngay!" property="og:description"/>
# <meta content="https://worldphone.vn/htc-u12-plus-moi" property="og:url"/>
# <meta content="WORLDPHONE.VN" property="og:site_name"/>
# <link href="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/bootstrap.scss.css?1654105636388" rel="stylesheet" type="text/css"/>
# <link href="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/plugin.scss.css?1654105636388" rel="stylesheet" type="text/css"/>
# <link href="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/base.scss.css?1654105636388" rel="stylesheet" type="text/css"/>
# <link href="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/ant-mobile.scss.css?1654105636388" rel="stylesheet" type="text/css"/>
# <script>
# 	var Bizweb = Bizweb || {};
# 	Bizweb.store = 'worldphone.mysapo.net';
# 	Bizweb.id = 168366;
# 	Bizweb.theme = { 'id': 713148, 'name': "Ant Mobile", 'role': 'main' };
# 	Bizweb.template = 'product';
# 	if(!Bizweb.fbEventId)  Bizweb.fbEventId = 'xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx'.replace(/[xy]/g, function (c) {
# 	var r = Math.random() * 16 | 0, v = c == 'x' ? r : (r & 0x3 | 0x8);
# 				return v.toString(16);
# 			});
# </script>
# <script>
# 	(function () {
# 		function asyncLoad() {
# 			var urls = ["//promotionpopup.sapoapps.vn/genscript/script.js?store=worldphone.mysapo.net","//productreviews.sapoapps.vn/assets/js/productreviews.min.js?store=worldphone.mysapo.net","https://availablenotice.sapoapps.vn/scripts/ab_availablenotice_scripttag.min.js?store=worldphone.mysapo.net","https://promotionbar.sapoapps.vn/Scripts/promotionbar.min.js?store=worldphone.mysapo.net","https://bizwebform.sapoapps.vn/genscript/script.js?store=worldphone.mysapo.net","https://productsrecommend.sapoapps.vn/assets/js/script.js?store=worldphone.mysapo.net","https://blogstatistics.sapoapps.vn/scripts/ab_blogstatistics_scripttag.js?store=worldphone.mysapo.net","https://productviewedhistory.sapoapps.vn/ProductViewed/ProductRecentScriptTags?store=worldphone.mysapo.net","//instantsearch.sapoapps.vn/scripts/instantsearch-st.js?store=worldphone.mysapo.net","https://google-shopping.sapoapps.vn/conversion-tracker/global-tag/8246.js?store=worldphone.mysapo.net","https://google-shopping.sapoapps.vn/conversion-tracker/event-tag/8246.js?store=worldphone.mysapo.net","https://google-shopping-v2.sapoapps.vn/api/conversion-tracker/global-tag/259?store=worldphone.mysapo.net","https://google-shopping-v2.sapoapps.vn/api/conversion-tracker/event-tag/259?store=worldphone.mysapo.net","https://google-shopping-v2.sapoapps.vn/api/conversion-tracker/event-tag-conversion/259?store=worldphone.mysapo.net"];
# 			for (var i = 0; i < urls.length; i++) {
# 				var s = document.createElement('script');
# 				s.type = 'text/javascript';
# 				s.async = true;
# 				s.src = urls[i];
# 				var x = document.getElementsByTagName('script')[0];
# 				x.parentNode.insertBefore(s, x);
# 			}
# 		};
# 		window.attachEvent ? window.attachEvent('onload', asyncLoad) : window.addEventListener('load', asyncLoad, false);
# 	})();
# </script>
# <script>
# 	window.BizwebAnalytics = window.BizwebAnalytics || {};
# 	window.BizwebAnalytics.meta = window.BizwebAnalytics.meta || {};
# 	window.BizwebAnalytics.meta.currency = 'VND';
# 	window.BizwebAnalytics.tracking_url = '/s';
#
# 	var meta = {};
#
# 	meta.product = {"id": 12115613, "vendor": "HTC", "name": "HTC U12 Plus (Brandnew - Seabox)",
# 	"type": "Điện Thoại", "price": 8690000.0000 };
#
#
# 	for (var attr in meta) {
# 	window.BizwebAnalytics.meta[attr] = meta[attr];
# 	}
# </script>
# <script src="/dist/js/stats.min.js?v=ed6e8e3"></script>
# <!-- Global site tag (gtag.js) - Google Analytics --> <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-47887487-1"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'UA-47887487-1'); </script>
# <!--Facebook Pixel Code-->
# <script>
# 	!function(f, b, e, v, n, t, s){
# 	if (f.fbq) return; n = f.fbq = function(){
# 	n.callMethod?
# 	n.callMethod.apply(n, arguments):n.queue.push(arguments)}; if (!f._fbq) f._fbq = n;
# 	n.push = n; n.loaded = !0; n.version = '2.0'; n.queue =[]; t = b.createElement(e); t.async = !0;
# 	t.src = v; s = b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t, s)}
# 	(window,
# 	document,'script','https://connect.facebook.net/en_US/fbevents.js');
# 	fbq('init', '143560199475367', {} , {'agent': 'plsapo'}); // Insert your pixel ID here.
# 	fbq('track', 'PageView',{},{ eventID: Bizweb.fbEventId });
#
# 	fbq('track', 'ViewContent', {
# 	content_ids: [12115613],
# 	content_name: 'HTC U12 Plus (Brandnew - Seabox)',
# 	content_type: 'product_group',
# 	value: '8690000.0000',
# 	currency: window.BizwebAnalytics.meta.currency
# 	}, { eventID: Bizweb.fbEventId });
#
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=143560199475367&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!--DO NOT MODIFY-->
# <!--End Facebook Pixel Code-->
# <script>
# 	var eventsListenerScript = document.createElement('script');
# 	eventsListenerScript.async = true;
#
# 	eventsListenerScript.src = "/dist/js/store_events_listener.min.js?v=9e67bf4";
#
# 	document.getElementsByTagName('head')[0].appendChild(eventsListenerScript);
# </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.2.3/jquery.min.js" type="text/javascript"></script>
# <script>var ProductReviewsAppUtil=ProductReviewsAppUtil || {};</script>
# <link href="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/tkn-style.css?1654105636388" rel="stylesheet" type="text/css"/>
# <link href="https://instantsearch.sapoapps.vn/content/font-awesome/css/font-awesome.min.css" rel="stylesheet"/>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/tkn-util.js?1654105636388" type="text/javascript"></script>
# <link href="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/tkn-style.css?1654105636388" rel="stylesheet" type="text/css"/>
# <link href="https://instantsearch.sapoapps.vn/content/font-awesome/css/font-awesome.min.css" rel="stylesheet"/>
# </head>
# <body class="bg-body">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KGN97ZG" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="header">
# <div class="container">
# <div class="row">
# <div class="col-lg-2 col-md-2 col-100-h">
# <button class="navbar-toggle collapsed visible-sm visible-xs" id="trigger-mobile" type="button"><span class="sr-only">Toggle navigation</span><span class="icon-bar"></span><span class="icon-bar"></span><span class="icon-bar"></span></button>
# <div class="logo"><a class="logo-wrapper" href="/" title="WORLDPHONE.VN"><img alt="logo WORLDPHONE.VN" data-lazyload="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/logo.png?1654105636388" src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/loader.svg?1654105636388"/></a></div>
# <div class="mobile-cart visible-sm visible-xs">
# <a href="/cart" title="Giỏ hàng"><i class="fa fa-cart-arrow-down"></i><div class="cart-right"><span class="count_item_pr">0</span></div></a>
# </div>
# </div>
# <div class="col-lg-3 col-md-3 add-arrow">
# <form action="/search" class="search-bar has-validation-callback" method="get" role="search">
# <input autocomplete="off" class="input-group-field search-text" name="query" placeholder="Tìm kiếm..." type="search" value=""/>
# <button class="btn icon-fallback-text">
# <svg height="20px" style="enable-background:new 0 0 451 451;" version="1.1" viewbox="0 0 451 451" width="20px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><g><g>
# <path class="active-path" d="M447.05,428l-109.6-109.6c29.4-33.8,47.2-77.9,47.2-126.1C384.65,86.2,298.35,0,192.35,0C86.25,0,0.05,86.3,0.05,192.3   s86.3,192.3,192.3,192.3c48.2,0,92.3-17.8,126.1-47.2L428.05,447c2.6,2.6,6.1,4,9.5,4s6.9-1.3,9.5-4   C452.25,441.8,452.25,433.2,447.05,428z M26.95,192.3c0-91.2,74.2-165.3,165.3-165.3c91.2,0,165.3,74.2,165.3,165.3   s-74.1,165.4-165.3,165.4C101.15,357.7,26.95,283.5,26.95,192.3z" data-old_color="#f20000" data-original="#000000" fill="#f20000"></path>
# </g></g> </svg>
# </button>
# </form>
# <div class="arrow-left"></div>
# </div>
# <div class="col-md-7 col-lg-7 nav-bg-white hidden-sm hidden-xs">
# <ul class="nav" id="nav">
# <li class="nav-item"><a class="nav-link" href="/" title="TRANG CHỦ">TRANG CHỦ</a></li>
# <li class="nav-item">
# <a class="nav-link" href="/dien-thoai-blackberry" title="ĐIỆN THOẠI BLACKBERRY">ĐIỆN THOẠI BLACKBERRY <i class="fa fa-angle-down" data-toggle="dropdown"></i></a>
# <ul class="dropdown-menu">
# <li class="nav-item-lv2"><a class="nav-link" href="/blackberry-os" title="BLACKBERRY OS">BLACKBERRY OS</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/blackberry-10" title="BLACKBERRY 10">BLACKBERRY 10</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/blackberry-android" title="BLACKBERRY ANDROID">BLACKBERRY ANDROID</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/blackberry-cao-cap" title="BLACKBERRY CAO CẤP">BLACKBERRY CAO CẤP</a></li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/dien-thoai-android" title="ĐIỆN THOẠI ANDROID">ĐIỆN THOẠI ANDROID <i class="fa fa-angle-down" data-toggle="dropdown"></i></a>
# <ul class="dropdown-menu">
# <li class="nav-item-lv2"><a class="nav-link" href="/htc" title="ĐIỆN THOẠI HTC">ĐIỆN THOẠI HTC</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/lg" title="ĐIỆN THOẠI LG">ĐIỆN THOẠI LG</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/samsung" title="ĐIỆN THOẠI SAMSUNG">ĐIỆN THOẠI SAMSUNG</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/google" title="ĐIỆN THOẠI GOOGLE">ĐIỆN THOẠI GOOGLE</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/motorola" title="ĐIỆN THOẠI MOTOROLA">ĐIỆN THOẠI MOTOROLA</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/dien-thoai-sony" title="ĐIỆN THOẠI SONY">ĐIỆN THOẠI SONY</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/dien-thoai-2-sim" title="ĐIỆN THOẠI 2 SIM">ĐIỆN THOẠI 2 SIM</a></li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/iphone" title="APPLE IPHONE">APPLE IPHONE <i class="fa fa-angle-down" data-toggle="dropdown"></i></a>
# <ul class="dropdown-menu">
# <li class="nav-item-lv2"><a class="nav-link" href="/iphone-12-12-pro-12-pro-max" title="IPHONE 12 | 12 PRO | 12 PRO MAX">IPHONE 12 | 12 PRO | 12 PRO MAX</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/iphone-11-11-pro-11-pro-max" title="IPHONE 11 | 11 PRO | 11 PRO MAX">IPHONE 11 | 11 PRO | 11 PRO MAX</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/iphone-xs-xs-max" title="IPHONE XS | XS MAX">IPHONE XS | XS MAX</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/iphone-x-iphone-xr" title="IPHONE X | XR">IPHONE X | XR</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/iphone-8-8-plus" title="IPHONE 8 | 8 PLUS">IPHONE 8 | 8 PLUS</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/iphone-7-7-plus" title="IPHONE 7 | 7 PLUS">IPHONE 7 | 7 PLUS</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/ipad" title="IPAD">IPAD</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/iphone-13-13-pro-13-pro-max" title="iPhone 13 | 13 Pro | 13 Pro Max">iPhone 13 | 13 Pro | 13 Pro Max</a></li>
# </ul>
# </li>
# <li class="nav-item"><a class="nav-link" href="/khuyen-mai" title="KHUYẾN MÃI">KHUYẾN MÃI</a></li>
# <li class="nav-item">
# <a class="nav-link" href="/linh-phu-kien-chinh-hang" title="LINH PHỤ KIỆN">LINH PHỤ KIỆN <i class="fa fa-angle-down" data-toggle="dropdown"></i></a>
# <ul class="dropdown-menu">
# <li class="nav-item-lv2"><a class="nav-link" href="/bao-gia" title="BÁO GIÁ LINH KIỆN">BÁO GIÁ LINH KIỆN</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/sac-cap" title="SẠC - CÁP">SẠC - CÁP</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/tai-nghe-loa" title="TAI NGHE - LOA">TAI NGHE - LOA</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/bao-da-op-lung" title="BAO DA - ỐP LƯNG">BAO DA - ỐP LƯNG</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/tai-nghe" title="THẺ NHỚ">THẺ NHỚ</a></li>
# <li class="dropdown-submenu nav-item-lv2">
# <a class="nav-link" href="/linh-kien-blackberry" title="LINH KIỆN BLACKBERRY">LINH KIỆN BLACKBERRY <i class="fa fa-angle-right"></i></a>
# <ul class="dropdown-menu">
# <li class="nav-item-lv3"><a class="nav-link" href="/man-hinh-blackberry" title="MÀN HÌNH BLACKBERRY">MÀN HÌNH BLACKBERRY</a></li>
# <li class="nav-item-lv3"><a class="nav-link" href="/ban-phim-blackberry" title="BÀN PHÍM BLACKBERRY">BÀN PHÍM BLACKBERRY</a></li>
# <li class="nav-item-lv3"><a class="nav-link" href="/camera-blackberry" title="CAMERA BLACKBERRY">CAMERA BLACKBERRY</a></li>
# <li class="nav-item-lv3"><a class="nav-link" href="/bo-vo-blackberry" title="BỘ VỎ BLACKBERRY">BỘ VỎ BLACKBERRY</a></li>
# <li class="nav-item-lv3"><a class="nav-link" href="/pin" title="PIN">PIN</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu nav-item-lv2">
# <a class="nav-link" href="/linh-kien-google" title="LINH KIỆN GOOGLE">LINH KIỆN GOOGLE <i class="fa fa-angle-right"></i></a>
# <ul class="dropdown-menu">
# <li class="nav-item-lv3"><a class="nav-link" href="/linh-kien-google-pixel-pixel-xl" title="LINH KIỆN GOOGLE PIXEL/PIXEL XL">LINH KIỆN GOOGLE PIXEL/PIXEL XL</a></li>
# <li class="nav-item-lv3"><a class="nav-link" href="/linh-kien-google-pixel-2-pixel-2-xl" title="LINH KIỆN GOOGLE PIXEL 2/PIXEL 2 XL">LINH KIỆN GOOGLE PIXEL 2/PIXEL 2 XL</a></li>
# <li class="nav-item-lv3"><a class="nav-link" href="/linh-kien-google-pixel-3-3-xl-3a-3a-xl" title="LINH KIỆN GOOGLE PIXEL 3/3 XL/3a/3a XL">LINH KIỆN GOOGLE PIXEL 3/3 XL/3a/3a XL</a></li>
# <li class="nav-item-lv3"><a class="nav-link" href="/linh-kien-google-pixel-4-4-xl-4a" title="LINH KIỆN GOOGLE PIXEL 4/4 XL/4a">LINH KIỆN GOOGLE PIXEL 4/4 XL/4a</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="nav-item"><a class="nav-link" href="/tin-cong-nghe" title="NEWS &amp; TIPS">NEWS &amp; TIPS</a></li>
# <li class="nav-item">
# <a class="nav-link" href="/do-choi-cong-nghe" title="ĐỒ CHƠI SỐ">ĐỒ CHƠI SỐ <i class="fa fa-angle-down" data-toggle="dropdown"></i></a>
# <ul class="dropdown-menu">
# <li class="nav-item-lv2"><a class="nav-link" href="/robot-hut-bui" title="ROBOT HÚT BỤI">ROBOT HÚT BỤI</a></li>
# <li class="nav-item-lv2"><a class="nav-link" href="/dong-ho-thong-minh" title="ĐỒNG HỒ THÔNG MINH">ĐỒNG HỒ THÔNG MINH</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </header>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/option-selectors.js?1654105636388" type="text/javascript"></script>
# <script src="//bizweb.dktcdn.net/assets/themes_support/api.jquery.js" type="text/javascript"></script>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/owl.carousel.min.js?1654105636388" type="text/javascript"></script>
# <section class="bread-crumb margin-bottom-10">
# <div class="container">
# <div class="row">
# <div class="col-xs-12">
# <ul class="breadcrumb" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <li class="home"><a href="/" itemprop="url" title="Trang chủ"><span itemprop="title">Trang chủ</span></a><span><i class="fa fa-angle-right"></i></span></li>
# <li><a href="/htc" itemprop="url" title="ĐIỆN THOẠI HTC"><span itemprop="title">ĐIỆN THOẠI HTC</span></a><span><i class="fa fa-angle-right"></i></span></li>
# <li><strong><span itemprop="title">HTC U12 Plus (Brandnew - Seabox)</span></strong></li><li>
# </li></ul>
# </div>
# </div>
# </div>
# </section>
# <section class="product" itemscope="" itemtype="http://schema.org/Product">
# <meta content="//worldphone.vn/htc-u12-plus-moi" itemprop="url"/>
# <meta content="HTC U12 Plus (Brandnew - Seabox)" itemprop="name"/>
# <meta content="http://bizweb.dktcdn.net/thumb/grande/100/168/366/products/sp.jpg?v=1546232067460" itemprop="image"/>
# <meta content="
#   Màn hình:  Super LCD 6, 6.0, Quad HD+ (2K+)
#   2 Camera trước:  8MP, 8MP
#   2 Camera sau:  16MP, 12MP
#   RAM:  6GB
#   Bộ nhớ trong:  64GB
#   Chip:  Snapdragon 845
#   Dung lượng pin:  3500mAh
#   Hệ điều hành:  Android 8.0
#   SIM:  2 SIM Nano  " itemprop="description"/>
# <meta content="HTC" itemprop="brand"/>
# <meta content="" itemprop="model"/>
# <div class="price-box" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <link href="http://schema.org/OutOfStock" itemprop="availability"/>
# <meta content="VND" itemprop="priceCurrency"/>
# <meta content="8690000" itemprop="price"/>
# <meta content="https://worldphone.vn/htc-u12-plus-moi" itemprop="url"/>
# <meta content="2099-01-01" itemprop="priceValidUntil"/>
# </div>
# <div class="hidden" itemprop="review" itemscope="" itemtype="https://schema.org/Review">
# <span itemprop="itemReviewed" itemscope="" itemtype="https://schema.org/Thing">
# <span itemprop="name">HTC U12 Plus (Brandnew - Seabox)</span>
# </span>
# <span itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <span itemprop="name">WORLDPHONE.VN</span>
# </span>
# <div class="hidden" itemprop="reviewRating" itemscope="" itemtype="https://schema.org/Rating">
# <span itemprop="ratingValue">10</span> out of
# 			<span itemprop="bestRating">10</span>
# </div>
# <span itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
# <meta content="WORLDPHONE.VN" itemprop="name"/>
# </span>
# </div>
# <div class="container">
# <div class="row">
# <div class="details-product padding-bottom-10">
# <div class="col-xs-12 col-sm-12 col-lg-12 col-md-12 details-pro">
# <div class="product-top clearfix">
# <h1 class="title-head">HTC U12 Plus (Brandnew - Seabox)</h1>
# <div class="sku-product">
# 							Mã sản phẩm: <span class="variant-sku" content="Đang cập nhật" itemprop="sku">(Đang cập nhật...)</span>
# <span class="hidden" itemprop="brand" itemscope="" itemtype="https://schema.org/brand">WORLDPHONE.VN</span>
# </div>
# <div class="panel-product-rating clearfix">
# <div class="bizweb-product-reviews-badge" data-id="12115613"></div>
# <div class="iddanhgia" onclick="scrollToxx();">
# <span>Đánh giá sản phẩm</span>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-lg-5 col-md-5">
# <div class="relative product-image-block no-thum">
# <div class="large-image">
# <a class="large_image_url" data-rel="prettyPhoto[product-gallery]" href="//bizweb.dktcdn.net/thumb/1024x1024/100/168/366/products/sp.jpg?v=1546232067460" title="HTC U12 Plus (Brandnew - Seabox)">
# <img alt="HTC U12 Plus (Brandnew - Seabox)" class="img-responsive center-block" id="zoom_01" src="//bizweb.dktcdn.net/thumb/1024x1024/100/168/366/products/sp.jpg?v=1546232067460"/>
# </a>
# <div class="hidden">
# </div>
# </div>
# <div class="social-sharing margin-top-10">
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5cb4487c04a4d6b9" type="text/javascript"></script>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <div class="addthis_inline_share_toolbox"></div>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-lg-4 col-md-4 details-pro">
# <div class="price-box clearfix">
# <div class="special-price">
# <span class="price product-price">8.690.000₫</span>
# </div> <!-- Giá -->
# </div>
# <ul>
# <li class="inventory_quantity" itemscope="" itemtype="http://schema.org/ItemAvailability">
# <span class="stock-brand-title">Tình trạng:</span>
# <span class="a-stock a-stock-out" itemprop="supersededBy">Hết hàng</span>
# </li>
# </ul>
# <div class="form-product">
# <form action="/cart/add" class="form-inline" enctype="multipart/form-data" id="add-to-cart-form" method="post">
# <div class="box-variant clearfix">
# <input name="variantId" type="hidden" value="64858510"/>
# </div>
# <div class="visible-xs">
# <div class="ant_onlineSupport">
# <div class="fs-dtckr">
# <style>
# 			.fs-dtcktit{margin-bottom:10px}
# 			.fs-trhcj{position:relative;font-size:13px;color:#337ab7;margin-bottom:15px;padding-left:28px}
# 			.fs-trhcj a{color:#337ab7}
# 			.fs-trhcj:before{content:"";position:absolute;top:0;left:0;display:inline-block;height:17px;width:17px;background:url(/images/tronghop.png) no-repeat center}
# 			.fs-dtckr {padding: 15px;}
# 			.fs-trhcj:before {
# 				content: "";
# 				position: absolute;
# 				top: 3px;
# 				left: 0;
# 				display: inline-block;
# 				height: 17px;
# 				width: 17px;
# 				background: url(//bizweb.dktcdn.net/100/168/366/themes/713148/assets/tronghop.png?1654105636388) no-repeat center;
# 			}
# 			.fs-trhcj {
# 				    min-height: 20px;
# 				position: relative;
# 				font-size: 13px;
# 				color: #337ab7;
# 				margin-bottom: 15px;
# 				padding-left: 28px;
# 			}
# 			.fs-dtckbox li {
# 				font-size: 13px;
# 				color: #545454;
# 				margin-bottom: 8px;
# 				padding-left: 28px;
# 				position: relative;
# 			}
# 			.fs-dtckbox li span {
# 				position: absolute;
# 				top: 1px;
# 				left: 0;
# 				height: 20px;
# 				width: 16px;
# 			}
# 			.fs-dtckbox li p {
# 				margin: 0;
# 			}
# 			.icdt {
# 				display: inline-block;
# 				background-image: url(//bizweb.dktcdn.net/100/168/366/themes/713148/assets/icondt.png?1654105636388);
# 				background-repeat: no-repeat;
# 			}
# 			.fs-dtck1 {
# 				background-position: -5px -51px;
# 			}
# 			.fs-dtck2 {
# 				background-position: -27px -51px;
# 			}
# 			.fs-dtck3 {
# 				background-position: -53px -51px;
# 			}
# 			.fs-dtck4 {
# 				width: 15px;
# 				background-position: -78px -51px;
# 			}
# 			.promo-detail h4 {
# 				font-size: 14px;
# 				color: inherit;
# 				font-weight: 400;
# 			}
# 		</style>
# <h4 class="fs-dtcktit">Bộ sản phẩm bao gồm:</h4>
# <div class="fs-trhcj fancybox-access-box" style="cursor:pointer">
# <div class="promo-detail"></div>
# <script>
# 				$(document).ready(function() {
# 					$('#tab-1 h4').wrap('<p class="promo" />');
# 					$('.promo').contents().appendTo('.promo-detail');
# 				});
# 			</script>
# </div>
# <h4 class="fs-dtcktit">Worldphone cam kết:</h4>
# <ul class="fs-dtckbox">
# <li><span class="icdt fs-dtck1"></span> <p>Hàng chính hãng, nguyên bản</p></li>
# <li><span class="icdt fs-dtck2"></span> <p>Hỗ trợ linh hoạt sau bảo hành</p></li>
# <li><span class="icdt fs-dtck3"></span> <p>Miễn phí giao hàng toàn quốc</p></li>
# <li><span class="icdt fs-dtck4"></span> <p>Miễn phí thu cũ đổi mới</p></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="box-promotion">
# <p class="fk-tit">Khuyến mại đặc biệt (SL có hạn)</p>
# <div class="fk-main">
# <ul>
# <li>Gói bảo hành: 3 tháng - 1 đổi 1 trong 15 ngày</li>
# <li>Tặng ốp silicon, que chọc sim</li>
# <li>Giảm ngay 100k cho sinh viên</li></ul>
# </div>
# <input name="" type="hidden" value="
#
#  Gói bảo hành: 3 tháng - 1 đổi 1 trong 15 ngày
#  Tặng ốp silicon, que chọc sim
#  Giảm ngay 100k cho sinh viên  "/>
# </div>
# <div class="clearfix form-group">
# <div class="btn-mua-1" onclick="location.href='https://worldphone.vn/tat-tan-tat-nhung-dieu-ban-can-biet-khi-mua-dien-thoai-tra-gop'">
# <div class="btn">
# <span class="txt-main" onclick="location.href='https://worldphone.vn/tat-tan-tat-nhung-dieu-ban-can-biet-khi-mua-dien-thoai-tra-gop'"><i class="fa fa-cart-arrow-down padding-right-10"></i> Mua trả góp</span>
# </div>
# </div>
# <div class="btn-mua">
# <button class="btn btn-lg btn-style btn-style-active btn-cart btn-soldout" disabled="disabled">
# <span class="txt-main"><i class="fa fa-cart-arrow-down padding-right-10"></i> Hết hàng</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# <div class="clearfix"></div>
# <div class="call-and-payment">
# <div class="box-zalo-promotion">
# 							 Trở thành <span>Worldphone Member</span> ngay hôm nay! <a href="#" title="Click xem thể lệ">Click </a>
# </div>
# <div class="hotline_product">
# 							Gọi để đặt hàng: <a href="tel:1900.6729" title="1900.6729">1900.6729</a>
# </div>
# <div class="hotline_product_box" id="myorder">
# <form accept-charset="utf-8" action="/contact" id="contact" method="post">
# <input name="FormType" type="hidden" value="contact"/>
# <input name="utf8" type="hidden" value="true"/><input id="Token-71c16360b02142299fe1b775b262e500" name="Token" type="hidden"/><script src="https://www.google.com/recaptcha/api.js?render=6Ldtu4IUAAAAAMQzG1gCw3wFlx_GytlZyLrXcsuK"></script>
# <script>
# grecaptcha.ready(function() {
# grecaptcha.execute("6Ldtu4IUAAAAAMQzG1gCw3wFlx_GytlZyLrXcsuK", {action: "/contact"})
# .then(function(token) {
# document.getElementById("Token-71c16360b02142299fe1b775b262e500").value = token
# });
# });
# </script>
# <input name="FormType" type="hidden" value="contact"/>
# <input name="utf8" type="hidden" value="true"/>
# <div class="orderFormActions">
# <div class="orderFormInput">
# <input class="hidden input-control disabled" name="contact[name]" readonly="" type="text" value="HTC U12 Plus (Brandnew - Seabox)"/>
# <input class="hidden input-control" data-validation="email" data-validation-error-msg="Email sai định dạng" name="contact[email]" pattern="[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,63}$" placeholder="Email" required="" type="email" value="worldphone.vn@gmail.com"/>
# <span class="dix"><i aria-hidden="true" class="fa fa-phone"></i></span>
# <input class="number-sidebar input-control abc&gt;" maxlength="11" minlength="8" name="contact[phone]" placeholder="Để lại SĐT để được tư vấn" required="" type="tel"/>
# <textarea class="hidden input-control" data-validation="required" data-validation-error-msg="Không được để trống" name="contact[Body]" placeholder="Nội dung" required="">Tư vấn về sản phẩm</textarea>
# <div class="text-center fgr">
# <button class="button type_2 btn btn-style btn-style-active" type="submit"><i aria-hidden="true" class="fa fa-paper-plane"></i></button>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-12 col-lg-3 col-md-3 hidden-xs">
# <div class="ant_onlineSupport">
# <div class="fs-dtckr">
# <style>
# 			.fs-dtcktit{margin-bottom:10px}
# 			.fs-trhcj{position:relative;font-size:13px;color:#337ab7;margin-bottom:15px;padding-left:28px}
# 			.fs-trhcj a{color:#337ab7}
# 			.fs-trhcj:before{content:"";position:absolute;top:0;left:0;display:inline-block;height:17px;width:17px;background:url(/images/tronghop.png) no-repeat center}
# 			.fs-dtckr {padding: 15px;}
# 			.fs-trhcj:before {
# 				content: "";
# 				position: absolute;
# 				top: 3px;
# 				left: 0;
# 				display: inline-block;
# 				height: 17px;
# 				width: 17px;
# 				background: url(//bizweb.dktcdn.net/100/168/366/themes/713148/assets/tronghop.png?1654105636388) no-repeat center;
# 			}
# 			.fs-trhcj {
# 				    min-height: 20px;
# 				position: relative;
# 				font-size: 13px;
# 				color: #337ab7;
# 				margin-bottom: 15px;
# 				padding-left: 28px;
# 			}
# 			.fs-dtckbox li {
# 				font-size: 13px;
# 				color: #545454;
# 				margin-bottom: 8px;
# 				padding-left: 28px;
# 				position: relative;
# 			}
# 			.fs-dtckbox li span {
# 				position: absolute;
# 				top: 1px;
# 				left: 0;
# 				height: 20px;
# 				width: 16px;
# 			}
# 			.fs-dtckbox li p {
# 				margin: 0;
# 			}
# 			.icdt {
# 				display: inline-block;
# 				background-image: url(//bizweb.dktcdn.net/100/168/366/themes/713148/assets/icondt.png?1654105636388);
# 				background-repeat: no-repeat;
# 			}
# 			.fs-dtck1 {
# 				background-position: -5px -51px;
# 			}
# 			.fs-dtck2 {
# 				background-position: -27px -51px;
# 			}
# 			.fs-dtck3 {
# 				background-position: -53px -51px;
# 			}
# 			.fs-dtck4 {
# 				width: 15px;
# 				background-position: -78px -51px;
# 			}
# 			.promo-detail h4 {
# 				font-size: 14px;
# 				color: inherit;
# 				font-weight: 400;
# 			}
# 		</style>
# <h4 class="fs-dtcktit">Bộ sản phẩm bao gồm:</h4>
# <div class="fs-trhcj fancybox-access-box" style="cursor:pointer">
# <div class="promo-detail"></div>
# <script>
# 				$(document).ready(function() {
# 					$('#tab-1 h4').wrap('<p class="promo" />');
# 					$('.promo').contents().appendTo('.promo-detail');
# 				});
# 			</script>
# </div>
# <h4 class="fs-dtcktit">Worldphone cam kết:</h4>
# <ul class="fs-dtckbox">
# <li><span class="icdt fs-dtck1"></span> <p>Hàng chính hãng, nguyên bản</p></li>
# <li><span class="icdt fs-dtck2"></span> <p>Hỗ trợ linh hoạt sau bảo hành</p></li>
# <li><span class="icdt fs-dtck3"></span> <p>Miễn phí giao hàng toàn quốc</p></li>
# <li><span class="icdt fs-dtck4"></span> <p>Miễn phí thu cũ đổi mới</p></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-12 col-lg-12 col-md-12 margin-top-10">
# <div class="row">
# <div class="col-md-9">
# <div class="product-tab e-tabs padding-bottom-10">
# <ul class="tabs tabs-title clearfix margin-bottom-20">
# <li class="tab-link" data-tab="tab-1"><h3><span>Mô tả</span></h3></li>
# </ul>
# <div class="tab-content" id="tab-1">
# <div class="rte" id="fancy-image-view">
# <div class="ba-text-fpt has-height">
# <h1 style="text-align: center;"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><strong><span style="line-height:150%"><span style="color:#365f91">Đánh giá chi tiết điện thoại HTC U12+ nổi bật về mọi mặt</span></span></strong></span></span></h1>
# <p><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><b><i><span style="line-height:150%">Điện thoại HTC U12+ nổi bật cả về thiết kế, hiệu năng, màn hình sắc nét, camera chất lượng cao. </span></i></b></span></span></span></p>
# <p><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><b><i></i></b></span></span></span><iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="315" src="https://www.youtube.com/embed/n1ZD8f9sQsk" width="560"></iframe></p>
# <p><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><b><i><span style="line-height:150%">Do đó, ngay từ khi mới ra mắt, U12 Plus đã thu hút được sự chú ý của các tín đồ smartphone.</span></i></b></span></span></span></p>
# <p> </p>
# <p> </p>
# <p style="text-align: center;"><span style="font-size:16px;"><em>Đánh giá nhanh Flagship HTC U12+</em></span></p>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Chính thức ra mắt thị trường vào năm 2018, điện thoại HTC U12+ nhanh chóng trở thành mẫu smartphone được nhiều người lựa chọn. Với hàng loạt những ưu điểm nổi bật cả về thiết kế, màn hình, camera, pin, tính năng sử dụng, … mẫu điện thoại này vẫn giữ được vị trí nhất định trong lòng người tiêu dùng và được nhiều người lựa chọn trong năm nay. Những đánh giá chi tiết dưới đây sẽ giúp bạn có được cái nhìn cụ thể nhất về đứa con cưng của HTC, điện thoại U12 Plus.</span></span></span></span></p>
# <p style="text-align: center;"><span style="font-size:16px;"><img data-thumb="original" original-height="2700" original-width="3600" src="//bizweb.dktcdn.net/100/168/366/files/img-20190910-080440.jpg?v=1576651181852" style="width: 900px; height: 675px;"/></span></p>
# <p align="center" style="text-align:center"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><i><span style="line-height:150%">Điện thoại HTC U12+ - sự lựa chọn thông minh cho các tín đồ smartphone</span></i></span></span></span></p>
# <h2><span style="font-size:16px;"><strong><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="color:#4f81bd"><span style="line-height:150%">1. Đánh giá thiết kế</span></span></span></span></strong></span></h2>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Màn hình 18:9 được bao phủ bởi những đường cong ấn tượng và 2 mặt kính sáng bóng chính là những ưu điểm nổi bật về thiết kế của chiếc điên thoại U12 Plus. So với các sản phẩm tiền nhiệm, thiết kế này không có sự khác biệt của lớn nhưng chúng vẫn được đánh giá là mẫu điện thoại có thiết kế đẹp mắt. Bên cạnh đó, nhà sản xuất còn đưa ra 3 sự lựa chọn về màu sắc gồm: xanh trong suốt, lửa đỏ và gốm đen. Nếu như xanh trong suốt giúp người dùng có thể nhìn thấy các linh kiện bên trong thì lửa đỏ lại có sự chuyển đổi màu sắc tinh tế từ vàng sang đỏ với các góc nhìn khác nhau. Điều này càng nâng cao giá trị thẩm mỹ của U12+ trong mắt người tiêu dùng. </span></span></span></span></p>
# <p style="text-align:justify"><iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="315" src="https://www.youtube.com/embed/iyryIAwiDJg" width="560"></iframe></p>
# <p style="text-align: center;"><span style="font-size:16px;"><img data-thumb="original" original-height="750" original-width="1200" src="//bizweb.dktcdn.net/100/168/366/files/1-694e9516-e4d3-4c0a-9a3b-54d27e902fd9.jpg?v=1576647499384" style="width: 800px; height: 500px;"/></span></p>
# <p align="center" style="text-align:center"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><i><span style="line-height:150%">HTC U12+ có 3 phiên bản màu</span></i></span></span></span></p>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Có một sự thay đổi lớn của HTC12 Plus so với “đàn anh” của mình chính là bàn phím vật lý. Không giống như Blackberry luôn bảo tồn loại bàn phím này,HTC đã quyết định loại bỏ chúng, thay vào đó là bàn phím cảm ứng và U12+ là một trong những sản phẩm được áp dụng công nghệ này. Mặc dù vậy, khi sử dụng bàn phím cảm ứng, người dùng vẫn có cảm giác như đang sử dụng bàn phím vật lý nhờ tính rung nhẹ trên màn hình. Đặc điểm này nhận được những đánh giá theo nhiều chiều khác nhau. Tuy nhiên, hầu hết người dùng đều công nhận rằng bàn phím cảm ứng trên U12+ vẫn gặp phải một số nhược điểm và chúng cần được khắc phục vào các phiên bản sau.</span></span></span></span></p>
# <h2><span style="font-size:16px;"><strong><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="color:#4f81bd"><span style="line-height:150%">2. Đánh giá màn hình</span></span></span></span></strong></span></h2>
# <p style="text-align: center;"><img data-thumb="original" original-height="2623" original-width="3497" src="//bizweb.dktcdn.net/100/168/366/files/img-20190910-080919-01.jpg?v=1576651228385" style="width: 900px; height: 675px;"/></p>
# <p align="center" style="text-align:center"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><i><span style="line-height:150%">Kích thước màn hình HTc U12+ lên tới 6.4inch, tỷ lệ 18:9 đi kèm với nhiều tính năng nổi bật</span></i></span></span></span></p>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Hãng sản xuất HTC đã trang bị cho dòng sản phẩm U12Plus màn hình lớn có kích thước 6 inch với tỉ lệ 18:9, độ phân giải Quad HD+ cùng khả năng hỗ trợ dải màu DCI-P3. Hàng loạt các tính năng nổi bật này đã giúp U12+ thực sự nổi bật, mang đến cho người dùng những trải nghiệm tuyệt vời. Một đặc điểm khác, độc và lạ của U12 Plus, khác biệt hoàn toàn so với các mẫu smartphone khác trên thị trường đó là 2 viền benzel. Mặc dù, viền benzel khá dày nhưng chúng vẫn đảm bảo được sự thanh thoát, nhẹ nhàng cho sản phẩm.</span></span></span></span></p>
# <h2><span style="font-size:16px;"><strong><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="color:#4f81bd"><span style="line-height:150%">3. Đánh giá camera</span></span></span></span></strong></span></h2>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">HTC chưa bao giờ làm người dùng thất vọng khi họ luôn dành những bộ camera tốt nhất cho sản phẩm của mình và điện thoại HTC U12+ cũng không ngoại lệ. Ở mặt sau, U12+ sở hữu bộ camera kép gồm 1 camera 12MP góc rộng và khẩu độ f/1.75 và một camera tele 16MP khẩu độ f/2.6. Bằng công nghệ chống rung quang học, chống rung điện tử, xóa phông, cân bằng ánh sáng, quay video ở phân giải 4K, quay slow, … tất cả đã kết hợp để tạo ra những tấm hình chân thực, sắc nét và sinh động nhất. </span></span></span></span></p>
# <p style="text-align: center;"><img data-thumb="original" original-height="2664" original-width="3552" src="//bizweb.dktcdn.net/100/168/366/files/img-20190910-080616.jpg?v=1576651457238" style="width: 900px; height: 675px;"/></p>
# <p align="center" style="text-align:center"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><i><span style="line-height:150%">Bộ camera kép trên điện thoại U12 Plus giúp người dùng lưu lại những hình ảnh sắc nét và chân thực</span></i></span></span></span></p>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Riêng với camera trước, chúng được trang bị ống kính có độ phân giải 8MP với khẩu độ f/2.0 và góc nhìn 84 độ. Mặc dù không có tính năng chống rung nhưng camera selfie của HTC U12+ vẫn giành được số điểm cao nhờ các tính năng làm đẹp độc đáo.</span></span></span></span></p>
# <h2><span style="font-size:16px;"><strong><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="color:#4f81bd"><span style="line-height:150%">4. Đánh giá pin</span></span></span></span></strong></span></h2>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Theo thông số kỹ thuật từ nhà sản xuất, điện thoại HTC 12Plus sở hữu pin có dung lượng 3500 mAh nhưng trải nghiệm thực tế của người dùng cho thấy chúng chỉ có thể đáp ứng nhu cầu sử dụng trong khoảng thời gian từ 3 đến 4 đồng hồ. Tuy nhiên, người dùng cũng không cần quá lo lắng đến việc HTC12+ có thể “ngưng thở” trong một ngày bởi chúng đã được trang bị tính năng sạc nhanh 4.0. </span></span></span></span></p>
# <p style="text-align: center;"><span style="font-size:16px;"><img data-thumb="original" original-height="721" original-width="1430" src="//bizweb.dktcdn.net/100/168/366/files/6-a5eb961c-0d77-49cd-bcb9-b011453a037d.jpg?v=1576647568508" style="width: 800px; height: 403px;"/></span></p>
# <p align="center" style="text-align:center"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><i><span style="line-height:150%">Kết quả bài test cho thấy pin điện thoại U12Plus có tuổi đời không quá ấn tượng</span></i></span></span></span></p>
# <h2><span style="font-size:16px;"><strong><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="color:#4f81bd"><span style="line-height:150%">5. Đánh giá hiệu năng</span></span></span></span></strong></span></h2>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Điện thoại HTC 12+ được trang bị bộ vi xử lý Snapdragon 845, RAM 6GB. Với con chip này, HTC U12+ có hiệu năng không kém gì các dòng điện thoại nổi bật hiện nay như: OnPlus 6, Samsung Galaxy S9. Do đó, dù là chơi game, nghe nhạc, xin phim, hay sử dụng bất kỳ ứng dụng nào, U12+ luôn mang đến cho người dùng cảm giác tốt nhất, mượt mà nhất. </span></span></span></span></p>
# <p style="text-align: center;"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"> <img data-thumb="original" original-height="376" original-width="602" src="//bizweb.dktcdn.net/100/168/366/files/5-89d903d8-ee6d-4ebe-8050-9315e64e5f69.jpg?v=1576647591330" style="width: 800px; height: 500px;"/></span></span></span></p>
# <p align="center" style="text-align:center"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><i><span style="line-height:150%">Giao diện màn hình HC U12+ không nhận được sự đánh giá cao từ phía người sử dụng</span></i></span></span></span></p>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Mặc dù khá nổi bật về phần thiết kế, camera, màn hình nhưng HTC U12+ lại gặp phải nhiều nhược điểm ở phương diện phần mềm. So với các sản phẩm đời trước, U12 Plus không có sự khác biệt về giao diện, ngoài ra, một số người còn cho rằng, các tính năng xuất hiện trên màn hình chính không là không cần thiết khi chúng không mang lại bất kỳ lợi ích gì. Điểm cộng duy nhất mà U12+ nhận được trên phần mềm sử dụng đó hính là tính năng bóp cạnh viền Edge Sense. Nhờ tính năng này, người dùng có thể dễ dàng xoay màn hình sử dụn cũng như thiết lập các ứng dụng ưa thích, bật các thông báo hay kích hoạt trợ lý ảo một cách nhanh chóng.</span></span></span></span></p>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Bên cạnh đó, HTC U12+ còn được trang bị tính năng bảo bật bằng sinh trắc vân tay kết hợp Face ID. Tính năng này giúp người dùng có thể mở máy một cách dễ dàng nhưng tính bảo vật vẫn được đảm bảo ở mức tối đa. </span></span></span></span></p>
# <h2><span style="font-size:16px;"><strong><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="color:#4f81bd"><span style="line-height:150%">6. Giá bán điện thoại HTC U12+ vô cùng hấp dẫn</span></span></span></span></strong></span></h2>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Không chỉ nổi bật về ngoại hình, tính năng mà điện thoại HTC U12+ còn thu hút người dùng bởi mức giá thành vô cùng ưu đãi, nhiều nhà phân phối còn đưa ra các chính sách khuyến mãi và bảo hành hậu hĩnh cho khách hàng. Trong thời kỳ mới ra mắt, U12 Plus có giá từ 18 đến 20 triệu. Mức giá này được đánh giá là hoàn toàn phù hợp. Tuy nhiên, sau 1 năm ra mắt, giá của điện thoại HTC U12 Plus đã giảm xuống một cách đáng kể, phù hợp với nhiều đối tượng khách hàng hơn.</span></span></span></span></p>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Có sự chênh lệch về giá cả giữa điện thoại U12 Plus có bộ nhớ 64GB và 128GB. Mặc dù vậy, điều này không làm ảnh hưởng quá nhiều đến quyết định lựa chọn mẫu sản phẩm nào của U12+, quan trọng hơn cả vẫn là nhu cầu sử dụng của người dùng.</span></span></span></span></p>
# <p style="text-align: center;"><img data-thumb="original" original-height="2863" original-width="3816" src="//bizweb.dktcdn.net/100/168/366/files/img-20190910-080717.jpg?v=1576651483364" style="width: 900px; height: 675px;"/></p>
# <p align="center" style="text-align:center"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><i><span style="line-height:150%">Điện thoại HTC U12+ là sự lựa chọn sáng giá cho người tiêu dùng</span></i></span></span></span></p>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Kết luận: Xét cả về các tính năng, cũng như giá cả, điện thoại U12+ là sự lựa chọn hoàn hảo cho người tiêu dùng. Mặc dù, mẫu điện thoại này vẫn còn tồn tại những nhược điểm nhưng so với các ưu điểm, chúng hoàn toàn xứng đáng trở thành một trong những mẫu điện thoại bán chạy nhất trong năm 2018. Đến năm 2019, mặc dù, trên thị trường xuất hiện các dòng sản phẩm mới nhưng U12 Plus vẫn giữ được vị trí tốt nhất trong lòng người tiêu dùng. Mong rằng, đối với các phiên bản sau, nhà sản xuất HTC sẽ có những bước cải tiến mới để tiếp tục mang đến các sản phẩm tốt nhất cho “người hâm mộ”.</span></span></span></span></p>
# <h2><span style="font-size:16px;"><strong><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="color:#4f81bd"><span style="line-height:150%">7. Mua điện thoại HTC U12+ ở đâu?</span></span></span></span></strong></span></h2>
# <p style="text-align:justify"><span style="font-size:16px;"><span style="font-family:Arial,Helvetica,sans-serif;"><span style="line-height:150%"><span style="line-height:150%">Không quá khó để người tiêu dùng có thể lựa chọn cho mình địa chỉ mua HTC U12+ nhưng để có được sản phẩm đảm bảo về chất lượng cũng như giá cả và chăm sóc hậu mãi thì người mua hàng cần tìm đến các nhà phân phối uy tín và worldphone.vn là một trong những gợi ý dành cho bạn.</span></span></span></span></p>
# <p style="text-align: center;"><img data-thumb="original" original-height="1320" original-width="1760" src="//bizweb.dktcdn.net/100/168/366/files/img-20190910-080421.jpg?v=1576651548379" style="width: 900px; height: 675px;"/></p>
# ...
# 												$cartDesktop = $('.count_item_pr'),
# 												$cartDesktopList = $('.cart-counter-list'),
# 												$cartPopup = $('.cart-popup-count');
# 											switch(data.item_count){
# 												case 0:
# 													$cartMobile.text('0');
# 													$cartDesktop.text('0');
# 													$cartDesktopList.text('0');
# 													$cartPopup.text('0');
# 													break;
# 												case 1:
# 													$cartMobile.text('1');
# 													$cartDesktop.text('1');
# 													$cartDesktopList.text('1');
# 													$cartPopup.text('1');
# 													break;
# 												default:
# 													$cartMobile.text(data.item_count);
# 													$cartDesktop.text(data.item_count);
# 													$cartDesktopList.text(data.item_count);
# 													$cartPopup.text(data.item_count);
# 													break;
# 											}
# 											$('.top-cart-content .top-subtotal .price, aside.sidebar .block-cart .subtotal .price, .popup-total .total-price').html($cartPrice);
# 											$('.popup-total .total-price').html($cartPrice);
# 											$('.cart-collaterals .totals_price').html($cartPrice);
# 											$('.header-cart-price .totals_price_mobile').html($cartPrice);
# 											$('.cartCount, .cart-products-count').html(data.item_count);
# 										}
# 										Bizweb.onCartUpdate = function(cart) {
# 											Bizweb.updateCartFromForm(cart, '.mini-products-list');
# 											Bizweb.updateCartPopupForm(cart, '#popup-cart-desktop .tbody-popup');
#
# 										};
# 										Bizweb.onCartUpdateClick = function(cart, variantId) {
# 											jQuery.each(cart, function(key, value) {
# 												if (key === 'items') {
# 													jQuery.each(value, function(i, item) {
# 														if(item.variant_id == variantId){
# 															$('.productid-'+variantId).find('.pricechange').html(Bizweb.formatMoney(item.price, "{{amount_no_decimals_with_comma_separator}}₫"));
# 															$('.productid-'+variantId).find('.cart-price span.price').html(Bizweb.formatMoney(item.price * item.quantity, "{{amount_no_decimals_with_comma_separator}}₫"));
# 															$('.productid-'+variantId).find('.items-count').prop("disabled", false);
# 															$('.productid-'+variantId +' .number-sidebar').val(item.quantity);
# 															if(item.quantity == '1'){
# 																$('.productid-'+variantId).find('.items-count.btn-minus').prop("disabled", true);
# 															}
# 														}
# 													});
# 												}
# 											});
# 											updateCartDesc(cart);
# 										}
# 										Bizweb.onCartRemoveClick = function(cart, variantId) {
# 											jQuery.each(cart, function(key, value) {
# 												if (key === 'items') {
# 													jQuery.each(value, function(i, item) {
# 														if(item.variant_id == variantId){
# 															$('.productid-'+variantId).remove();
# 														}
# 													});
# 												}
# 											});
# 											updateCartDesc(cart);
# 										}
# 										$(window).ready(function(){
# 											$.ajax({
# 												type: 'GET',
# 												url: '/cart.js',
# 												async: false,
# 												cache: false,
# 												dataType: 'json',
# 												success: function (cart){
# 													Bizweb.updateCartFromForm(cart, '.mini-products-list');
# 													Bizweb.updateCartPopupForm(cart, '#popup-cart-desktop .tbody-popup');
#
# 												}
# 											});
# 										});
# </script>
# <div class="modal fade" id="popup-cart" role="dialog">
# <div class="clearfix" id="popup-cart-desktop">
# <div class="title-popup-cart"><i aria-hidden="true" class="ion ion-md-notifications-outline"></i> Bạn đã thêm <span class="cart-popup-name"></span> vào giỏ hàng</div>
# <div class="title-quantity-popup"><a href="/cart" title="Giỏ hàng của bạn">Giỏ hàng của bạn có <span class="cart-popup-count"></span> sản phẩm</a></div>
# <div class="content-popup-cart clearfix">
# <div class="thead-popup"><div class="text-left" style="width: 55%;">Sản phẩm</div><div class="text-center" style="width: 15%;">Đơn giá</div><div class="text-center" style="width: 15%;">Số lượng</div><div class="text-center" style="width: 15%;">Thành tiền</div></div>
# <div class="tbody-popup"></div>
# <div class="tfoot-popup">
# <div class="tfoot-popup-1 clearfix">
# <div class="pull-left popupcon"><a class="button btn-continue" onclick="$('#popup-cart').modal('hide');" title="Tiếp tục mua hàng"><span><span><i aria-hidden="true" class="fa fa-caret-left"></i> Tiếp tục mua hàng</span></span></a></div>
# <div class="pull-right popup-total"><p>Thành tiền: <span class="total-price"></span></p></div>
# </div>
# <div class="tfoot-popup-2 clearfix"><a class="button btn-proceed-checkout" href="/checkout" title="Thanh toán đơn hàng"><span>Thanh toán đơn hàng</span></a></div>
# </div>
# </div>
# <a class="quickview-close close-window" href="javascript:;" onclick="$('#popup-cart').modal('hide');" title="Đóng"><i class="fa fa-times"></i></a>
# </div>
# </div>
# <div class="modal fade" id="myModal" role="dialog"></div>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/appear.js?1654105636388" type="text/javascript"></script>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/cs.script.js?1654105636388" type="text/javascript"></script>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/main.js?1654105636388" type="text/javascript"></script>
# <link href="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/lightbox.css?1654105636388" rel="stylesheet" type="text/css"/>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/jquery.elevatezoom308.min.js?1654105636388" type="text/javascript"></script>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/jquery.prettyphoto.min005e.js?1654105636388" type="text/javascript"></script>
# <script src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/jquery.prettyphoto.init.min367a.js?1654105636388" type="text/javascript"></script>
# <div class="backdrop__body-backdrop___1rvky"></div>
# <div class="mobile-main-menu">
# <div class="drawer-header">
# <a href="account/login">
# <div class="drawer-header--auth">
# <div class="_object"><img alt="WORLDPHONE.VN" src="//bizweb.dktcdn.net/100/168/366/themes/713148/assets/user.svg?1654105636388"/></div>
# <div class="_body">ĐĂNG NHẬP<br/>Nhận nhiều ưu đãi hơn</div>
# </div>
# </a>
# </div>
# <ul class="ul-first-menu">
# <li><a href="/account/login" title="Đăng nhập">Đăng nhập</a></li>
# <li><a href="/account/register" title="Đăng ký">Đăng ký</a></li>
# </ul>
# <div class="la-scroll-fix-infor-user">
# <div class="la-nav-menu-items">
# <div class="la-title-nav-items"><strong>Danh mục</strong></div>
# <ul class="la-nav-list-items">
# <li class="ng-scope"><a href="/" title="TRANG CHỦ">TRANG CHỦ</a></li>
# <li class="ng-scope ng-has-child1">
# <a href="/dien-thoai-blackberry" title="ĐIỆN THOẠI BLACKBERRY">ĐIỆN THOẠI BLACKBERRY <i aria-hidden="true" class="fa fa-plus fa1"></i></a>
# <ul class="ul-has-child1">
# <li class="ng-scope"><a href="/blackberry-os" title="BLACKBERRY OS">BLACKBERRY OS</a></li>
# <li class="ng-scope"><a href="/blackberry-10" title="BLACKBERRY 10">BLACKBERRY 10</a></li>
# <li class="ng-scope"><a href="/blackberry-android" title="BLACKBERRY ANDROID">BLACKBERRY ANDROID</a></li>
# <li class="ng-scope"><a href="/blackberry-cao-cap" title="BLACKBERRY CAO CẤP">BLACKBERRY CAO CẤP</a></li>
# </ul>
# </li>
# <li class="ng-scope ng-has-child1">
# <a href="/dien-thoai-android" title="ĐIỆN THOẠI ANDROID">ĐIỆN THOẠI ANDROID <i aria-hidden="true" class="fa fa-plus fa1"></i></a>
# <ul class="ul-has-child1">
# <li class="ng-scope"><a href="/htc" title="ĐIỆN THOẠI HTC">ĐIỆN THOẠI HTC</a></li>
# <li class="ng-scope"><a href="/lg" title="ĐIỆN THOẠI LG">ĐIỆN THOẠI LG</a></li>
# <li class="ng-scope"><a href="/samsung" title="ĐIỆN THOẠI SAMSUNG">ĐIỆN THOẠI SAMSUNG</a></li>
# <li class="ng-scope"><a href="/google" title="ĐIỆN THOẠI GOOGLE">ĐIỆN THOẠI GOOGLE</a></li>
# <li class="ng-scope"><a href="/motorola" title="ĐIỆN THOẠI MOTOROLA">ĐIỆN THOẠI MOTOROLA</a></li>
# <li class="ng-scope"><a href="/dien-thoai-sony" title="ĐIỆN THOẠI SONY">ĐIỆN THOẠI SONY</a></li>
# <li class="ng-scope"><a href="/dien-thoai-2-sim" title="ĐIỆN THOẠI 2 SIM">ĐIỆN THOẠI 2 SIM</a></li>
# </ul>
# </li>
# <li class="ng-scope ng-has-child1">
# <a href="/iphone" title="APPLE IPHONE">APPLE IPHONE <i aria-hidden="true" class="fa fa-plus fa1"></i></a>
# <ul class="ul-has-child1">
# <li class="ng-scope"><a href="/iphone-12-12-pro-12-pro-max" title="IPHONE 12 | 12 PRO | 12 PRO MAX">IPHONE 12 | 12 PRO | 12 PRO MAX</a></li>
# <li class="ng-scope"><a href="/iphone-11-11-pro-11-pro-max" title="IPHONE 11 | 11 PRO | 11 PRO MAX">IPHONE 11 | 11 PRO | 11 PRO MAX</a></li>
# <li class="ng-scope"><a href="/iphone-xs-xs-max" title="IPHONE XS | XS MAX">IPHONE XS | XS MAX</a></li>
# <li class="ng-scope"><a href="/iphone-x-iphone-xr" title="IPHONE X | XR">IPHONE X | XR</a></li>
# <li class="ng-scope"><a href="/iphone-8-8-plus" title="IPHONE 8 | 8 PLUS">IPHONE 8 | 8 PLUS</a></li>
# <li class="ng-scope"><a href="/iphone-7-7-plus" title="IPHONE 7 | 7 PLUS">IPHONE 7 | 7 PLUS</a></li>
# <li class="ng-scope"><a href="/ipad" title="IPAD">IPAD</a></li>
# <li class="ng-scope"><a href="/iphone-13-13-pro-13-pro-max" title="iPhone 13 | 13 Pro | 13 Pro Max">iPhone 13 | 13 Pro | 13 Pro Max</a></li>
# </ul>
# </li>
# <li class="ng-scope"><a href="/khuyen-mai" title="KHUYẾN MÃI">KHUYẾN MÃI</a></li>
# <li class="ng-scope ng-has-child1">
# <a href="/linh-phu-kien-chinh-hang" title="LINH PHỤ KIỆN">LINH PHỤ KIỆN <i aria-hidden="true" class="fa fa-plus fa1"></i></a>
# <ul class="ul-has-child1">
# <li class="ng-scope"><a href="/bao-gia" title="BÁO GIÁ LINH KIỆN">BÁO GIÁ LINH KIỆN</a></li>
# <li class="ng-scope"><a href="/sac-cap" title="SẠC - CÁP">SẠC - CÁP</a></li>
# <li class="ng-scope"><a href="/tai-nghe-loa" title="TAI NGHE - LOA">TAI NGHE - LOA</a></li>
# <li class="ng-scope"><a href="/bao-da-op-lung" title="BAO DA - ỐP LƯNG">BAO DA - ỐP LƯNG</a></li>
# <li class="ng-scope"><a href="/tai-nghe" title="THẺ NHỚ">THẺ NHỚ</a></li>
# <li class="ng-scope ng-has-child2"><a href="/linh-kien-blackberry" title="LINH KIỆN BLACKBERRY">LINH KIỆN BLACKBERRY <i aria-hidden="true" class="fa fa-plus fa2"></i></a><ul class="ul-has-child2"><li class="ng-scope"><a href="/man-hinh-blackberry" title="MÀN HÌNH BLACKBERRY">MÀN HÌNH BLACKBERRY</a></li><li class="ng-scope"><a href="/ban-phim-blackberry" title="BÀN PHÍM BLACKBERRY">BÀN PHÍM BLACKBERRY</a></li><li class="ng-scope"><a href="/camera-blackberry" title="CAMERA BLACKBERRY">CAMERA BLACKBERRY</a></li><li class="ng-scope"><a href="/bo-vo-blackberry" title="BỘ VỎ BLACKBERRY">BỘ VỎ BLACKBERRY</a></li><li class="ng-scope"><a href="/pin" title="PIN">PIN</a></li></ul></li>
# <li class="ng-scope ng-has-child2"><a href="/linh-kien-google" title="LINH KIỆN GOOGLE">LINH KIỆN GOOGLE <i aria-hidden="true" class="fa fa-plus fa2"></i></a><ul class="ul-has-child2"><li class="ng-scope"><a href="/linh-kien-google-pixel-pixel-xl" title="LINH KIỆN GOOGLE PIXEL/PIXEL XL">LINH KIỆN GOOGLE PIXEL/PIXEL XL</a></li><li class="ng-scope"><a href="/linh-kien-google-pixel-2-pixel-2-xl" title="LINH KIỆN GOOGLE PIXEL 2/PIXEL 2 XL">LINH KIỆN GOOGLE PIXEL 2/PIXEL 2 XL</a></li><li class="ng-scope"><a href="/linh-kien-google-pixel-3-3-xl-3a-3a-xl" title="LINH KIỆN GOOGLE PIXEL 3/3 XL/3a/3a XL">LINH KIỆN GOOGLE PIXEL 3/3 XL/3a/3a XL</a></li><li class="ng-scope"><a href="/linh-kien-google-pixel-4-4-xl-4a" title="LINH KIỆN GOOGLE PIXEL 4/4 XL/4a">LINH KIỆN GOOGLE PIXEL 4/4 XL/4a</a></li></ul></li>
# </ul>
# </li>
# <li class="ng-scope"><a href="/tin-cong-nghe" title="NEWS &amp; TIPS">NEWS &amp; TIPS</a></li>
# <li class="ng-scope ng-has-child1">
# <a href="/do-choi-cong-nghe" title="ĐỒ CHƠI SỐ">ĐỒ CHƠI SỐ <i aria-hidden="true" class="fa fa-plus fa1"></i></a>
# <ul class="ul-has-child1">
# <li class="ng-scope"><a href="/robot-hut-bui" title="ROBOT HÚT BỤI">ROBOT HÚT BỤI</a></li>
# <li class="ng-scope"><a href="/dong-ho-thong-minh" title="ĐỒNG HỒ THÔNG MINH">ĐỒNG HỒ THÔNG MINH</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <ul class="mobile-support">
# <li><div class="drawer-text-support">HỖ TRỢ</div></li>
# <li><i aria-hidden="true" class="fa fa-phone"></i> HOTLINE: <a href="tel:1900.6729" title="1900.6729">1900.6729</a></li>
# <li><i aria-hidden="true" class="fa fa-envelope"></i> EMAIL: <a href="mailto:cskh.worldphone.vn@gmail.com" title="cskh.worldphone.vn@gmail.com">cskh.worldphone.vn@gmail.com</a></li>
# </ul>
# </div>
# <script type="text/javascript">
# 			WebFontConfig = {
# 				custom: {
# 					families: ['FontAwesome'],
# 					urls: ['https://use.fontawesome.com/releases/v5.7.2/css/all.css']
# 				}
# 			};
# 			(function() {
# 				var wf = document.createElement('script');
# 				wf.src = 'https://ajax.googleapis.com/ajax/libs/webfont/1/webfont.js';
# 				wf.type = 'text/javascript';
# 				wf.async = 'true';
# 				var s = document.getElementsByTagName('script')[0];
# 				s.parentNode.insertBefore(wf, s);
# 			})();
# 		</script>
# <div class="support-cart mini-cart hidden-sm hidden-xs">
# <a class="btn-support-cart" href="/cart">
# <svg height="30px" style="enable-background:new 0 0 435.104 435.104;" version="1.1" viewbox="0 0 435.104 435.104" width="30px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <circle class="active-path" cx="154.112" cy="377.684" data-old_color="#Ffffff" data-original="#000000" fill="#FFFFFF" r="52.736"></circle>
# <path class="active-path" d="M323.072,324.436L323.072,324.436c-29.267-2.88-55.327,18.51-58.207,47.777c-2.88,29.267,18.51,55.327,47.777,58.207     c3.468,0.341,6.962,0.341,10.43,0c29.267-2.88,50.657-28.94,47.777-58.207C368.361,346.928,348.356,326.924,323.072,324.436z" data-old_color="#F8F8F8" data-original="#000000" fill="#FFFFFF"></path>
# <path class="active-path" d="M431.616,123.732c-2.62-3.923-7.059-6.239-11.776-6.144h-58.368v-1.024C361.476,54.637,311.278,4.432,249.351,4.428     C187.425,4.424,137.22,54.622,137.216,116.549c0,0.005,0,0.01,0,0.015v1.024h-43.52L78.848,50.004     C77.199,43.129,71.07,38.268,64,38.228H0v30.72h51.712l47.616,218.624c1.257,7.188,7.552,12.397,14.848,12.288h267.776     c7.07-0.041,13.198-4.901,14.848-11.776l37.888-151.552C435.799,132.019,434.654,127.248,431.616,123.732z M249.344,197.972     c-44.96,0-81.408-36.448-81.408-81.408s36.448-81.408,81.408-81.408s81.408,36.448,81.408,81.408     C330.473,161.408,294.188,197.692,249.344,197.972z" data-old_color="#F8F8F8" data-original="#000000" fill="#FFFFFF"></path>
# <path class="active-path" d="M237.056,118.1l-28.16-28.672l-22.016,21.504l38.912,39.424c2.836,2.894,6.7,4.55,10.752,4.608     c3.999,0.196,7.897-1.289,10.752-4.096l64.512-60.928l-20.992-22.528L237.056,118.1z" data-old_color="#F8F8F8" data-original="#000000" fill="#FFFFFF"></path>
# </g>
# </svg>
# <div class="animated infinite zoomIn kenit-alo-circle"></div>
# <div class="animated infinite pulse kenit-alo-circle-fill"></div>
# <span class="cnt crl-bg count_item_pr">0</span>
# </a>
# <div class="top-cart-content hidden-md hidden-sm hidden-xs">
# <ul class="mini-products-list count_li" id="cart-sidebar">
# <li class="list-item"><ul></ul></li>
# <li class="action">
# <ul>
# <li class="li-fix-1"><div class="top-subtotal">Tổng tiền thanh toán:<span class="price"></span></div></li>
# <li class="li-fix-2">
# <div class="actions clearfix">
# <a class="btn btn-primary" href="/cart">Giỏ hàng</a>
# <a class="btn btn-checkout btn-gray" href="/checkout">Thanh toán</a>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="" id="menu-overlay"></div>
# <div id="tawk_57d22e31e90e076865003609"></div>
# <input name="_promotionbar_params" type="hidden" value="worldphone.mysapo.net"/><input name="_promotionbar_storename" type="hidden" value="WORLDPHONE.VN"/></body>
# <!--Start of Tawk.to Script-->
# <script type="text/javascript">
# 		var Tawk_API=Tawk_API||{}, Tawk_LoadStart=new Date();
# 		(function(){
# 			var s1=document.createElement("script"),s0=document.getElementsByTagName("script")[0];
# 			s1.async=true;
# 			s1.src='https://embed.tawk.to/57d22e31e90e076865003609/default';
# 			s1.charset='UTF-8';
# 			s1.setAttribute('crossorigin','*');
# 			s0.parentNode.insertBefore(s1,s0);
# 		})();
# 	</script>
# <!--End of Tawk.to Script-->
# </html>

# %%
phone_name = soup.find(class_="title-head")

# %%
phone_name.get_text()
# Out:
# 'HTC U12 Plus (Brandnew - Seabox)'

# %%
price = soup.select(".price.product-price")

# %%
price[0].get_text()
# Out:
# '8.690.000₫'

# %%
all_info = soup.find(class_="modal-body")

# %%
phone_details = {}
for li in all_info.find_all("li"):
    info = li.get_text()
    info = info.replace('\xa0',' ')
    info_list = info.split(': ')
    if len(info_list) == 2:
        phone_details[info_list[0]] = info_list[1]
# Out:
# ['Màn hình']
# ['Công nghệ màn hình', 'Super LCD 6']
# ['Độ phân giải', '2K+ (1440 x 2880 Pixels)']
# ['Màn hình rộng', '6.0"']
# ['Mặt kính cảm ứng', 'Corning Gorilla Glass 5']
# ['Camera sau']
# ['Độ phân giải', '16 MP và 12 MP (2 camera)']
# ['Quay phim', 'Quay phim HD 720p@24fps, Quay phim FullHD 1080p@30fps, Quay phim FullHD 1080p@60fps, Quay phim FullHD 1080p@240fps, Quay phim 4K 2160p@60fps']
# ['Đèn Flash', 'Đèn LED 2 tông màu']
# ['Chụp ảnh nâng cao', 'Lấy nét bằng laser, Chụp ảnh xóa phông, Chế độ Slow Motion, Tự động lấy nét, Chạm lấy nét, Nhận diện khuôn mặt, HDR, Panorama, Chống rung quang học (OIS)']
# ['Camera trước']
# ['Độ phân giải', '8 MP và 8 MP (2 camera)']
# ['Videocall', 'Hỗ trợ VideoCall thông qua ứng dụng']
# ['Thông tin khác', 'Nhận diện khuôn mặt, Chế độ làm đẹp, Quay video Full HD, Tự động lấy nét, Camera góc rộng, Selfie ngược sáng HDR, Panorama, Camera kép']
# ['Hệ điều hành - CPU']
# ['Hệ điều hành', 'Android 8.0 (Oreo)']
# ['Chipset (hãng SX CPU)', 'Snapdragon 845 8 nhân']
# ['Tốc độ CPU', '4 nhân 2.8 GHz & 4 nhân 1.7 GHz']
# ['Chip đồ họa (GPU)', 'Adreno 630']
# ['Bộ nhớ & Lưu trữ']
# ['RAM', '6GB']
# ['Bộ nhớ trong', '64/128 GB']
# ['Bộ nhớ còn lại (khả dụng)', 'Đang cập nhật']
# ['Thẻ nhớ ngoài', 'MicroSD, hỗ trợ tối đa 2 TB']
# ['Kết nối']
# ['Mạng di động', 'Hỗ trợ 4G']
# ['SIM', '2 SIM Nano']
# ['Wifi', 'Wi-Fi 802.11 a/b/g/n/ac, Dual-band, DLNA, Wi-Fi Direct, Wi-Fi hotspot']
# ['GPS', 'BDS, A-GPS, GLONASS']
# ['Bluetooth', 'apt-X, A2DP, LE, v5.0']
# ['Cổng kết nối/sạc', 'USB Type-C']
# ['Jack tai nghe', '3.5 mm']
# ['Kết nối khác', 'NFC, HTC Connect, USB 3.1, OTG']
# ['Thiết kế & Trọng lượng']
# ['Thiết kế', 'Nguyên khối']
# ['Chất liệu', 'Khung kim loại + mặt kính cường lực']
# ['Kích thước', 'Dài 156.6 mm - Ngang 73.9 mm - Dày 8.7 mm']
# ['Trọng lượng', '188 g']
# ['Thông tin pin & Sạc']
# ['Dung lượng pin', '3500 mAh']
# ['Loại pin', 'Pin chuẩn Li-Ion']
# ['Công nghệ pin', 'Tiết kiệm pin, Sạc nhanh Quick Charge 3.0']
# ['Tiện ích']
# ['Bảo mật nâng cao', 'Mở khóa bằng vân tay, Mở khóa bằng khuôn mặt']
# ['Tính năng đặc biệt:']
# ['HTC BoomSound™\nChuẩn Kháng nước, Chuẩn kháng bụi\nSạc pin nhanh\nMặt kính 2.5D\nCông nghệ cảm ứng cạnh viền EDGE SENSE']
# ['Ghi âm', 'Có']
# ['Radio', 'Không']
# ['Xem phim', '3GP, MP4, AVI, WMV, H.263, H.264(MPEG4-AVC)']
# ['Nghe nhạc', 'AMR, Midi, MP3, WAV, WMA9, WMA, AAC, OGG, FLAC']
# ['Thông tin khác']
# ['Thời điểm ra mắt', 'Đang cập nhật']

# %%
def get_all_data(root="https://worldphone.vn", names=['htc','lg','samsung','google','motorola', 'dien-thoai-sony', 'dien-thoai-2-sim']):
    all_data = []
    for name in names:
        mobile_link = root + '/' + name
        r = requests.get(mobile_link)
        soup = bs(r.content)
        all_phones = soup.find_all(class_="news-item-products")
        if len(all_phones) > 0:
            for phone in all_phones:
                phone_info = {}
                new_link = root + phone.a['href']
                r = requests.get(new_link)
                soup = bs(r.content)
                phone_name = soup.find(class_="title-head")
                phone_info["Tên điện thoại"] = phone_name.get_text()
                price = soup.select(".price.product-price")
                if len(price) > 0:
                    phone_info['Giá'] = price[0].get_text()
                all_info = soup.find(class_="modal-body")
                if all_info is not None:
                    for li in all_info.find_all("li"):
                        info = li.get_text()
                        info = info.replace('\xa0',' ')
                        info_list = info.split(': ')
                        if len(info_list) == 2:
                            phone_info[info_list[0]] = info_list[1]
                    all_data.append(phone_info)
    return all_data

# %%
all_data = get_all_data()

# %%
len(all_data)
# Out:
# 92

# %%
all_data_2 = get_all_data(names=["iphone-12-12-pro-12-pro-max",
                                "iphone-xs-xs-max",
                                "iphone-11-11-pro-11-pro-max",
                                "iphone-x-iphone-xr",
                                "iphone-8-8-plus",
                                "iphone-7-7-plus"])

# %%
len(all_data_2)
# Out:
# 44

# %%
all_phones = all_data + all_data_2

# %%
len(all_phones)
# Out:
# 136

# %%
import json
with open("worldphone.json", "w", encoding='utf-8') as outfile:
        json.dump(all_phones, outfile, ensure_ascii=False, indent=2)
