# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import time

def crawl_item(url_input):
  try:
    url = 'https://mediamart.vn' + url_input
    headers = {
      'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:73.0) Gecko/20100101 Firefox/73.0',
      'X-Requested-With': 'XMLHttpRequest',
    }    
    r = requests.get(url, headers=headers)
    data = {}
    soup = BeautifulSoup(r.content.decode('utf-8', 'ignore'), 'html.parser')
    data["name"] = soup.find_all("div", class_="pdetail-name")[0].text.split('\n')[1]
    x=0
    key=''
    for tr in soup.find_all('td'):
      if(len(tr.get_text()) > 0):
        if(x%2)==0:
          key=tr.get_text()
        else:
          data[key]=tr.get_text()
        x=x+1
    data["price"] = soup.find("div", class_="pdetail-price-box").text
    time.sleep(10)
    return data
  except:
    pass

def crawl_mediaMart():
  data=[]
  df = pd.read_csv('mediamart.csv') #duong dan file csv
  url = 'https://mediamart.vn/smartphones'
  headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:73.0) Gecko/20100101 Firefox/73.0',
    'X-Requested-With': 'XMLHttpRequest',
  }    
  r = requests.get(url, headers=headers)
  soup = BeautifulSoup(r.content, 'html.parser')
  for div in soup.find_all("div", class_="col-6 col-md-3 col-lg-3"):
    data.append(crawl_item(div.find("a", href=True)['href']))
  pd.concat([pd.DataFrame(data), df], ignore_index=True)
  return df

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %%
url = 'https://mediamart.vn/smartphones/apple-iphone-11-64gb-white'
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:73.0) Gecko/20100101 Firefox/73.0',
    'X-Requested-With': 'XMLHttpRequest',
}    
r = requests.get(url, headers=headers)
data = {}
soup = BeautifulSoup(r.content.decode('utf-8', 'ignore'), 'html.parser')

data["name"] = soup.find_all("div", class_="pdetail-name")[0].text.split('\n')[1]
x=0
key=''
for tr in soup.find_all('td'):
  if(len(tr.get_text()) > 0):
    if(x%2)==0:
      key=tr.get_text()
    else:
      data[key]=tr.get_text()
    x=x+1
data["price"] = soup.find("div", class_="pdetail-price-box").text
print(data)
jsonString = json.dumps(data, ensure_ascii=False)
jsonFile = open("/content/drive/MyDrive/Colab Notebooks/Media_mart/1.json", "w")
jsonFile.write(jsonString)
jsonFile.close()
# Out:
# {'name': 'Apple Iphone 11 64G White', 'Thương hiệu': '\nApple\n', 'Mã sản phẩm': '\nIphone 11\n', 'Hộp máy gồm': 'Sách hướng dẫnCáp Lightning - Type CCây lấy sim', 'Công nghệ màn hình': 'Retina', 'Độ phân giải': '1792 x 828 pixels', 'Màn hình': '6.1 inch', 'Cảm ứng': 'Đa điểm', 'Mặt kính cảm ứng': 'Kính cường lực', 'Camera sau': 'Kép 12MP + 12MP', 'Quay phim': 'Có', 'Đèn Flash': 'Có', 'Chụp ảnh nâng cao': 'Chụp chế độ ban đêmChạm lấy nétChế độ ánh sáng yếuTự động lấy nét', 'Camera trước': '12 MP', 'Videocall': 'Có', 'Thông tin khác': 'Tự động lấy nétNhận diện khuôn mặt', 'Hệ điều hành': 'iOS13', 'CPU': 'A13 Bionic', 'Số nhân': '6 nhân', 'Tốc độ tối đa': '2.66 GHz', 'RAM': '4 GB', 'Bộ nhớ': '64 GB', 'Băng tần 2G': 'Có', 'Băng tần 3G': 'Có', 'Hỗ trợ 4G': 'Có hỗ trợ 4G', 'Số khe sim': '1 Nano SIM & 1 eSIM', 'Wifi': 'Có', 'GPS': 'Có', 'Bluetooth': 'Có', 'NFC': 'Có', 'Cổng kết nối/sạc': 'Lightning', 'Kết nối khác': 'NFC', 'Thiết kế': 'Nguyên khối', 'Chất liệu': 'Khung nhôm, mặt lưng kính', 'Dung lượng pin': '3110 mAh', 'Tính năng đặc biệt': 'Bảo mật vân tayMở khóa bằng khuôn mặt', 'Xem phim': 'Có', 'Nghe nhạc': 'Có', 'Chức năng khác': 'Mặt kính 2.5DMở khóa bằng vân tayMở khóa bằng khuôn mặtSạc pin nhanh', 'Bảo hành': '\n12 tháng\n', 'price': '\n11.990.000 ₫\n21.990.000 ₫\n\r\n                Tiết kiệm (45%)\r\n            \n'}

# %%
import requests
from bs4 import BeautifulSoup
import json
f = open("/content/mediamart.txt", "r")
soup = BeautifulSoup(f.read(), 'html.parser')

# %%
soup
# Out:
# <html class="p-product p-cate cookies webp webp-alpha webp-animation webp-lossless mdl-js de-t" lang="vi-vn"><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><title>Điện thoại di động giá rẻ | Smartphone chính hãng tốt nhất</title><meta content="Điện thoại di động giá rẻ | Smartphone chính hãng tốt nhất" name="title"/><meta content="Điện thoại giá rẻ,điện thoại iPhone,điện thoại Samsung,điện thoại Nokia,điện thoại Oppo,điện thoại Sony,Điện thoại di động GIÁ RẺ,điện thoại thông minh,Smartphone giá rẻ,IPHONE 6S,iPhone 7,iPhone 7 Plus,SAMSUNG GALAXY S8,Galaxy Note 8,Xperia XZs,điện thoại giá tốt,điện thoại trả góp,ĐTDĐ" name="keywords"/><meta content="Mua bán Điện thoại iPhone Samsung Nokia Sony Oppo chính hãng giá rẻ, smartphone thiết kế đẹp cấu hình mạnh loại tốt nhất đổi trả miễn phí 30 ngày, trả góp 0%" name="description"/><link href="https://mediamart.vn/rssfeed/smartphones" rel="alternate" title="Điện thoại di động giá rẻ | Smartphone chính hãng tốt nhất » Feed" type="application/rss+xml"/><link href="https://mediamart.vn/smartphones" rel="canonical"/><meta content="968" http-equiv="REFRESH"/><meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/><meta content="MediaMart.Vn" name="copyright"/><meta content="MediaMart.Vn" name="author"/><meta content="MediaMart.Vn" name="GENERATOR"/><meta content="General" http-equiv="audience"/><meta content="Document" name="resource-type"/><meta content="Global" name="distribution"/><meta content="1 days" name="revisit-after"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="vi" http-equiv="content-language"/><meta content="" property="fb:app_id"/><meta content="https://mediamart.vn/smartphones" property="og:site_name"/><meta content="vi_VN" property="og:locale"/><meta content="https://mediamart.vn/smartphones" itemprop="url" property="og:url"/><meta content="Điện thoại di động giá rẻ | Smartphone chính hãng tốt nhất" property="og:title"/><meta content="Mua bán Điện thoại iPhone Samsung Nokia Sony Oppo chính hãng giá rẻ, smartphone thiết kế đẹp cấu hình mạnh loại tốt nhất đổi trả miễn phí 30 ngày, trả góp 0%" property="og:description"/><meta content="https://cdn.mediamart.vn/images/category/smartphones_45fc858c.png" property="og:image"/><meta content="Điện thoại di động giá rẻ | Smartphone chính hãng tốt nhất" property="og:image:alt"/><meta content="image/jpeg" property="og:image:type"/><meta content="600" property="og:image:width"/><meta content="315" property="og:image:height"/><link href="https://cdn.mediamart.vn/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="" rel="author"/><link href="" rel="publisher"/><script async="" src="https://storage.googleapis.com/sbz/app.js?accid=acorexjjvxacyls251bd"></script><script async="" src="https://widget.subiz.net/sbz/app.js?accid=acorexjjvxacyls251bd"></script><script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-QH0RBCCF60&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="//deqik.com/tag/corejs/ATMQ85OBNVVLX.js"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="application/ld+json">{"@context":"https://schema.org","@type":"WebSite","name":"MediaMart - Hệ thống Siêu thị Điện máy hàng đầu Việt Nam","alternateName":"MediaMart - Hệ thống Siêu thị Điện máy hàng đầu Việt Nam","url":"https://mediamart.vn","potenti ...
# /* sc-component-id: sc-keyframes-FiaaB */
# @-webkit-keyframes FiaaB{100%{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}@keyframes FiaaB{100%{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}
# /* sc-component-id: sc-keyframes-gTcftA */
# @-webkit-keyframes gTcftA{10%,90%{-webkit-transform:translate3d(-1px,0,0);-ms-transform:translate3d(-1px,0,0);transform:translate3d(-1px,0,0);}20%,80%{-webkit-transform:translate3d(2px,0,0);-ms-transform:translate3d(2px,0,0);transform:translate3d(2px,0,0);}30%,50%,70%{-webkit-transform:translate3d(-4px,0,0);-ms-transform:translate3d(-4px,0,0);transform:translate3d(-4px,0,0);}40%,60%{-webkit-transform:translate3d(4px,0,0);-ms-transform:translate3d(4px,0,0);transform:translate3d(4px,0,0);}}@keyframes gTcftA{10%,90%{-webkit-transform:translate3d(-1px,0,0);-ms-transform:translate3d(-1px,0,0);transform:translate3d(-1px,0,0);}20%,80%{-webkit-transform:translate3d(2px,0,0);-ms-transform:translate3d(2px,0,0);transform:translate3d(2px,0,0);}30%,50%,70%{-webkit-transform:translate3d(-4px,0,0);-ms-transform:translate3d(-4px,0,0);transform:translate3d(-4px,0,0);}40%,60%{-webkit-transform:translate3d(4px,0,0);-ms-transform:translate3d(4px,0,0);transform:translate3d(4px,0,0);}}
# /* sc-component-id: sc-keyframes-caPIRE */
# @-webkit-keyframes caPIRE{0%{-webkit-transform:scale(.75);-ms-transform:scale(.75);transform:scale(.75);}20%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}40%{-webkit-transform:scale(.75);-ms-transform:scale(.75);transform:scale(.75);}60%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}80%{-webkit-transform:scale(.75);-ms-transform:scale(.75);transform:scale(.75);}100%{-webkit-transform:scale(.75);-ms-transform:scale(.75);transform:scale(.75);}}@keyframes caPIRE{0%{-webkit-transform:scale(.75);-ms-transform:scale(.75);transform:scale(.75);}20%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}40%{-webkit-transform:scale(.75);-ms-transform:scale(.75);transform:scale(.75);}60%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}80%{-webkit-transform:scale(.75);-ms-transform:scale(.75);transform:scale(.75);}100%{-webkit-transform:scale(.75);-ms-transform:scale(.75);transform:scale(.75);}}</style><style>@-webkit-keyframes swal2-show{0%{-webkit-transform:scale(.7);transform:scale(.7)}45%{-webkit-transform:scale(1.05);transform:scale(1.05)}80%{-webkit-transform:scale(.95);transform:scale(.95)}100%{-webkit-transform:scale(1);transform:scale(1)}}@keyframes swal2-show{0%{-webkit-transform:scale(.7);transform:scale(.7)}45%{-webkit-transform:scale(1.05);transform:scale(1.05)}80%{-webkit-transform:scale(.95);transform:scale(.95)}100%{-webkit-transform:scale(1);transform:scale(1)}}@-webkit-keyframes swal2-hide{0%{-webkit-transform:scale(1);transform:scale(1);opacity:1}100%{-webkit-transform:scale(.5);transform:scale(.5);opacity:0}}@keyframes swal2-hide{0%{-webkit-transform:scale(1);transform:scale(1);opacity:1}100%{-webkit-transform:scale(.5);transform:scale(.5);opacity:0}}@-webkit-keyframes swal2-animate-success-line-tip{0%{top:1.1875em;left:.0625em;width:0}54%{top:1.0625em;left:.125em;width:0}70%{top:2.1875em;left:-.375em;width:3.125em}84%{top:3em;left:1.3125em;width:1.0625em}100%{top:2.8125em;left:.875em;width:1.5625em}}@keyframes swal2-animate-success-line-tip{0%{top:1.1875em;left:.0625em;width:0}54%{top:1.0625em;left:.125em;width:0}70%{top:2.1875em;left:-.375em;width:3.125em}84%{top:3em;left:1.3125em;width:1.0625em}100%{top:2.8125em;left:.875em;width:1.5625em}}@-webkit-keyframes swal2-animate-success-line-long{0%{top:3.375em;right:2.875em;width:0}65%{top:3.375em;right:2.875em;width:0}84%{top:2.1875em;right:0;width:3.4375em}100%{top:2.375em;right:.5em;width:2.9375em}}@keyframes swal2-animate-success-line-long{0%{top:3.375em;right:2.875em;width:0}65%{top:3.375em;right:2.875em;width:0}84%{top:2.1875em;right:0;width:3.4375em}100%{top:2.375em;right:.5em;width:2.9375em}}@-webkit-keyframes swal2-rotate-success-circular-line{0%{-webkit-transform:rotate(-45deg);transform:rotate(-45deg)}5%{-webkit-transform:rotate(-45deg);transform:rotate(-45deg)}12%{-webkit-transform:rotate(-405deg);transform:rotate(-405deg)}100%{-webkit-transform:rotate(-405deg);transform:rotate(-405deg)}}@keyframes swal2-rotate-success-circular-line{0%{-webkit-transform:rotate(-45deg);transform:rotate(-45deg)}5%{-webkit-transform:rotate(-45deg);transform:rotate(-45deg)}12%{-webkit-transform:rotate(-405deg);transform:rotate(-405deg)}100%{-webkit-transform:rotate(-405deg);transform:rotate(-405deg)}}@-webkit-keyframes swal2-animate-error-x-mark{0%{margin-top:1.625em;-webkit-transform:scale(.4);transform:scale(.4);opacity:0}50%{margin-top:1.625em;-webkit-transform:scale(.4);transform:scale(.4);opacity:0}80%{margin-top:-.375em;-webkit-transform:scale(1.15);transform:scale(1.15)}100%{margin-top:0;-webkit-transform:scale(1);transform:scale(1);opacity:1}}@keyframes swal2-animate-error-x-mark{0%{margin-top:1.625em;-webkit-transform:scale(.4);transform:scale(.4);opacity:0}50%{margin-top:1.625em;-webkit-transform:scale(.4);transform:scale(.4);opacity:0}80%{margin-top:-.375em;-webkit-transform:scale(1.15);transform:scale(1.15)}100%{margin-top:0;-webkit-transform:scale(1);transform:scale(1);opacity:1}}@-w ...
#       .ejoy-sub-active{
#         color: #1296ba !important;
#       }
#
#       .ejoy-sub-hovered{
#         color: #1296ba !important;
#       }
#       .ejoy-sub-clzz{
#         cursor: pointer;
#
#         lineHeight: 1.2;
#           font-size: 28px;
#           color: #FFCC00; background: rgba(17, 17, 17, 0.7);
#
#       }
#       .ejoy-sub-clzz:hover{
#         color: #1296ba !important;
#       }
#       .ej-trans-sub{
#         position: absolute;
#         width: 100%;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         z-index: 9999999;
#         cursor: move;
#       }
#       .ej-trans-sub > span{
#         color: #3CF9ED;
#         font-size: 18px;
#         text-align: center;
#         padding: 0 16px;
#         line-height: 1.5;
#         background: rgba(32, 26, 25, 0.8);
#         // text-shadow: 0px 1px 4px black;
#         padding: 0 8px;
#
#         lineHeight: 1.2;
#         font-size: 16px;
#         color: #0CB1C7; background: rgba(67, 65, 65, 0.7);
#
#       }
#       .ej-main-sub{
#         position: absolute;
#         width: 100%;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         z-index: 99999999;
#         cursor: move;
#         padding: 0 8px;
#       }
#       .ej-main-sub > span{
#         color: white;
#         font-size: 20px;
#         line-height: 1.5;
#         text-align: center;
#         background: rgba(32, 26, 25, 0.8);
#         // text-shadow: 0px 1px 4px black;
#         padding: 2px 8px;
#
#         lineHeight: 1.2;
#           font-size: 28px;
#           color: #FFCC00; background: rgba(17, 17, 17, 0.7);
#
#       }
#
#       .ej-main-sub .ejoy-sub-clzz{
#         background: transparent !important
#       }
#
#       .tran-subtitle > span{
#         cursor: pointer;
#         padding-left: 10px;
#         top: 2px;
#         position: relative;
#       }
#
#       .tran-subtitle > span > span{
#         position: absolute;
#         top: -170%;
#         background: rgba(0,0,0,0.5);
#         font-size: 13px;
#         line-height: 20px;
#         padding: 2px 8px;
#         color: white;
#         display: none;
#         border-radius: 4px;
#         white-space: nowrap;
#         left: -50%;
#         font-weight: normal;
#       }
#
#       .view-icon-copy-main-sub:hover > span, .view-icon-edit-sub:hover > span, .view-icon-copy-tran-sub:hover > span {
#         display: block;
#       }
#
#       .tran-subtitle > span > svg{
#         width: 16px;
#         height: 16px;
#         pointer-events: none;
#         display: inline-flex !important;
#         vertical-align: baseline !important;
#       }
#
#       .view-icon-copy-main-sub > svg{
#         pointer-events: none;
#         color: #FFCC00
#       }
#
#       .view-icon-copy-tran-sub{
#         padding-left: 0 !important;
#         padding-right: 8px !important;
#       }
#       .view-icon-copy-tran-sub > svg{
#         pointer-events: none;
#         color: #0CB1C7
#       }
#
#
#       </style><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/691592443/?random=1655641995845&amp;cv=9&amp;fst=1655641995845&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=376635471&amp;u_h=713&amp;u_w=962&amp;u_ah=713&amp;u_aw=962&amp;u_cd=24&amp;u_his=4&amp;u_tz=420&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;gtm=2oa6f0&amp;sendb=1&amp;ig=1&amp;data=event%3Dgtag.config&amp;frm=0&amp;url=https%3A%2F%2Fmediamart.vn%2Fsmartphones&amp;ref=https%3A%2F%2Fmediamart.vn%2F&amp;tiba=%C4%90i%E1%BB%87n%20tho%E1%BA%A1i%20di%20%C4%91%E1%BB%99ng%20gi%C3%A1%20r%E1%BA%BB%20%7C%20Smartphone%20ch%C3%ADnh%20h%C3%A3ng%20t%E1%BB%91t%20nh%E1%BA%A5t&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><link class="ins-frameless-css" classname="ins-frameless-css" href="https://assets.api.useinsider.com/css/info.min.css" id="ins-frameless-css" rel="stylesheet" type="text/css"/><script id="ins-frameless-js" src="https://eitri.api.useinsider.com/static/info.js" type="text/javascript"></script><style class="ins-outer-stylesheet-959" classname="ins-outer-stylesheet-959" id="ins-outer-stylesheet-959" type="text/css">.ins-preview-wrapper-959 .ins-content-wrapper strong{ color: inherit;}.ins-preview-wrapper-959 #ins-email-collection-adaptive{ float: left; width: 288px;}.ins-preview-wrapper-959 .ins-notification-content{ width: 288px !important; display: inline-block !important; height: auto !important; margin: 10px; max-width: 100%;}.ins-preview-wrapper-959 .ins-notification-content a{ color: inherit !important;}.ins-preview-wrapper-959 .ins-element-close-button{ display: block !important;top: 10px;right: 16px;font-size: 28px;color: #333;position: absolute;z-index: 1;}.ins-preview-wrapper-959 .ins-close-button-icon{ display: inline-block; font-size: inherit; text-rendering: auto; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale; transform: translate(0, 0); color: inherit;}.ins-preview-wrapper-959 .ins-close-button-icon:before{ content: "d7"; color: inherit; cursor: pointer; font-size: inherit; font-family: Arial,sans-serif; line-height: 1;}.ins-preview-wrapper-959 .ins-element-link{ width: 100%; height: 100%; color: inherit;}.ins-preview-wrapper-959 .ins-adaptive-title .ins-element-content,.ins-preview-wrapper-959 .ins-adaptive-description .ins-element-content{ height: auto; margin: 0 auto; padding: 0; box-sizing: border-box; color: rgb(95, 95, 95);}.ins-preview-wrapper-959 .ins-adaptive-email input{ background-color: #ffffff;width: 100%;height: 45px;margin: 0;border: 1px solid #d4d6d4;font-size: 16px;color: #c5c5c5;padding: 0 15px;box-sizing: border-box;border-radius: 3px;outline: none;display: block;}.ins-preview-wrapper-959 .ins-adaptive-title,.ins-preview-wrapper-959 .ins-adaptive-description,.ins-preview-wrapper-959 .ins-adaptive-question,.ins-preview-wrapper-959 .ins-adaptive-button{ margin: auto; margin-top: 10px; color: #FFFFFF;}.ins-preview-wrapper-959 .ins-adaptive-title .ins-element-content,.ins-preview-wrapper-959 .ins-adaptive-description .ins-element-content{ outline: none; word-wrap: break-word; text-align: center;}.ins-preview-wrapper-959 .ins-adaptive-title .ins-element-content{ font-size: 24px; font-weight: 700;}.ins-preview-wrapper-959 .ins-adaptive-description .ins-element-content{ font-size: 14px;}.ins-preview-wrapper-959 .ins-adaptive-button .ins-element-content{ width: 130px; padding: 8px; margin: 0 auto; opacity: 1; background-color: rgb(90, 191, 247); border-radius: 25px !important; font-size: 16px;}.ins-preview-wrapper-959 .ins-slider{ width: 100%; overflow: hidden;}.ins-preview-wrapper-959 .ins-slider-page{ float: left; visibility: hidden;}.ins-preview-wrapper-959 .ins-slider-page.ins-active-slide{ float: left; visibility: visible;}.ins-preview-wrapper-959 .ins-slider-container{ overflow: hidden; transform: translate3d(0,0,0); display: flex !important; align-items: center !important; justify-content: center !important; -webkit-tr ...
# gtag('js',new Date());gtag('config','UA-42719228-1');</script><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-691592443"></script><script>window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments);}gtag('js',new Date());gtag('config','AW-691592443');</script><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NBFFVWK" style="display:none;visibility:hidden" width="0"></iframe></noscript><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WC7BMZL" style="display:none;visibility:hidden" width="0"></iframe></noscript><script>!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');fbq('init','920879161645117');fbq('track','PageView');</script><noscript><img height="1" src="https://www.facebook.com/tr?id=920879161645117&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript><script>(function(a,b,d,c,e){a[c]=a[c]||[];a[c].push({"atm.start":(new Date).getTime(),event:"atm.js"});a=b.getElementsByTagName(d)[0];b=b.createElement(d);b.async=!0;b.src="//deqik.com/tag/corejs/"+e+".js";a.parentNode.insertBefore(b,a)})(window,document,"script","atmDataLayer","ATMQ85OBNVVLX");</script><script async="" src="//mediamartvn.api.useinsider.com/ins.js?id=10004325"></script><div class="p-progress"><div class="progress-over"></div><div class="progress" style="height:3px"><div class="progress-bar progress-filter" style="width:0;height:10px"></div></div></div><div class="container-fluid padding-unset-h"><div class="bgcolor-2"><div class="container"><div class="row"><div class="col-12 col-md-12"><div class="owlRespon-2 boxbanner-2"><div class="banner-list owl-loaded owl-drag"><div class="owl-stage-outer"><div class="owl-stage" style="transform: translate3d(0px, 0px, 0px); transition: all 0s ease 0s; width: 963px;"><div class="owl-item active" style="width: 481.2px;"><div class="item banner-item banner-item-1"><a data-id="1266" href="/dieu-hoa-sieu-sale" target='"_blank"'> <img alt="Điều hòa giảm sâu1" height='"66"' src="https://cdn.mediamart.vn/images/banner/diu-hoa-gim-sau1_8fde285e.jpg" width='"600"'/> <span class="banner-item-view banner-item-view-1266" style="display:none"></span> </a></div></div><div class="owl-item active" style="width: 481.2px;"><div class="item banner-item banner-item-2"><a data-id="1267" href="/dieu-hoa-sieu-sale" target='"_blank"'> <img alt="Điều hòa giảm sâu2" height='"66"' src="https://cdn.mediamart.vn/images/banner/diu-hoa-gim-sau2_761511aa.jpg" width='"600"'/> <span class="banner-item-view banner-item-view-1267" style="display:none"></span> </a></div></div></div></div><div class="owl-nav disabled"><button class="owl-prev disabled" role="presentation" type="button"></button><button class="owl-next disabled" role="presentation" type="button"></button></div><div class="owl-dots disabled"><button class="owl-dot active" role="button"><span></span></button></div></div></div></div></div></div></div><div class="bgcolor-main"><div class="container"><div class="row header-body flex flex-content-spacebetween"><div class="col-md-3 col-9"><div class="box-logo"><a class="flex flex-items-center" href="/"> <img alt="" src="/css/images/logo.png"/> </a></div></div><div class="col-md-5 col-3 box-utilities"><div class="flex flex-content-spacearound"><div class="box-contact"><a href="tel:1900 6788"> <b>1900 6788</b> <span>Tư vấn bán hàng</span> </a></div><div class="box-location"><a href="/he-thong-sieu-thi"> <b>Xem 300 Siêu thị &gt;</b> <span>Mở cửa: 8:00 - 21:30</span> </a></div><div class="box-cart"><div class="cart-badge badge-icons pull-right"><a href="/cart"><i class="fa fa-shopping-cart"></i><span>Giỏ hà ...
# <div class="card mb-4">
# <a class="product-item" data-id="19248" href="/smartphones/dien-thoai-realme-c21-y-4-64-den" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <span class="product-type product-type-17" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 50;background: url(https://cdn.mediamart.vn/images/catalog/sale-nua-gia_b91ce5da.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/realme-46XwW1.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c21-y-4-64-den_a26fb29e.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c21-y-4-64-den_a26fb29e.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Realme C21-Y (4-64) Đen" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c21-y-4-64-den_a26fb29e.jpg"/>
# <span class="product-item-view product-item-view-19248" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Realme C21-Y (4-64) Đen            </h5>
# <ul class="list-inline product-attributes">
# <li>4 GB</li>
# <li>64 GB</li>
# </ul>
# <p class="card-text product-price">
#                     3.790.000 ₫
#                         <span class="product-price-saving">-15%</span>
# <br/>
# <span class="product-price-regular">4.490.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="19246" href="/smartphones/dien-thoai-realme-c21-y-3-32-den" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <span class="product-type product-type-17" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 50;background: url(https://cdn.mediamart.vn/images/catalog/sale-nua-gia_b91ce5da.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/realme-46XwW1.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c21-y-3-32-den_2bbf4948.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c21-y-3-32-den_2bbf4948.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Realme C21-Y (3-32) Đen" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c21-y-3-32-den_2bbf4948.jpg"/>
# <span class="product-item-view product-item-view-19246" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Realme C21-Y (3-32) Đen            </h5>
# <ul class="list-inline product-attributes">
# <li>3 GB</li>
# <li>32 GB</li>
# </ul>
# <p class="card-text product-price">
#                     3.290.000 ₫
#                         <span class="product-price-saving">-17%</span>
# <br/>
# <span class="product-price-regular">3.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="19663" href="/smartphones/dien-thoai-oppo-cph2343-reno7-z-5g-den" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/oppo-0bI09D.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2343---reno7-z-5g-den_040199a5.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2343---reno7-z-5g-den_040199a5.jpg" type="image/jpeg"/>
# <img alt="Điện thoại OPPO CPH2343 - Reno7 Z 5G Đen" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2343---reno7-z-5g-den_040199a5.jpg"/>
# <span class="product-item-view product-item-view-19663" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# OPPO CPH2343 - Reno7 Z 5G Đen            </h5>
# <ul class="list-inline product-attributes">
# <li>8 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     9.690.000 ₫
#                         <span class="product-price-saving">-11%</span>
# <br/>
# <span class="product-price-regular">10.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="19197" href="/smartphones/dien-thoai-oppo-cph2365-a95-bac-pha-cach" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/oppo-0bI09D.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2365---a95-bc-pha-cach_f973de0e.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2365---a95-bc-pha-cach_f973de0e.jpg" type="image/jpeg"/>
# <img alt="Điện thoại OPPO CPH2365 - A95 Bạc Phá Cách" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2365---a95-bc-pha-cach_f973de0e.jpg"/>
# <span class="product-item-view product-item-view-19197" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# OPPO CPH2365 - A95 Bạc Phá Cách            </h5>
# <ul class="list-inline product-attributes">
# <li>8 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     6.490.000 ₫
#                         <span class="product-price-saving">-9%</span>
# <br/>
# <span class="product-price-regular">7.190.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="19541" href="/smartphones/dien-thoai-samsung-galaxy-s22-ultra-5g-s908e-8-128g-den-phantom" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <span class="product-type product-type-16" style="display: block;   position: absolute;   left: 10px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 2000;background: url(https://cdn.mediamart.vn/images/catalog/option-6_641d2c0f.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/samsung-2XG2f2.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-s22-ultra-8128g-den_4988f69b.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-s22-ultra-8128g-den_4988f69b.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Samsung Galaxy S22 Ultra 5G S908E (8+128G) Đen Phantom" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-s22-ultra-8128g-den_4988f69b.jpg"/>
# <span class="product-item-view product-item-view-19541" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Samsung Galaxy S22 Ultra 5G S908E (8+128G) Đen Phantom            </h5>
# <ul class="list-inline product-attributes">
# <li>8 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     26.990.000 ₫
#                         <span class="product-price-saving">-14%</span>
# <br/>
# <span class="product-price-regular">31.490.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="8119" href="/smartphones/dien-thoai-samsung-galaxy-a03s-sma037-64g-xanh" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <span class="product-type product-type-16" style="display: block;   position: absolute;   left: 10px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 2000;background: url(https://cdn.mediamart.vn/images/catalog/option-6_641d2c0f.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/samsung-2XG2f2.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-samsung-galaxy-a03s-sma037-64g-blue-1G4461.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-samsung-galaxy-a03s-sma037-64g-blue-1G4461.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Samsung Galaxy A03s SM-A037 64G Xanh" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-samsung-galaxy-a03s-sma037-64g-blue-1G4461.jpg"/>
# <span class="product-item-view product-item-view-8119" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Samsung Galaxy A03s SM-A037 64G Xanh            </h5>
# <ul class="list-inline product-attributes">
# <li>4 GB</li>
# <li>64 GB</li>
# </ul>
# <p class="card-text product-price">
#                     3.290.000 ₫
#                         <span class="product-price-saving">-17%</span>
# <br/>
# <span class="product-price-regular">3.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="8116" href="/smartphones/dien-thoai-samsung-galaxy-z-flip-128gb-beige-dm" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/samsung-2XG2f2.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/-yGw6s0.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/-yGw6s0.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Samsung Galaxy Z Flip 3 F711B 5G 128GB Cream(Beige) (DM)" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/-yGw6s0.jpg"/>
# <span class="product-item-view product-item-view-8116" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Samsung Galaxy Z Flip 3 F711B 5G 128GB Cream(Beige) (DM)            </h5>
# <ul class="list-inline product-attributes">
# <li>8 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     16.990.000 ₫
#                         <span class="product-price-saving">-37%</span>
# <br/>
# <span class="product-price-regular">26.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="19597" href="/smartphones/dien-thoai-oppo-cph2375-a76-xanh-thoi-thuong" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/oppo-0bI09D.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2375---a76-xanh-thi-thung_493c4ae8.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2375---a76-xanh-thi-thung_493c4ae8.jpg" type="image/jpeg"/>
# <img alt="Điện thoại OPPO CPH2375 - A76 Xanh Thời Thượng" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2375---a76-xanh-thi-thung_493c4ae8.jpg"/>
# <span class="product-item-view product-item-view-19597" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# OPPO CPH2375 - A76 Xanh Thời Thượng            </h5>
# <ul class="list-inline product-attributes">
# <li>6 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     5.490.000 ₫
#                         <span class="product-price-saving">-15%</span>
# <br/>
# <span class="product-price-regular">6.490.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="8310" href="/smartphones/dien-thoai-xiaomi-redmi-9c-4-128-xam" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-17" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 50;background: url(https://cdn.mediamart.vn/images/catalog/sale-nua-gia_b91ce5da.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/xiaomi-68M4uk.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-xiaomi-redmi-9c-4128-xam-j92Q5P.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-xiaomi-redmi-9c-4128-xam-j92Q5P.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Xiaomi Redmi 9C (4+128) Xám" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-xiaomi-redmi-9c-4128-xam-j92Q5P.jpg"/>
# <span class="product-item-view product-item-view-8310" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Xiaomi Redmi 9C (4+128) Xám            </h5>
# <ul class="list-inline product-attributes">
# <li>4 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     2.990.000 ₫
#                         <span class="product-price-saving">-18%</span>
# <br/>
# <span class="product-price-regular">3.690.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="8108" href="/smartphones/dien-thoai-samsung-galaxy-a52-128g-a525f-den" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-16" style="display: block;   position: absolute;   left: 10px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 2000;background: url(https://cdn.mediamart.vn/images/catalog/option-6_641d2c0f.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/samsung-2XG2f2.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/-IPLdw7.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/-IPLdw7.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Samsung Galaxy A52 128G A525F Đen" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/-IPLdw7.jpg"/>
# <span class="product-item-view product-item-view-8108" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Samsung Galaxy A52 128G A525F Đen            </h5>
# <ul class="list-inline product-attributes">
# <li>8 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     5.990.000 ₫
#                         <span class="product-price-saving">-38%</span>
# <br/>
# <span class="product-price-regular">9.790.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="8160" href="/smartphones/dien-thoai-samsung-galaxy-m21-smm215f-64gb-blue" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/samsung-2XG2f2.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/-6vQ4s3.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/-6vQ4s3.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Samsung Galaxy M21 SM-M215F 64GB Blue" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/-6vQ4s3.jpg"/>
# <span class="product-item-view product-item-view-8160" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Samsung Galaxy M21 SM-M215F 64GB Blue            </h5>
# <ul class="list-inline product-attributes">
# <li>4 GB</li>
# <li>64 GB</li>
# </ul>
# <p class="card-text product-price">
#                     3.990.000 ₫
#                         <span class="product-price-saving">-33%</span>
# <br/>
# <span class="product-price-regular">5.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="19600" href="/smartphones/dien-thoai-xiaomi-redmi-note-11-pro-5g-8-128g-xam" target="_blank">
# <div class="card-img-top">
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/xiaomi-68M4uk.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-xiaomi-redmi-note-11-pro-5g-8128g-xam_3d99e09f.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-xiaomi-redmi-note-11-pro-5g-8128g-xam_3d99e09f.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Xiaomi Redmi Note 11 Pro 5G (8+128G) Xám" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-xiaomi-redmi-note-11-pro-5g-8128g-xam_3d99e09f.jpg"/>
# <span class="product-item-view product-item-view-19600" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Xiaomi Redmi Note 11 Pro 5G (8+128G) Xám            </h5>
# <ul class="list-inline product-attributes">
# <li>8 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     8.990.000 ₫
#                         <span class="product-price-saving">-5%</span>
# <br/>
# <span class="product-price-regular">9.490.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="19871" href="/smartphones/dien-thoai-samsung-galaxy-a33-a336e-5g-xanh" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <span class="product-type product-type-16" style="display: block;   position: absolute;   left: 10px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 2000;background: url(https://cdn.mediamart.vn/images/catalog/option-6_641d2c0f.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/samsung-2XG2f2.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-a33-a336e-5g-xanh_114ac1f0.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-a33-a336e-5g-xanh_114ac1f0.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Samsung Galaxy A33 A336E 5G Xanh" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-a33-a336e-5g-xanh_114ac1f0.jpg"/>
# <span class="product-item-view product-item-view-19871" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Điện thoại Samsung Galaxy A33 A336E 5G Xanh            </h5>
# <ul class="list-inline product-attributes">
# <li>6 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     6.990.000 ₫
#                         <span class="product-price-saving">-22%</span>
# <br/>
# <span class="product-price-regular">8.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="8110" href="/smartphones/samsung-galaxy-a22-128g-a225f-den" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/samsung-2XG2f2.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/-P3RblP.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/-P3RblP.jpg" type="image/jpeg"/>
# <img alt="Samsung Galaxy A22 128G A225F Đen" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/-P3RblP.jpg"/>
# <span class="product-item-view product-item-view-8110" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Samsung Galaxy A22 128G A225F Đen            </h5>
# <ul class="list-inline product-attributes">
# <li>6 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     4.490.000 ₫
#                         <span class="product-price-saving">-25%</span>
# <br/>
# <span class="product-price-regular">5.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3 col-lg-3" style="">
# <div class="card mb-4">
# <a class="product-item" data-id="8117" href="/smartphones/dien-thoai-samsung-galaxy-z-fold-3-5g-256g-den-phantom" target="_blank">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/samsung-2XG2f2.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-samsung-galaxy-z-fold-3-5g-256g-den-phantom-k54FnR.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-samsung-galaxy-z-fold-3-5g-256g-den-phantom-k54FnR.jpg" type="image/jpeg"/>
# ...
# <div class="item banner-item banner-item-1">
# <a data-id="1055" href="javascript:;">
# <picture>
# <source media="(max-width: 420px)" srcset="https://cdn.mediamart.vn/images/banner/ha-cate-ban-chy_6121cdb0.jpg" type="image/jpeg"/>
# <source srcset="https://cdn.mediamart.vn/images/banner/ha-cate-ban-chy_e9589310.jpg" type="image/jpeg"/>
# <img alt="HA-Cate bán chạy" height='"940"' loading="lazy" src="https://cdn.mediamart.vn/images/banner/ha-cate-ban-chy_e9589310.jpg" width='"640"'/>
# </picture>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-md-9">
# <div class="row product-list product-list-4">
# <div class="col-6 col-md-3">
# <div class="card mb-4">
# <a class="product-item" data-id="8089" href="/smartphones/apple-iphone-13-pro-max-128g-blue">
# <div class="card-img-top">
# <span class="product-type product-type-22" style="display: block;   position: absolute;   left: 23px ;     bottom: 78px ;     width: 50px;     height: 63px;    background-size: contain; z-index: 202;background: url(https://cdn.mediamart.vn/images/catalog/option-12_037b5c0f.png) no-repeat center center;"></span>
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-17" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 50;background: url(https://cdn.mediamart.vn/images/catalog/sale-nua-gia_b91ce5da.png) no-repeat center center;"></span>
# <span class="product-type product-type-16" style="display: block;   position: absolute;   left: 10px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 2000;background: url(https://cdn.mediamart.vn/images/catalog/option-6_641d2c0f.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/apple-7HolmJ.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-max-128g-blue-Q8TaJN.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-max-128g-blue-Q8TaJN.jpg" type="image/jpeg"/>
# <img alt="Apple Iphone 13 Pro Max 128G Blue" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-max-128g-blue-Q8TaJN.jpg"/>
# <span class="product-item-view product-item-view-8089" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Apple Iphone 13 Pro Max 128G Blue            </h5>
# <ul class="list-inline product-attributes">
# <li>6 GB</li>
# <li>128 GB</li>
# </ul>
# <p class="card-text product-price">
#                     28.990.000 ₫
#                         <span class="product-price-saving">-17%</span>
# <br/>
# <span class="product-price-regular">34.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3">
# <div class="card mb-4">
# <a class="product-item" data-id="8185" href="/smartphones/dien-thoai-xiaomi-redmi-9a-2-32-xanh-la">
# <div class="card-img-top">
# <span class="product-type product-type-25" style="display: block; position: absolute; left: 9px ; bottom: -9px ; width: 145px; height: 30px; background-size: contain; z-index: 22;background: url(https://cdn.mediamart.vn/images/catalog/san-pham-hot_79ce5812.png) no-repeat center center;"></span>
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/xiaomi-68M4uk.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-xiaomi-redmi-9a-232-xanh-la_180be925.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-xiaomi-redmi-9a-232-xanh-la_180be925.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-xiaomi-redmi-9a-232-xanh-la_180be925.jpg"/>
# <span class="product-item-view product-item-view-8185" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Xiaomi REDMI 9A (2+32) Xanh lá            </h5>
# <ul class="list-inline product-attributes">
# <li>2 GB</li>
# <li>32 GB</li>
# </ul>
# <p class="card-text product-price">
#                     2.290.000 ₫
#                         <span class="product-price-saving">-23%</span>
# <br/>
# <span class="product-price-regular">2.990.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3">
# <div class="card mb-4">
# <a class="product-item" data-id="8138" href="/smartphones/dien-thoai-oppo-cph2325-a55-den-manh-me">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-11" style="display: block; position: absolute; right: 6px ; top: 8px ; font-size: 11px; z-index: 3; background-color: #f1f1f1; color: #333; padding: 2px 5px ; border-radius: 3px ;">Trả góp 0%</span>
# <span class="product-type product-type-17" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 50;background: url(https://cdn.mediamart.vn/images/catalog/sale-nua-gia_b91ce5da.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/oppo-0bI09D.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-oppo-cph2325-a55-den-manh-me-qZC39z.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-oppo-cph2325-a55-den-manh-me-qZC39z.jpg" type="image/jpeg"/>
# <img alt="Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/dien-thoai-oppo-cph2325-a55-den-manh-me-qZC39z.jpg"/>
# <span class="product-item-view product-item-view-8138" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# OPPO CPH2325 - A55 Đen Mạnh Mẽ            </h5>
# <ul class="list-inline product-attributes">
# <li>4 GB</li>
# <li>64 GB</li>
# </ul>
# <p class="card-text product-price">
#                     4.390.000 ₫
#                         <span class="product-price-saving">-15%</span>
# <br/>
# <span class="product-price-regular">5.190.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-6 col-md-3">
# <div class="card mb-4">
# <a class="product-item" data-id="19131" href="/smartphones/dien-thoai-realme-c11-2021-2-32-xanh">
# <div class="card-img-top">
# <span class="product-type product-type-18" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 19;background: url(https://cdn.mediamart.vn/images/catalog/sale-giua-thang_9b584444.png) no-repeat center center;"></span>
# <span class="product-type product-type-17" style="display: block;   position: absolute;   left: 9px ;     bottom: -5px ;     width: 145px;     height: 22px;    background-size: contain; z-index: 50;background: url(https://cdn.mediamart.vn/images/catalog/sale-nua-gia_b91ce5da.png) no-repeat center center;"></span>
# <p class="product-brand" style="background: url( https://cdn.mediamart.vn/images/brand/realme-46XwW1.png ) no-repeat left center;">
# </p>
# <picture>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c11-2021-2-32-xanh_92fa02c1.webp" type="image/webp"/>
# <source srcset="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c11-2021-2-32-xanh_92fa02c1.jpg" type="image/jpeg"/>
# <img alt="Điện thoại Realme C11 2021 (2-32) Xanh" loading="lazy" src="https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c11-2021-2-32-xanh_92fa02c1.jpg"/>
# <span class="product-item-view product-item-view-19131" style="display:none;"></span>
# </picture>
# </div>
# <div class="card-body">
# <h5 class="card-title product-name">
# Realme C11 2021 (2-32) Xanh            </h5>
# <ul class="list-inline product-attributes">
# <li>2 GB</li>
# <li>32 GB</li>
# </ul>
# <p class="card-text product-price">
#                     2.590.000 ₫
#                         <span class="product-price-saving">-18%</span>
# <br/>
# <span class="product-price-regular">3.190.000 ₫</span>
# </p>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></div><div class="clearfix pt-3"></div><div class="row"><div class="product-viewed col-12 col-md-12"></div></div><div class="clearfix pt-3"></div></div></div><div class="clearfix"></div></div><div class="clearfix"></div><div id="footer-banner"><div class="container"><div class="row"><div class="col-12"><div class="wrapbox-getBanners" data-id="3" data-limit="3">
# </div></div></div></div></div><div class="clearfix"></div><div class="footer-content bg-footer"><div class="footer-hr"></div><div class="container"><div class="clearfix pt-4"></div><div class="row"><div class="col-12 col-md-6 col-lg-3"><ul class="list-unstyled"><li><a href="/he-thong-sieu-thi" title="&lt;b&gt;THÔNG TIN MEDIAMART&lt;/b&gt;"> <span><b>THÔNG TIN MEDIAMART</b></span> </a></li><li><a href="/he-thong-sieu-thi" title="Hệ thống 300 Siêu thị (8:00-21:30)"> <span>Hệ thống 300 Siêu thị (8:00-21:30)</span> </a></li><li><a href="/thong-tin-chung/gioi-thieu-cong-ty" title="Giới thiệu công ty"> <span>Giới thiệu công ty</span> </a></li><li><a href="/tuyen-dung" title="Tuyển dụng"> <span>Tuyển dụng</span> </a></li><li><a href="mailto:hotro@mediamart.com.vn" title="Liên hệ và góp ý"> <span>Liên hệ và góp ý</span> </a></li><li><a href="/chinh-sach-chung/quy-dinh-thanh-toan" title="Phương thức thanh toán"> <span>Phương thức thanh toán</span> </a></li></ul><div class="wrapbox-getBanners banner-methodpay" data-id="4" data-limit="1">
# </div></div><div class="col-12 col-md-6 col-lg-3"><ul class="list-unstyled"><li><a href="javascript:" title="&lt;b&gt;Hỗ trợ khách hàng&lt;/b&gt;"> <span><b>Hỗ trợ khách hàng</b></span> </a></li><li><a href="/ho-tro-mua-hang/huong-dan-mua-hang-online" title="Hướng dẫn mua hàng Online"> <span>Hướng dẫn mua hàng Online</span> </a></li><li><a href="/uu-dai-tra-gop" title="Mua hàng trả góp"> <span>Mua hàng trả góp</span> </a></li><li><a href="/chinh-sach-chung/chinh-sach-doi-tra-hang" title="Chính sách bảo hành, đổi trả"> <span>Chính sách bảo hành, đổi trả</span> </a></li><li><a href="/chinh-sach-chung/chinh-sach-giao-nhan" title="Giao hàng và lắp đặt"> <span>Giao hàng và lắp đặt</span> </a></li><li><a href="/chinh-sach-chung/quy-dinh-bao-mat" title="Chính sách bảo mật TT cá nhân"> <span>Chính sách bảo mật TT cá nhân</span> </a></li><li><a href="https://tracuuhoadon.mediamart.com.vn" title="In hóa đơn điện tử"> <span>In hóa đơn điện tử</span> </a></li></ul></div><div class="col-12 col-md-6 col-lg-3"><ul class="list-unstyled"><li><a href="javascript:" title="&lt;b&gt;Tổng đài gọi hỗ trợ&lt;/b&gt;"> <span><b>Tổng đài gọi hỗ trợ</b></span> </a></li><li><a href="tel:19006788" title="Bán hàng: 1900 6788"> <span>Bán hàng: 1900 6788</span> </a></li><li><a href="tel:19006743" title="Bảo hành: 1900 6743"> <span>Bảo hành: 1900 6743</span> </a></li><li><a href="tel:19006741" title="Khiếu nại: 1900 6741"> <span>Khiếu nại: 1900 6741</span> </a></li></ul></div><div class="col-12 col-md-6 col-lg-3"><div class="footer-social"><ul class="list-unstyled"><li><a href="#" title="Theo dõi MediaMart trên"> <span>Theo dõi MediaMart trên</span> </a></li><li><a href="https://www.facebook.com/DienmayMediaMart" title="MediaMart Facebook Fanpage"> <span>MediaMart Facebook Fanpage</span> <img alt="MediaMart Facebook Fanpage" src="https://cdn.mediamart.vn/images/menu/mediamart-facebook-fanpage_7b8f3ccc.png"/> </a></li><li><a href="https://www.youtube.com/c/CongtyMediamart" title="MediaMart Youtube Channel"> <span>MediaMart Youtube Channel</span> <img alt="MediaMart Youtube Channel" src="https://cdn.mediamart.vn/images/menu/mediamart-youtube-channel_53501d19.png"/> </a></li><li><a href="https://www.tiktok.com/@mediamart.official" title="MediaMart Tiktok Channel"> <span>MediaMart Tiktok Channel</span> <img alt="MediaMart Tiktok Channel" src="https://cdn.mediamart.vn/images/menu/mediamart-tiktok-channel_52e656aa.png"/> </a></li><li><a href="https://play.google.com/store/apps/details?id=com.mediamartvn.mediamartvn" title="Cập nhật MediaMart trên Mobile"> <span>Cập nhật MediaMart trên Mobile</span> </a></li><li><a href="https://apps.apple.com/vn/app/mediamartvn/id1572630752" title="MediaMart iOS App"> <span>MediaMart iOS App</span> <img alt="MediaMart iOS App" src="https://cdn.mediamart.vn/images/menu/mediamart-ios-app_4b5435b9.png"/> </a></li><li><a href="#" title="MediaMart Android App"> <span>MediaMart Android App</span> <img alt="MediaMart Android App" src="https://cdn.mediamart.vn/images/menu/mediamart-android-app_0f2f434d.png"/> </a></li></ul></div><div class="clearfix"></div><a class="statusBCT" href="http://online.gov.vn/Home/WebDetails/2484" rel="nofollow" target="_blank"> </a> <a class="noFake" href="/chinh-sach-chung/quy-trinh-giai-quyet-khieu-nai" target="_blank"> </a></div></div></div></div><div class="footer-createby bg-createby"><div class="container"><div class="createby">© 2007 Công ty Cổ phần MEDIAMART Việt Nam - ĐCĐK: 29F Hai Bà Trưng. GPĐKKD số: 0102516308 do Sở KHĐT Tp.Hà Nội cấp ngày 15/11/2007. Email: hotro@mediamart.com.vn. Điện thoại: 1900 6741. Fax: 0243 933 0766 Website: mediamart.vn / thegioidienmay.com</div></div></div><div class="popup-allpage popup-allpage-active" id="popup-allpage" style="display:none"><div class="popup-allpage-item"><div class="boxbanner-8"></div><a class="popup-allpage-close" href="javascript:" title="Đóng lại"></a></div></div><div class="popup-footer popup-footer-hide" id="popup-footer" style="display: block;"><div ...
# (function(self){self.sendDataToContactList=function(userInfo){var payload={partner:partnerName,source:'email',users:[{identifiers:{em:userInfo.email},attributes:userInfo.attributes,append:true,immediate:true}],};Insider.request.post({url:'https://unification.useinsider.com/api/attribute/v2/update',data:JSON.stringify(payload),dataType:'json'});};(Insider.__external.ajaxListener||Insider.fns.noop)(function(url){if(url.indexOf('/save-questionnaire/mediamartvn')>-1){var contactListId=10;var userInfo={email:Insider.dom('#ins-dynamic-input-1552321452906').val(),attributes:{lid:[contactListId],eo:true,gdpr:true}};self.sendDataToContactList(userInfo);}});})({});})({"id":959,"predictiveFeedSettings":"","locationConfig":{"type":0,"mode":"adaptive","position":"fixed","left":"6.0026044845581055","top":"60.8897590637207","windowHeight":"568","windowWidth":"320","windowHref":"https://mediamart.vn/","selectedElement":"","frameless":true,"gridIsActive":true,"gridConfig":{"gridIsActive":"true","mode":"adaptive","xDirection":"center","yDirection":"middle"}},"currencyFormatRules":{"USD":{"name":"US Dollar","symbol":"USD","alignment":"1","thousandSeparator":".","decimalSeparator":",","decimalCount":0,"value":"USD"},"VND":{"name":"Vietnamese Dong","symbol":"đ","alignment":"1","thousandSeparator":".","decimalSeparator":",","decimalCount":0,"value":"VND"}},"smsConfig":{"virtualLongNumber":""}});}catch(err){Insider.errorBag.add(err);}</script></body></html>

# %%
images_link = []
for img in soup.find_all("div", class_ = "card-img-top"):
  images_link.append(img.find("img")['src'])

# %%
images_link = images_link[:147]

# %%
len(soup.find_all("div", class_="col-6 col-md-3 col-lg-3"))
# Out:
# 147

# %%
import time
k = 0
with open("Media_Mart.txt", mode = "w", encoding = "utf8") as f:
  for div in soup.find_all("div", class_="col-6 col-md-3 col-lg-3"):
    try:
      url = 'https://mediamart.vn' + div.find("a", href=True)['href']
      headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:73.0) Gecko/20100101 Firefox/73.0',
        'X-Requested-With': 'XMLHttpRequest',
      }    
      r = requests.get(url, headers=headers)
      data = {}
      detail = BeautifulSoup(r.content.decode('utf-8', 'ignore'), 'html.parser')
      data["name"] = detail.find_all("div", class_="pdetail-name")[0].text.split('\n')[1]
      data["url"] = url
      data["image_link"] = images_link[k]
      x=0
      key=''
      for tr in detail.find_all('td'):
        if(len(tr.get_text()) > 0):
          if(x%2)==0:
            key=tr.get_text()
          else:
            data[key]=tr.get_text()
          x=x+1
      data["price"] = detail.find("div", class_="pdetail-price-box").text
      jsonString = json.dumps(data, ensure_ascii=False)
      f.write(jsonString + "\n")
      print(jsonString)
      k = k + 1
    except:
      pass
    # time.sleep(2)
# Out:
# {"name": "Apple Iphone 11 64G White", "url": "https://mediamart.vn/smartphones/apple-iphone-11-64gb-white", "image_link": "https://cdn.mediamart.vn/thumb/images/product/-N9QObu.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 11\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "Retina", "Độ phân giải": "1792 x 828 pixels", "Màn hình": "6.1 inch", "Cảm ứng": "Đa điểm", "Mặt kính cảm ứng": "Kính cường lực", "Camera sau": "Kép 12MP + 12MP", "Quay phim": "Có", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Chụp chế độ ban đêmChạm lấy nétChế độ ánh sáng yếuTự động lấy nét", "Camera trước": "12 MP", "Videocall": "Có", "Thông tin khác": "Tự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS13", "CPU": "A13 Bionic", "Số nhân": "6 nhân", "Tốc độ tối đa": "2.66 GHz", "RAM": "4 GB", "Bộ nhớ": "64 GB", "Băng tần 2G": "Có", "Băng tần 3G": "Có", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Có", "GPS": "Có", "Bluetooth": "Có", "NFC": "Có", "Cổng kết nối/sạc": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung nhôm, mặt lưng kính", "Dung lượng pin": "3110 mAh", "Tính năng đặc biệt": "Bảo mật vân tayMở khóa bằng khuôn mặt", "Xem phim": "Có", "Nghe nhạc": "Có", "Chức năng khác": "Mặt kính 2.5DMở khóa bằng vân tayMở khóa bằng khuôn mặtSạc pin nhanh", "Bảo hành": "\n12 tháng\n", "price": "\n11.990.000 ₫\n21.990.000 ₫\n\r\n                Tiết kiệm (45%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen", "url": "https://mediamart.vn/smartphones/dien-thoai-galaxy-a13-4g-128g-a135f-den", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-galaxy-a13-4g128g-a135f-den_2b9b765c.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nA13\n", "Công nghệ màn hình": "TFT LCD", "Độ phân giải": "Full HD+ (1080x2408 pixels)", "Màn hình": "6.6 inch", "Mặt kính cảm ứng": "Kính cường lực Corning Gorilla Glass 5", "Tần số quét": "60Hz", "Camera sau": "Chính 50 MP & Phụ 5 MP, 2 MP, 2 MP", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Ban đêm (Night Mode)Góc rộng (Wide)Góc siêu rộng (Ultrawide)HDRLấy nét theo pha (PDAF)Siêu cận (Macro)Toàn cảnh (Panorama)Xóa phông", "Camera trước": "8MP", "Hệ điều hành": "Android 12", "CPU": "Exynos 850", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Chip đồ họa (GPU)": "Mali-G52", "RAM": "4 GB", "Bộ nhớ": "128 GB", "Thẻ nhớ ngoài": "MicroSD", "Hỗ trợ 4G": "Có", "Số khe sim": "2 Nano Sim", "Wifi": "802.11 a/b/g/n/ac", "GPS": "BEIDOU", "Bluetooth": "V5.0", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Thiết kế": "Nguyên khối", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "Pin khủngBảo mật vân tay", "Bảo hành": "\n12 tháng\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n3.790.000 ₫\n5.190.000 ₫\n\r\n                Tiết kiệm (26%)\r\n            \n"}
# {"name": "Apple iphone 11 128G Black", "url": "https://mediamart.vn/smartphones/apple-iphone-11-128g-black", "image_link": "https://cdn.mediamart.vn/thumb/images/product/-kx3E3U.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\niphone 11\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "Retina", "Độ phân giải": "1792 x 828 pixels", "Màn hình": "6.1 inch", "Cảm ứng": "Đa điểm", "Mặt kính cảm ứng": "Kính cường lực", "Camera sau": "Kép 12MP + 12MP", "Quay phim": "Có", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Chụp chế độ ban đêmChạm lấy nétChế độ ánh sáng yếuTự động lấy nét", "Camera trước": "12 MP", "Videocall": "Có", "Thông tin khác": "Tự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS13", "CPU": "A13 Bionic", "Số nhân": "6 nhân", "Tốc độ tối đa": "2.66 GHz", "RAM": "4 GB", "Bộ nhớ": "128 GB", "Băng tần 2G": "Có", "Băng tần 3G": "Có", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Có", "GPS": "Có", "Bluetooth": "Có", "NFC": "Có", "Cổng kết nối/sạc": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung nhôm, mặt lưng kính", "Dung lượng pin": "3110 mAh", "Tính năng đặc biệt": "Bảo mật vân tayMở khóa bằng khuôn mặt", "Xem phim": "Có", "Nghe nhạc": "Có", "Chức năng khác": "Mặt kính 2.5DMở khóa bằng khuôn mặtMở khóa bằng vân taySạc pin nhanh", "Bảo hành": "\n12 tháng\n", "price": "\n13.690.000 ₫\n23.990.000 ₫\n\r\n                Tiết kiệm (42%)\r\n            \n"}
# {"name": "Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ", "url": "https://mediamart.vn/smartphones/dien-thoai-oppo-cph2325-a55-den-manh-me", "image_link": "https://cdn.mediamart.vn/thumb/images/product/dien-thoai-oppo-cph2325-a55-den-manh-me-qZC39z.jpg", "Thương hiệu": "\nOppo\n", "Mã sản phẩm": "\nA55\n", "Công nghệ màn hình": "IPS LCD", "Độ phân giải": "700 x 1600 Pixel", "Màn hình": "6.51 inch", "Cảm ứng": "Đa điểm", "Mặt kính cảm ứng": "Kính cường lực Dinorex™ Glass", "Tần số quét": "60Hz", "Camera sau": "Chính 50 MP & Phụ 2 MP, 2 MP", "Quay phim": "Quay phim FHD (1920 x 1080)@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChế độ chụp ảnh chuyên nghiệpA.I CameraLàm đẹpChụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétTự động lấy nétXoá phông", "Camera trước": "16 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngQuay video Full HDHDRTự động lấy nétLàm đẹpNhận diện khuôn mặt", "Hệ điều hành": "Android 11", "CPU": "Helio G35", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.3 Ghz", "Chip đồ họa (GPU)": "PowerVR GE8320", "RAM": "4 GB", "Bộ nhớ": "64 GB", "Thẻ nhớ ngoài": "MicroSD", "Hỗ trợ thẻ tối đa": "256 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Dual-bandWi-Fi DirectWi-Fi hotspotWi-Fi 802.11 a/b/g/n/ac", "GPS": "BDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "3 camera sauBảo mật vân tayPin khủng", "Chức năng khác": "Mở khoá vân tay cạnh viềnMở khóa bằng khuôn mặt", "Bảo hành": "\n12 tháng\n", "price": "\n4.390.000 ₫\n5.190.000 ₫\n\r\n                Tiết kiệm (15%)\r\n            \n"}
# {"name": "Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá", "url": "https://mediamart.vn/smartphones/dien-thoai-xiaomi-redmi-9a-2-32-xanh-la", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-xiaomi-redmi-9a-232-xanh-la_180be925.jpg", "Thương hiệu": "\nXiaomi\n", "Mã sản phẩm": "\nRedmi 9A\n", "Hộp máy gồm": "Sách hướng dẫnCáp Micro USBCây lấy simCủ sạc nhanh rời đầu Type A", "Công nghệ màn hình": "IPS LCD", "Độ phân giải": "700 x 1600 Pixel", "Màn hình": "6.53 inch", "Cảm ứng": "Đa điểm", "Mặt kính cảm ứng": "Kính cường lực Gorilla Glass 3", "Camera sau": "13 MP", "Quay phim": "Quay phim FullHD 1080p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRA.I CameraNhận diện khuôn mặtChạm lấy nétTự động lấy nétChụp ảnh xóa phông", "Camera trước": "5 MP", "Thông tin khác": "Chế độ làm đẹpChụp xóa phôngQuay video Full HDHDRNhận diện khuôn mặt", "Hệ điều hành": "Android 10.0", "CPU": "Helio G25", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.0 Ghz", "Chip đồ họa (GPU)": "PowerVR GE8320", "RAM": "2 GB", "Bộ nhớ": "32 GB", "Thẻ nhớ ngoài": "Hỗ trợ tối đa 512 GB", "Hỗ trợ thẻ tối đa": "512 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Wifi 802.11 a/b/g/nWi-Fi DirectWi-Fi hotspot", "GPS": "BDSGLONASSA-GPS", "Bluetooth": "LEA2DP", "Cổng kết nối/sạc": "Micro USB", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "Pin khủng", "Xem phim": "H.265MP4H.264(MPEG4-AVC)", "Nghe nhạc": "FLACMP3AACWAV", "Ghi âm": "Có", "Radio": "Có", "Chức năng khác": "Mở khóa bằng khuôn mặt", "Bảo hành": "\n18 Tháng\n", "price": "\n2.290.000 ₫\n2.990.000 ₫\n\r\n                Tiết kiệm (23%)\r\n            \n"}
# {"name": "Apple Iphone 13 Pro Max 128G Blue", "url": "https://mediamart.vn/smartphones/apple-iphone-13-pro-max-128g-blue", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-max-128g-blue-Q8TaJN.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13 Pro Max\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1284 x 2778 pixels", "Màn hình": "6.7 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "120Hz", "Camera sau": "12MP + 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcSiêu cận (Macro)Chụp chế độ ban đêmChạm lấy nétGóc siêu rộngNhận diện khuôn mặtChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseẢnh RawChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "6 GB", "Bộ nhớ": "128 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "3 camera sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiMở khóa bằng khuôn mặtGhi âm cuộc gọiSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n28.990.000 ₫\n34.990.000 ₫\n\r\n                Tiết kiệm (17%)\r\n            \n"}
# {"name": "Điện thoại Xiaomi REDMI 9C (3+64) Xám", "url": "https://mediamart.vn/smartphones/dien-thoai-xiaomi-redmi-9c-3-64-xam", "image_link": "https://cdn.mediamart.vn/thumb/images/product/dien-thoai-xiaomi-redmi-9c-364-xam-SK4s0w.jpg", "Thương hiệu": "\nXiaomi\n", "Mã sản phẩm": "\nRedmi 9C\n", "Công nghệ màn hình": "IPS LCD", "Độ phân giải": "720 x 1600 Pixel", "Màn hình": "6.53 inch", "Cảm ứng": "Đa điểm", "Mặt kính cảm ứng": "Kính cường lực Gorilla Glass 3", "Tần số quét": "60Hz", "Camera sau": "13MP + 2MP + 2MP", "Quay phim": "Quay phim FullHD 1080p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChế độ chụp ảnh chuyên nghiệpA.I CameraSiêu cận (Macro)Làm đẹpNhận diện khuôn mặtChạm lấy nétTự động lấy nétXoá phông", "Camera trước": "5 MP", "Thông tin khác": "Chế độ làm đẹpQuay video Full HDChụp xóa phôngTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "Android 10.0", "CPU": "Helio G35", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.3 Ghz", "Chip đồ họa (GPU)": "PowerVR GE8320", "RAM": "3 GB", "Bộ nhớ": "64 GB", "Thẻ nhớ ngoài": "Hỗ trợ tối đa 512 GB", "Hỗ trợ thẻ tối đa": "512 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Wifi 802.11 a/b/g/nWi-Fi DirectWi-Fi hotspot", "GPS": "GLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Micro USB", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "Pin khủng", "Xem phim": "MP43GP", "Nghe nhạc": "MP3AAC", "Ghi âm": "Có", "Chức năng khác": "Chạm 2 lần sáng màn hìnhChặn cuộc gọiMở khóa bằng vân tayGhi âm cuộc gọiChặn tin nhắn", "Bảo hành": "\n18 Tháng\n", "price": "\n2.790.000 ₫\n3.190.000 ₫\n\r\n                Tiết kiệm (12%)\r\n            \n"}
# {"name": "Điện thoại OPPO CPH2349 - A16k Xanh thời thượng", "url": "https://mediamart.vn/smartphones/dien-thoai-oppo-cph2349-a16k-xanh-thoi-thuong", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2349---a16k-xanh-thi-thung_c868db6b.jpg", "Thương hiệu": "\nOppo\n", "Mã sản phẩm": "\nA16k\n", "Công nghệ màn hình": "IPS LCD", "Độ phân giải": "720 x 1600 Pixels", "Màn hình": "6.52 inch", "Tần số quét": "60Hz", "Camera sau": "13 MP", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRToàn cảnh (Panorama)", "Camera trước": "13 MP", "Hệ điều hành": "Android 11", "CPU": "MT6765", "Số nhân": "8 nhân", "Chip đồ họa (GPU)": "IMG PowerVR GE8320", "RAM": "3 GB", "Bộ nhớ": "32 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Có", "GPS": "BDSGLONASSGALILEO", "Bluetooth": "A2DPLEV5.0apt-X", "Cổng kết nối/sạc": "Micro USB", "Jack tai nghe": "Jack 3.5 mm", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung mặt lưng nhựa", "Dung lượng pin": "4230 mAh", "Loại pin": "Pin chuẩn Li-Po", "Bảo hành": "\n12 tháng\n", "price": "\n3.090.000 ₫\n3.990.000 ₫\n\r\n                Tiết kiệm (22%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy A23 (4G+128G) A235F Xanh", "url": "https://mediamart.vn/smartphones/dien-thoai-samsung-galaxy-a23-4g-128g-a235f-xanh", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-a23-4g128g-a235f-xanh_2eb86b98.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nA23\n", "Công nghệ màn hình": "TFT LCD", "Độ phân giải": "Full HD+ (1080 x 2408 Pixels)", "Màn hình": "6.6 inch", "Mặt kính cảm ứng": "Kính cường lực Corning Gorilla Glass 5", "Tần số quét": "90Hz", "Camera sau": "Chính 50 MP & Phụ 5 MP, 2 MP, 2MP", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Siêu cận (Macro)Lấy nét theo pha (PDAF)Góc siêu rộng (Ultrawide)Xóa phôngGóc rộng (Wide)", "Camera trước": "8 MP", "Hệ điều hành": "Android 12", "CPU": "Snapdragon 680", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Chip đồ họa (GPU)": "Adreno 610", "RAM": "4 GB", "Bộ nhớ": "128 GB", "Thẻ nhớ ngoài": "MicroSD", "Hỗ trợ 4G": "Có", "Số khe sim": "2 Nano Sim", "Wifi": "802.11 a/b/g/n/acDual-band (2.4 GHz/5 GHz)Direct", "GPS": "GALILEOBEIDOUQZSSGLONASS", "Bluetooth": "V5.0", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Tính năng đặc biệt": "Mở khoá vân tay cạnh viềnSạc pin nhanhPin khủng", "Bảo hành": "\n12 tháng\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n4.990.000 ₫\n6.190.000 ₫\n\r\n                Tiết kiệm (19%)\r\n            \n"}
# {"name": "Điện thoại OPPO CPH2269 - A16 3GB Đen Mạnh Mẽ", "url": "https://mediamart.vn/smartphones/dien-thoai-oppo-cph2269-a16-3gb-den-manh-me", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2269---a16-3gb-den-mnh-m_4e804f0c.jpg", "Thương hiệu": "\nOppo\n", "Mã sản phẩm": "\nA16\n", "Công nghệ màn hình": "IPS LCD", "Độ phân giải": "720 x 1600 Pixels", "Màn hình": "6.52 inch", "Tần số quét": "60Hz", "Camera sau": "Chính 13 MP & Phụ 2 MP, 2 MP", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Toàn cảnh (Panorama)HDR", "Camera trước": "8 MP", "Hệ điều hành": "Android 11", "CPU": "Helio G35", "Số nhân": "8 nhân", "Chip đồ họa (GPU)": "IMG PowerVR GE8320", "RAM": "3 GB", "Bộ nhớ": "32 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "802.11 a/b/g/n", "GPS": "GLONASSBDS", "Bluetooth": "V5.0LEA2DP", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Bảo hành": "\n12 tháng\n", "price": "\n3.690.000 ₫\n4.490.000 ₫\n\r\n                Tiết kiệm (17%)\r\n            \n"}
# {"name": "Apple Iphone 13 128G Pink", "url": "https://mediamart.vn/smartphones/apple-iphone-13-128g-pink", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-128g-pink-Dc4VHr.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1170 x 2532 pixels", "Màn hình": "6.1 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "60Hz", "Camera sau": "Kép 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcChụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "4 GB", "Bộ nhớ": "128 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "Camera Kép sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiGhi âm cuộc gọiMở khóa bằng khuôn mặtSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n20.490.000 ₫\n25.990.000 ₫\n\r\n                Tiết kiệm (21%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy A12 SM A127F Blue (Exynos850)", "url": "https://mediamart.vn/smartphones/dien-thoai-samsung-galaxy-a12-sm-a127f-blue-exynos850", "image_link": "https://cdn.mediamart.vn/thumb/images/product/dien-thoai-samsung-galaxy-a12-sm-a127f-blue-exynos850-K4jcUI.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nA12\n", "Hộp máy gồm": "Sách hướng dẫnCáp Type CCây lấy simCủ sạc nhanh rời đầu Type A", "Công nghệ màn hình": "TFT LCD", "Độ phân giải": "720 x 1600 Pixel", "Màn hình": "6.5 inch", "Cảm ứng": "Đa điểm", "Mặt kính cảm ứng": "Kính cường lực", "Camera sau": "Chính 48 MP & Phụ 5 MP, 2 MP, 2 MP", "Quay phim": "Quay video Full HD", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétTự động lấy nétNhận diện nụ cườiChụp góc rộngPanoramaChụp ảnh xóa phôngXoá phông", "Camera trước": "8 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Tự động cân bằng sángChụp xóa phôngQuay video Full HDHDRPanoramaTự động lấy nétCamera góc rộngNhận diện khuôn mặt", "Hệ điều hành": "Android 10.0", "CPU": "Exynos 850", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "RAM": "4 GB", "Bộ nhớ": "128 GB", "Thẻ nhớ ngoài": "Hỗ trợ tối đa 1TB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Wifi 802.11 a/b/g/nWi-Fi hotspot", "GPS": "BDSGALILEOGLONASSA-GPS", "Bluetooth": "V5.0", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Tính năng đặc biệt": "4 camera sauBảo mật vân tayPin khủng", "Xem phim": "MP4AVI", "Nghe nhạc": "MP3WAV", "Ghi âm": "Có", "Chức năng khác": "Chặn cuộc gọiMở khóa bằng vân taySạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n3.290.000 ₫\n4.490.000 ₫\n\r\n                Tiết kiệm (26%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy A03 3+32GB Đen", "url": "https://mediamart.vn/smartphones/dien-thoai-samsung-galaxy-a03-3-32gb-den", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-a03s-64g-den_bce3bcea.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nA03\n", "Công nghệ màn hình": "PLS LCD", "Độ phân giải": "720 x 1600 Pixel", "Màn hình": "6.5 inch", "Tần số quét": "60Hz", "Camera sau": "Chính 48 MP & Phụ 2 MP", "Quay phim": "Quay video Full HD", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRXoá phông", "Camera trước": "5 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Hệ điều hành": "Android 11", "CPU": "Unisoc T606", "Tốc độ tối đa": "1.6 Ghz", "Chip đồ họa (GPU)": "Mali-G57", "RAM": "3 GB", "Bộ nhớ": "32 GB", "Thẻ nhớ ngoài": "Hỗ trợ tối đa 1TB", "Hỗ trợ thẻ tối đa": "1 TB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Loại Sim": "Nano SIM", "Wifi": "Wi-Fi DirectWifi 802.11 a/b/g/nWi-Fi hotspot", "GPS": "GLONASSA-GPSBDSGALILEO", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "Pin khủng", "Bảo hành": "\n12 tháng\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n2.890.000 ₫\n3.490.000 ₫\n\r\n                Tiết kiệm (17%)\r\n            \n"}
# {"name": "Apple Iphone 13 Pro Max 256G Blue", "url": "https://mediamart.vn/smartphones/apple-iphone-13-pro-max-256g-blue", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-max-256g-blue-lH4dGm.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13 Pro Max\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1284 x 2778 pixels", "Màn hình": "6.7 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "120Hz", "Camera sau": "12MP + 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcSiêu cận (Macro)Chụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseẢnh RawChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "6 GB", "Bộ nhớ": "256 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "3 camera sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiMở khóa bằng khuôn mặtGhi âm cuộc gọiSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n32.490.000 ₫\n38.990.000 ₫\n\r\n                Tiết kiệm (16%)\r\n            \n"}
# {"name": "Điện thoại Realme C11 2021 (2-32) Xanh", "url": "https://mediamart.vn/smartphones/dien-thoai-realme-c11-2021-2-32-xanh", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c11-2021-2-32-xanh_92fa02c1.jpg", "Thương hiệu": "\nRealme\n", "Mã sản phẩm": "\nC11\n", "Hộp máy gồm": "Sách hướng dẫnCủ sạc rời đầu Type ACây lấy simCáp Micro USB", "Công nghệ màn hình": "LCD", "Độ phân giải": "720 x 1600 Pixel", "Màn hình": "6.5 inch", "Mặt kính cảm ứng": "Kính cường lực", "Tần số quét": "60Hz", "Camera sau": "8 MP", "Quay phim": "Quay phim FHD (1920 x 1080)@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Nhận diện khuôn mặtPanoramaTự động lấy nétLàm đẹpTime-LapseXoá phôngChạm lấy nétHDRA.I Camera", "Camera trước": "5 MP", "Thông tin khác": "Nhận diện khuôn mặtChụp xóa phôngLàm đẹpHDRTự động lấy nét", "Hệ điều hành": "Android 11", "CPU": "Spreadtrum SC9863A", "Số nhân": "8 nhân", "Chip đồ họa (GPU)": "IMG PowerVR GE8322", "RAM": "2 GB", "Bộ nhớ": "32 GB", "Số khe sim": "2 Nano Sim", "Wifi": "Wi-Fi hotspotWi-Fi DirectWifi 802.11 a/b/g/n", "GPS": "A-GPSBDSGLONASS", "Bluetooth": "V4.2A2DPLE", "Cổng kết nối/sạc": "Micro USB", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "Pin khủng", "Chức năng khác": "Mở khóa bằng khuôn mặt", "Bảo hành": "\n12 tháng\n", "price": "\n2.590.000 ₫\n3.190.000 ₫\n\r\n                Tiết kiệm (18%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy S22+ S906E 5G (8+128G) Đen Phantom", "url": "https://mediamart.vn/smartphones/dien-thoai-samsung-galaxy-s22-s906e-5g-8-128g-den-phantom", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-s22-s906e-8128g-den_1fa86174.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nS22+\n", "Hộp máy gồm": "Cáp Type CCây lấy simSách hướng dẫn", "Công nghệ màn hình": "Dynamic AMOLED 2X", "Độ phân giải": "1080 x 2340 pixels", "Màn hình": "6.6 inch", "Mặt kính cảm ứng": "Kính cường lực Corning Gorilla Glass Victus+", "Camera sau": "Chính 50 MP & Phụ 12 MP, 10 MP", "Quay phim": "Quay video Full HD", "Chụp ảnh nâng cao": "HDRChế độ Slow MotionTự động lấy nétChế độ ánh sáng yếuXoá phôngPanoramaTime-LapseChụp ảnh xóa phôngLấy nét theo phaChụp góc rộngNhận diện nụ cườiChạm lấy nétChế độ chụp ảnh chuyên nghiệpLàm đẹp thông minhSuper Slow motion (quay siêu chậm)Góc siêu rộngChụp ảnh bằng giọng nóiNhận diện khuôn mặtChụp phơi sángTự động lấy nét kép dự đoánChống rung quang họcA.I CameraChụp ảnh nhanhChụp chế độ ban đêm", "Camera trước": "10 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Tự động lấy nétPanoramaQuét mống mắtAI CameraNhận diện khuôn mặtLàm đẹpĐèn Flash trợ sángCamera góc rộngChống rungTự động cân bằng sángMở khóa bằng vân tayHDRChụp xóa phôngChế độ làm đẹp", "Hệ điều hành": "Android 12", "CPU": "Snapdragon 8 Gen 1", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Chip đồ họa (GPU)": "Adreno 730", "RAM": "8 GB", "Bộ nhớ": "128 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "2 Nano Sim", "Wifi": "Wi-Fi hotspotWi-Fi DirectWi-Fi 802.11 a/b/g/n/ac/6eDual-band", "GPS": "GALILEOGLONASSA-GPSBDS", "Bluetooth": "LEV5.2A2DP", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Type-C", "Kết nối khác": "OTGNFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại & Mặt lưng kính", "Chống nước": "IP68", "Dung lượng pin": "4500 mAh", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "Chuẩn chống nước IP685GMở khóa bằng khuôn mặt3 camera sauBảo mật vân tay", "Chức năng khác": "Dual AppGhi âm cuộc gọiSạc pin không dâyMở khóa bằng vân tayChặn tin nhắnSạc pin nhanhDolby Audio™Đèn pinChống nướcSefie tạo ra Phiên bản tương tác thực tế ảoMở khóa bằng khuôn mặtSạc pin cho thiết bị khácChặn cuộc gọiHỗ trợ sạc nhanh VOOCChống bụi", "Bảo hành": "\n12 Tháng\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n22.990.000 ₫\n26.490.000 ₫\n\r\n                Tiết kiệm (13%)\r\n            \n"}
# {"name": "APPLE iPhone 12 64G Black (2020)", "url": "https://mediamart.vn/smartphones/apple-iphone-12-64g-2020", "image_link": "https://cdn.mediamart.vn/thumb/images/product/-jjxE0x.png", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 12\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1170 x 2532 pixels", "Màn hình": "6.1 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Camera sau": "Kép 12MP + 12MP", "Quay phim": "Quay phim 4K", "Chụp ảnh nâng cao": "Chụp chế độ ban đêmChạm lấy nétChế độ ánh sáng yếuTự động lấy nét", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Tự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 14", "CPU": "A14 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Bộ nhớ": "64 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi hotspot", "GPS": "QZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "V5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung nhôm, mặt lưng kính", "Dung lượng pin": "2815 mAh", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "Camera Kép sauBảo mật vân tayMở khóa bằng khuôn mặt5G", "Chức năng khác": "Mở khóa bằng khuôn mặtMở khóa bằng vân taySạc pin nhanh", "Bảo hành": "\n12 tháng\n", "price": "\n16.990.000 ₫\n24.990.000 ₫\n\r\n                Tiết kiệm (32%)\r\n            \n"}
# {"name": "Apple Iphone 13 Pro 128G Silver", "url": "https://mediamart.vn/smartphones/apple-iphone-13-pro-128g-silver", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-128g-silver-ThXqdD.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13 Pro\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1170 x 2532 pixels", "Màn hình": "6.1 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "120Hz", "Camera sau": "12MP + 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcSiêu cận (Macro)Chụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseẢnh RawChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "6 GB", "Bộ nhớ": "128 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "3 camera sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiMở khóa bằng khuôn mặtGhi âm cuộc gọiSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n26.490.000 ₫\n31.990.000 ₫\n\r\n                Tiết kiệm (17%)\r\n            \n"}
# {"name": "Điện thoại OPPO CPH2237 - Reno 6Z 5G Đen", "url": "https://mediamart.vn/smartphones/dien-thoai-oppo-cph2237-reno-6z-5g-den", "image_link": "https://cdn.mediamart.vn/thumb/images/product/-Av3Z59.jpg", "Thương hiệu": "\nOppo\n", "Mã sản phẩm": "\nReno 6Z\n", "Công nghệ màn hình": "Super AMOLED", "Độ phân giải": "1080 x 2400 pixels", "Màn hình": "6.43 inch", "Mặt kính cảm ứng": "Kính cường lực", "Camera sau": "64MP + 8MP + 2MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Camera trước": "32MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Hệ điều hành": "Android 11", "CPU": "Dimensity 800U", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.4 GHz", "Chip đồ họa (GPU)": "Mali-G57 MC3", "RAM": "8 GB", "Bộ nhớ": "128 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "2 Nano Sim", "Wifi": "Dual-bandWi-Fi DirectWi-Fi hotspotWi-Fi 802.11 a/b/g/n/ac", "GPS": "BDSGALILEOGLONASSA-GPS", "Bluetooth": "V5.1LEapt-XA2DP", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTGNFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Dung lượng pin": "4310 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "3 camera sauBảo mật vân tay5G", "Chức năng khác": "Chặn cuộc gọiMở khóa bằng vân tayChặn tin nhắnSạc pin nhanh", "Bảo hành": "\n12 Tháng\n", "Xuất xứ": "\nTrung Quốc\n", "price": "\n7.490.000 ₫\n9.990.000 ₫\n\r\n                Tiết kiệm (25%)\r\n            \n"}
# {"name": "Điện thoại OPPO CPH2363 - Reno7 4G Đen", "url": "https://mediamart.vn/smartphones/dien-thoai-oppo-cph2363-reno7-4g-den", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2363---reno7-4g-den_d0653b5b.jpg", "Thương hiệu": "\nOppo\n", "Mã sản phẩm": "\nReno7\n", "Công nghệ màn hình": "AMOLED", "Độ phân giải": "1080 x 2400 pixels", "Màn hình": "6.4 inch", "Mặt kính cảm ứng": "Corning Gorilla Glass 5", "Camera sau": "Chính 64 MP & Phụ 2 MP, 2 MP", "Quay phim": "FullHD 1080p@30fps", "Chụp ảnh nâng cao": "Trôi nhanh thời gian (Time Lapse)Toàn cảnh (Panorama)Siêu cận (Macro)Quay chậm (Slow Motion)Nhãn dán (AR Stickers)Làm đẹpHDRChuyên nghiệp (Pro)Xóa phôngBan đêm (Night Mode)", "Camera trước": "32MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp đêmLàm đẹp A.ITrôi nhanh thời gian (Time Lapse)Toàn cảnh (Panorama)Chân dung đêmNhãn dán (AR Stickers)", "Hệ điều hành": "Android 12", "CPU": "Snapdragon 680", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.4 GHz", "Chip đồ họa (GPU)": "Adreno 610", "RAM": "8 GB", "Bộ nhớ": "128 GB", "Số khe sim": "2 Nano Sim", "Wifi": "Dual-band802.11 a/b/g/n/ac", "GPS": "BDSGLONASSA-GPS", "Bluetooth": "V5.1", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung nhựa & Mặt lưng thuỷ tinh hữu cơ", "Dung lượng pin": "4500 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "3 camera sauBảo mật vân tay", "Chức năng khác": "Chặn cuộc gọiChặn tin nhắnSạc pin nhanhMở khóa bằng vân tay", "Bảo hành": "\n12 Tháng\n", "Xuất xứ": "\nTrung Quốc\n", "price": "\n8.290.000 ₫\n9.490.000 ₫\n\r\n                Tiết kiệm (12%)\r\n            \n"}
# {"name": "Điện thoại Realme C21-Y (4-64) Đen", "url": "https://mediamart.vn/smartphones/dien-thoai-realme-c21-y-4-64-den", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c21-y-4-64-den_a26fb29e.jpg", "Thương hiệu": "\nRealme\n", "Mã sản phẩm": "\nC21-Y\n", "Công nghệ màn hình": "IPS LCD", "Độ phân giải": "720 x 1600 Pixels", "Màn hình": "6.5 inch", "Tần số quét": "60Hz", "Camera sau": "Chính 13 MP & Phụ 2 MP, 2 MP", "Quay phim": "FullHD 1080p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Tự động lấy nét (AF)Trôi nhanh thời gian (Time Lapse)Toàn cảnh (Panorama)Siêu cận (Macro)Quay chậm (Slow Motion)Nhận diện khuôn mặtLàm đẹpHDRChuyên nghiệp (Pro)Xóa phôngĐơn sắc trắng đen (Black White)Chạm lấy nétBan đêm (Night Mode)", "Camera trước": "5 MP", "Thông tin khác": "Xóa phôngTự động lấy nét (AF)Nhận diện khuôn mặtLàm đẹpHDR", "Hệ điều hành": "Android 11", "CPU": "Spreadtrum T610", "Số nhân": "8 nhân", "Chip đồ họa (GPU)": "Mali-G52", "RAM": "4 GB", "Bộ nhớ": "64 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Wi-Fi hotspotWi-Fi DirectWi-Fi 802.11 b/g/n", "GPS": "Có", "Bluetooth": "V5.0", "Cổng kết nối/sạc": "Micro USB", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Chức năng khác": "Mở khoá khuôn mặt", "Bảo hành": "\n12 tháng\n", "price": "\n3.790.000 ₫\n4.490.000 ₫\n\r\n                Tiết kiệm (15%)\r\n            \n"}
# {"name": "Điện thoại Realme C21-Y (3-32) Đen", "url": "https://mediamart.vn/smartphones/dien-thoai-realme-c21-y-3-32-den", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c21-y-3-32-den_2bbf4948.jpg", "Thương hiệu": "\nRealme\n", "Mã sản phẩm": "\nC21-Y\n", "Công nghệ màn hình": "IPS LCD", "Độ phân giải": "720 x 1600 Pixels", "Màn hình": "6.5 inch", "Tần số quét": "60Hz", "Camera sau": "Chính 13 MP & Phụ 2 MP, 2 MP", "Quay phim": "FullHD 1080p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Ban đêm (Night Mode)Tự động lấy nét (AF)Trôi nhanh thời gian (Time Lapse)Toàn cảnh (Panorama)Siêu cận (Macro)Quay chậm (Slow Motion)Nhận diện khuôn mặtLàm đẹpHDRChạm lấy nétChuyên nghiệp (Pro)Xóa phôngĐơn sắc trắng đen (Black White)", "Camera trước": "5 MP", "Thông tin khác": "HDRXóa phôngTự động lấy nét (AF)Nhận diện khuôn mặtLàm đẹp", "Hệ điều hành": "Android 11", "CPU": "Spreadtrum T610", "Số nhân": "8 nhân", "Chip đồ họa (GPU)": "Mali-G52", "RAM": "3 GB", "Bộ nhớ": "32 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Wi-Fi 802.11 b/g/nWi-Fi hotspotWi-Fi Direct", "GPS": "Có", "Bluetooth": "V5.0", "Cổng kết nối/sạc": "Micro USB", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Chức năng khác": "Mở khoá khuôn mặt", "Bảo hành": "\n12 tháng\n", "price": "\n3.290.000 ₫\n3.990.000 ₫\n\r\n                Tiết kiệm (17%)\r\n            \n"}
# {"name": "Điện thoại OPPO CPH2343 - Reno7 Z 5G Đen", "url": "https://mediamart.vn/smartphones/dien-thoai-oppo-cph2343-reno7-z-5g-den", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2343---reno7-z-5g-den_040199a5.jpg", "Thương hiệu": "\nOppo\n", "Mã sản phẩm": "\nReno7 Z\n", "Công nghệ màn hình": "AMOLED", "Độ phân giải": "1080 x 2400 pixels", "Màn hình": "6.43 inch", "Mặt kính cảm ứng": "Kính cường lực Schott Xensation UP", "Camera sau": "Chính 64 MP & Phụ 2 MP, 2 MP", "Quay phim": "FullHD 1080p@30fps", "Camera trước": "16MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Hệ điều hành": "Android 11", "CPU": "Snapdragon 695", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.2 GHz", "Chip đồ họa (GPU)": "Adreno 619", "RAM": "8 GB", "Bộ nhớ": "128 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "2 Nano Sim", "Wifi": "Dual-band802.11 a/b/g/n/ac", "GPS": "BDSGLONASSA-GPS", "Bluetooth": "V5.1", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung nhựa & Mặt lưng thuỷ tinh hữu cơ", "Dung lượng pin": "4500 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "3 camera sauBảo mật vân tay5G", "Chức năng khác": "Chặn cuộc gọiChặn tin nhắnSạc pin nhanhMở khóa bằng vân tay", "Bảo hành": "\n12 Tháng\n", "Xuất xứ": "\nTrung Quốc\n", "price": "\n9.690.000 ₫\n10.990.000 ₫\n\r\n                Tiết kiệm (11%)\r\n            \n"}
# {"name": "Điện thoại OPPO CPH2365 - A95 Bạc Phá Cách", "url": "https://mediamart.vn/smartphones/dien-thoai-oppo-cph2365-a95-bac-pha-cach", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-oppo-cph2365---a95-bc-pha-cach_f973de0e.jpg", "Thương hiệu": "\nOppo\n", "Mã sản phẩm": "\nA95\n", "Hộp máy gồm": "Cây lấy simỐp lưngCáp Type CCủ sạc nhanh Type CSách hướng dẫn", "Công nghệ màn hình": "AMOLED", "Độ phân giải": "1080 x 2400 pixels", "Màn hình": "6.43 inch", "Mặt kính cảm ứng": "Kính cường lực Schott Xensation UP", "Tần số quét": "60Hz", "Camera sau": "Chính 48 MP & Phụ 2 MP, 2 MP", "Quay phim": "FullHD 1080p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRLấy nét theo pha (PDAF)Trôi nhanh thời gian (Time Lapse)Siêu cận (Macro)Toàn cảnh (Panorama)Trôi nhanh thời gian (Time Lapse)Chuyên nghiệp (Pro)Xóa phôngAI Camera", "Camera trước": "16 MP", "Thông tin khác": "Làm đẹpQuay video Full HDToàn cảnh (Panorama)Chụp đêm", "Hệ điều hành": "Android 11", "CPU": "Snapdragon 662", "Số nhân": "8 nhân", "Nền tảng": "64 bit", "Chip đồ họa (GPU)": "Adreno 610", "RAM": "8 GB", "Bộ nhớ": "128 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Dual-band (2.4 GHz/5 GHz)Wi-Fi hotspotWi-Fi DirectWi-Fi 802.11 a/b/g/n/ac", "GPS": "GLONASSBDSGALILEO", "Bluetooth": "A2DPLEV5.0", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng thủy tinh hữu cơ", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Chức năng khác": "Mở khoá vân tay dưới màn hình", "Bảo hành": "\n12 tháng\n", "price": "\n6.490.000 ₫\n7.190.000 ₫\n\r\n                Tiết kiệm (9%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy S22 Ultra 5G S908E (8+128G) Đen Phantom", "url": "https://mediamart.vn/smartphones/dien-thoai-samsung-galaxy-s22-ultra-5g-s908e-8-128g-den-phantom", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-s22-ultra-8128g-den_4988f69b.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nS22 Ultra\n", "Hộp máy gồm": "Sách hướng dẫnCây lấy simCáp Type C", "Công nghệ màn hình": "Dynamic AMOLED 2X", "Độ phân giải": "2K+ (1440 x 3088 Pixels)", "Màn hình": "6.8 inch", "Mặt kính cảm ứng": "Kính cường lực Corning Gorilla Glass Victus+", "Camera sau": "Chính 108 MP & Phụ 12 MP, 10 MP, 10 MP", "Quay phim": "Quay video Full HD", "Chụp ảnh nâng cao": "HDRGóc siêu rộngSuper Slow motion (quay siêu chậm)Làm đẹp thông minhChế độ chụp ảnh chuyên nghiệpChụp ảnh bằng giọng nóiChụp chế độ ban đêmChụp ảnh nhanhA.I CameraChống rung quang họcTự động lấy nét kép dự đoánChụp phơi sángNhận diện khuôn mặtChạm lấy nétPanoramaXoá phôngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionNhận diện nụ cườiTime-LapseChụp góc rộngLấy nét theo phaChụp ảnh xóa phông", "Camera trước": "40 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "HDRMở khóa bằng vân tayTự động cân bằng sángChống rungChụp xóa phôngChế độ làm đẹpAI CameraQuét mống mắtPanoramaTự động lấy nétCamera góc rộngĐèn Flash trợ sángLàm đẹpNhận diện khuôn mặt", "Hệ điều hành": "Android 12", "CPU": "Snapdragon 8 Gen 1", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Chip đồ họa (GPU)": "Adreno 730", "RAM": "8 GB", "Bộ nhớ": "128 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "2 Nano Sim", "Wifi": "Wi-Fi 802.11 a/b/g/n/ac/6eDual-bandWi-Fi DirectWi-Fi hotspot", "GPS": "BDSGALILEOGLONASSA-GPS", "Bluetooth": "V5.2LEA2DP", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Type-C", "Kết nối khác": "OTGNFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại & Mặt lưng kính", "Chống nước": "IP68", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "3 camera sauBảo mật vân tay5GMở khóa bằng khuôn mặtChuẩn chống nước IP68", "Chức năng khác": "Sefie tạo ra Phiên bản tương tác thực tế ảoChống nướcChống bụiHỗ trợ sạc nhanh VOOCChặn cuộc gọiMở khóa bằng khuôn mặtSạc pin cho thiết bị khácSạc pin không dâyGhi âm cuộc gọiMở khóa bằng vân tayĐèn pinDual AppDolby Audio™Sạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 Tháng\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n26.990.000 ₫\n31.490.000 ₫\n\r\n                Tiết kiệm (14%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy A03s SM-A037 64G Xanh", "url": "https://mediamart.vn/smartphones/dien-thoai-samsung-galaxy-a03s-sma037-64g-xanh", "image_link": "https://cdn.mediamart.vn/thumb/images/product/dien-thoai-samsung-galaxy-a03s-sma037-64g-blue-1G4461.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nA03s\n", "Công nghệ màn hình": "PLS LCD", "Độ phân giải": "720 x 1600 Pixel", "Màn hình": "6.5 inch", "Mặt kính cảm ứng": "Mặt kính cong 3D", "Tần số quét": "60Hz", "Camera sau": "13MP + 2MP + 2MP", "Quay phim": "Quay video Full HD", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRSiêu cận (Macro)Làm đẹpNhận diện khuôn mặtChạm lấy nétTự động lấy nétChụp góc rộngLấy nét theo phaPanoramaXoá phông", "Camera trước": "5 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétLàm đẹpNhận diện khuôn mặt", "Hệ điều hành": "Android 11", "CPU": "Helio P35", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.3 Ghz", "Chip đồ họa (GPU)": "PowerVR GE8320", "RAM": "4 GB", "Bộ nhớ": "64 GB", "Thẻ nhớ ngoài": "Hỗ trợ tối đa 1TB", "Hỗ trợ thẻ tối đa": "1 TB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Loại Sim": "Nano SIM", "Wifi": "Wi-Fi hotspotWi-Fi DirectWifi 802.11 a/b/g/n", "GPS": "BDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "3 camera sauPin khủng", "Chức năng khác": "Mở khoá vân tay cạnh viềnMở khóa bằng khuôn mặtSạc pin nhanh", "Bảo hành": "\n12 tháng\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n3.290.000 ₫\n3.990.000 ₫\n\r\n                Tiết kiệm (17%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy Z Flip 3 F711B 5G 128GB Cream(Beige) (DM)", "url": "https://mediamart.vn/smartphones/dien-thoai-samsung-galaxy-z-flip-128gb-beige-dm", "image_link": "https://cdn.mediamart.vn/thumb/images/product/-yGw6s0.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nZ Flip\n", "Công nghệ màn hình": "Chính: Dynamic AMOLED 2X / Phụ: Super AMOLED", "Độ phân giải": "2640 x 1080 Pixels", "Màn hình": "Chính 6.7\" / Phụ 1.9\"", "Mặt kính cảm ứng": "Kính siêu mỏng Ultra Thin Glass (UTG)", "Camera sau": "Kép 12 MP", "Quay phim": "Quay video Full HD", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRSuper Slow motion (quay siêu chậm)Chế độ chụp ảnh chuyên nghiệpA.I CameraLàm đẹpChụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChống rung quang học (OIS)Chế độ Slow MotionChụp góc rộngLấy nét theo phaPanoramaXoá phông", "Camera trước": "10 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétLàm đẹpNhận diện khuôn mặt", "Hệ điều hành": "Android 11", "CPU": "Snapdragon 888", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.8 GHz", "Chip đồ họa (GPU)": "Adreno 660", "RAM": "8 GB", "Bộ nhớ": "128 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Loại Sim": "Nano SIMe Sim", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi DirectWi-Fi hotspot", "GPS": "BDSGALILEOGLONASSA-GPS", "Bluetooth": "V5.1LEA2DP", "NFC": "Có", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Type-C", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IPX8", "Dung lượng pin": "3300 mAh", "Tính năng đặc biệt": "Bảo mật vân tayMở khóa bằng khuôn mặt5G", "Chức năng khác": "Chống nướcChặn cuộc gọiMở khoá vân tay cạnh viềnLoa kép & Dolby AtmosSạc pin không dâyGhi âm cuộc gọiChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n16.990.000 ₫\n26.990.000 ₫\n\r\n                Tiết kiệm (37%)\r\n            \n"}
# ...
# {"name": "Điện thoại Realme C11 2021 (4-64) Xanh", "url": "https://mediamart.vn/smartphones/dien-thoai-realme-c11-2021-4-64-xanh", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-c11-2021-4-64-xanh_effedff5.jpg", "Thương hiệu": "\nRealme\n", "Mã sản phẩm": "\nC11\n", "Hộp máy gồm": "Củ sạc rời đầu Type ACây lấy simCáp Micro USBSách hướng dẫn", "Công nghệ màn hình": "LCD", "Độ phân giải": "720 x 1600 Pixel", "Màn hình": "6.5 inch", "Mặt kính cảm ứng": "Kính cường lực", "Tần số quét": "60Hz", "Camera sau": "8 MP", "Quay phim": "Quay phim FHD (1920 x 1080)@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "PanoramaTự động lấy nétLàm đẹpTime-LapseXoá phôngChạm lấy nétHDRA.I CameraNhận diện khuôn mặt", "Camera trước": "5 MP", "Thông tin khác": "Chụp xóa phôngLàm đẹpHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "Android 11", "CPU": "Spreadtrum SC9863A", "Số nhân": "8 nhân", "Chip đồ họa (GPU)": "IMG PowerVR GE8322", "RAM": "4 GB", "Bộ nhớ": "64 GB", "Số khe sim": "2 Nano Sim", "Wifi": "Wi-Fi DirectWifi 802.11 a/b/g/nWi-Fi hotspot", "GPS": "BDSGLONASSA-GPS", "Bluetooth": "A2DPLEV4.2", "Cổng kết nối/sạc": "Micro USB", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Tính năng đặc biệt": "Pin khủng", "Chức năng khác": "Mở khóa bằng khuôn mặt", "Bảo hành": "\n12 tháng\n", "price": "\n3.790.000 ₫\n3.990.000 ₫\n\r\n                Tiết kiệm (5%)\r\n            \n"}
# {"name": "Điện thoại Samsung Galaxy A72 256G A725F DM", "url": "https://mediamart.vn/smartphones/dien-thoai-samsung-galaxy-a72-256g-a725f-dm", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-samsung-galaxy-a72-256g-a725f-dm_5ac1a912.jpg", "Thương hiệu": "\nSamsung\n", "Mã sản phẩm": "\nA72\n", "Hộp máy gồm": "Cây lấy simCủ sạc nhanh Type CSách hướng dẫnCáp Type C - Type C", "Công nghệ màn hình": "Super AMOLED", "Độ phân giải": "1080 x 2400 pixels", "Màn hình": "6.7 inch", "Mặt kính cảm ứng": "Kính cường lực Gorilla Glass 3", "Camera sau": "Chính 64 MP & Phụ 12 MP, 8 MP, 5 MP", "Quay phim": "Quay video Full HD", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRTự động lấy nétChụp góc rộngPanoramaChụp ảnh xóa phôngXoá phôngGóc siêu rộng", "Camera trước": "32MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Tự động lấy nétNhận diện khuôn mặtChụp xóa phôngQuay video Full HD", "Hệ điều hành": "Android 11", "CPU": "Snapdragon 720G", "Số nhân": "8 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "2.3 Ghz", "Chip đồ họa (GPU)": "Adreno 618", "RAM": "8 GB", "Bộ nhớ": "256 GB", "Thẻ nhớ ngoài": "Hỗ trợ tối đa 1TB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Wi-Fi DirectWi-Fi hotspotWi-Fi 802.11 a/b/g/n/acDual-band", "GPS": "GLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "USB Type-C", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTGNFC", "Thiết kế": "Nguyên khối", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "4 camera sauPin khủng", "Chức năng khác": "Sạc pin nhanhChặn tin nhắnMở khóa bằng vân tayChặn cuộc gọiMở khóa bằng khuôn mặt", "Bảo hành": "\nTheo imei máy\n", "Xuất xứ": "\nViệt Nam\n", "price": "\n11.990.000 ₫\n"}
# {"name": "Điện thoại Realme RMX3269 - Realme C25Y (4-128) Xanh", "url": "https://mediamart.vn/smartphones/dien-thoai-realme-rmx3269-realme-c25y-4-128-xanh", "image_link": "https://cdn.mediamart.vn/thumb/images/product/din-thoi-realme-rmx3269---realme-c25y-4-128-xanh_b8926cb5.jpg", "Thương hiệu": "\nRealme\n", "Mã sản phẩm": "\nC25Y\n", "Hộp máy gồm": "Sách hướng dẫnCây lấy simCủ sạc rời đầu Type ACáp Micro USB", "Công nghệ màn hình": "IPS LCD", "Độ phân giải": "720 x 1600 Pixels", "Màn hình": "6.5 inch", "Mặt kính cảm ứng": "Kính cường lực Corning Gorilla Glass 3", "Tần số quét": "60Hz", "Camera sau": "Chính 50 MP & Phụ 2 MP, 2 MP", "Quay phim": "FullHD 1080p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "Ban đêm (Night Mode)HDRNhận diện khuôn mặtChạm lấy nétGóc rộng (Wide)Làm đẹp (Beautify)Toàn cảnh (Panorama)Trôi nhanh thời gian (Time Lapse)Tự động lấy nét (AF)Xóa phông", "Camera trước": "8 MP", "Thông tin khác": "HDRNhận diện khuôn mặtQuay video Full HDLàm đẹpTự động lấy nét (AF)Xóa phông", "Hệ điều hành": "Android 11", "CPU": "Unisoc T618", "Số nhân": "8 nhân", "Nền tảng": "64 bit", "Chip đồ họa (GPU)": "Mali-G52", "RAM": "4 GB", "Bộ nhớ": "128 GB", "Hỗ trợ 4G": "Có hỗ trợ 4G", "Số khe sim": "2 Nano Sim", "Wifi": "Wi-Fi 802.11 b/g/nWi-Fi hotspot", "GPS": "BDSGLONASS", "Bluetooth": "V5.0A2DPLE", "Cổng kết nối/sạc": "Micro USB", "Jack tai nghe": "Jack 3.5 mm", "Kết nối khác": "OTG", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Dung lượng pin": "5000 mAh", "Loại pin": "Pin chuẩn Li-Po", "Chức năng khác": "Mở khóa bằng vân tay", "Bảo hành": "\n12 tháng\n", "price": "\n4.990.000 ₫\n5.190.000 ₫\n\r\n                Tiết kiệm (3%)\r\n            \n"}
# {"name": "Apple Iphone 13 Pro 512G Blue", "url": "https://mediamart.vn/smartphones/apple-iphone-13-pro-512g-blue", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-512g-blue-Vr3KP9.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13 Pro\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1170 x 2532 pixels", "Màn hình": "6.1 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "120Hz", "Camera sau": "12MP + 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcSiêu cận (Macro)Chụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseẢnh RawChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "6 GB", "Bộ nhớ": "512 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "3 camera sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiGhi âm cuộc gọiMở khóa bằng khuôn mặtSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n38.990.000 ₫\n41.990.000 ₫\n\r\n                Tiết kiệm (7%)\r\n            \n"}
# {"name": "Apple Iphone 13 Pro 1TB Gold", "url": "https://mediamart.vn/smartphones/apple-iphone-13-pro-1tb-gold", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-1tb-gold-4ZHq8w.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13 Pro\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1170 x 2532 pixels", "Màn hình": "6.1 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "120Hz", "Camera sau": "12MP + 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcSiêu cận (Macro)Chụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseẢnh RawChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "6 GB", "Bộ nhớ": "1 TB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "3 camera sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiMở khóa bằng khuôn mặtGhi âm cuộc gọiSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n43.990.000 ₫\n44.990.000 ₫\n\r\n                Tiết kiệm (2%)\r\n            \n"}
# {"name": "Apple Iphone 13 mini 256G White", "url": "https://mediamart.vn/smartphones/apple-iphone-13-mini-256g-white", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-mini-256g-white-BHUnN6.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13 Mini\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1080 x 2340 pixels", "Màn hình": "5.4 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "60Hz", "Camera sau": "Kép 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcChụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "4 GB", "Bộ nhớ": "256 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "Camera Kép sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiMở khóa bằng khuôn mặtGhi âm cuộc gọiSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n23.990.000 ₫\n24.990.000 ₫\n\r\n                Tiết kiệm (4%)\r\n            \n"}
# {"name": "Apple Iphone 13 mini 512G Black", "url": "https://mediamart.vn/smartphones/apple-iphone-13-mini-512g-black", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-mini-512g-black-AHAi6c.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13 Mini\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1080 x 2340 pixels", "Màn hình": "5.4 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "60Hz", "Camera sau": "Kép 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcChụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "4 GB", "Bộ nhớ": "512 GB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "Camera Kép sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiGhi âm cuộc gọiMở khóa bằng khuôn mặtSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n29.990.000 ₫\n30.990.000 ₫\n\r\n                Tiết kiệm (3%)\r\n            \n"}
# {"name": "Apple Iphone 13 Pro Max 1TB Gray", "url": "https://mediamart.vn/smartphones/apple-iphone-13-pro-max-1tb-gray", "image_link": "https://cdn.mediamart.vn/thumb/images/product/apple-iphone-13-pro-max-1tb-gray-LjNrUE.jpg", "Thương hiệu": "\nApple\n", "Mã sản phẩm": "\nIphone 13 Pro Max\n", "Hộp máy gồm": "Sách hướng dẫnCáp Lightning - Type CCây lấy sim", "Công nghệ màn hình": "OLED (Super Retina HD display)", "Độ phân giải": "1284 x 2778 pixels", "Màn hình": "6.7 inch", "Mặt kính cảm ứng": "Kính cường lực Ceramic Shield", "Tần số quét": "120Hz", "Camera sau": "12MP + 12MP + 12MP", "Quay phim": "Quay phim 4K 2160p@30fps", "Đèn Flash": "Có", "Chụp ảnh nâng cao": "HDRChống rung quang họcSiêu cận (Macro)Chụp chế độ ban đêmNhận diện khuôn mặtChạm lấy nétGóc siêu rộngChế độ ánh sáng yếuTự động lấy nétChế độ Slow MotionTime-LapseẢnh RawChụp góc rộngPanoramaXoá phông", "Camera trước": "12 MP", "Videocall": "Hỗ trợ VideoCall thông qua ứng dụng OTT", "Thông tin khác": "Chụp xóa phôngHDRTự động lấy nétNhận diện khuôn mặt", "Hệ điều hành": "iOS 15", "CPU": "A15 Bionic", "Số nhân": "6 nhân", "Nền tảng": "64-bit", "Tốc độ tối đa": "3.22 GHz", "Chip đồ họa (GPU)": "Apple GPU (4-core graphics)", "RAM": "6 GB", "Bộ nhớ": "1 TB", "Hỗ Trợ 5G": "Có hỗ trợ 5G", "Số khe sim": "1 Nano SIM & 1 eSIM", "Wifi": "Dual-bandWi-Fi 802.11 a/b/g/n/ac/axWi-Fi MIMOWi-Fi hotspot", "GPS": "iBeaconQZSSBDSGALILEOGLONASSA-GPS", "Bluetooth": "LEV5.0A2DP", "Cổng kết nối/sạc": "Lightning", "Jack tai nghe": "Lightning", "Kết nối khác": "NFC", "Thiết kế": "Nguyên khối", "Chất liệu": "Khung kim loại + mặt kính cường lực", "Chống nước": "IP68", "Loại pin": "Pin chuẩn Li-Ion", "Tính năng đặc biệt": "3 camera sauChuẩn chống nước IP68Mở khóa bằng khuôn mặt5G", "Ghi âm": "microphone chuyên dụng chống ồn", "Chức năng khác": "Chống nướcNhận diện sinh trắc khuôn mặtChặn cuộc gọiMở khóa bằng khuôn mặtGhi âm cuộc gọiSạc pin nhanhChặn tin nhắn", "Bảo hành": "\n12 tháng\n", "price": "\n46.990.000 ₫\n47.990.000 ₫\n\r\n                Tiết kiệm (2%)\r\n            \n"}

# %%
import json
import pandas as pd

data_to_csv = []
with open("Media_Mart.txt", mode = "r", encoding="utf8") as f:
  for idx, line in enumerate(f):
    data = json.loads(line)
    data_to_csv.append(data)
print(data_to_csv)
# Out:
# [{'name': 'Apple Iphone 11 64G White', 'url': 'https://mediamart.vn/smartphones/apple-iphone-11-64gb-white', 'image_link': 'https://cdn.mediamart.vn/thumb/images/product/-N9QObu.jpg', 'Thương hiệu': '\nApple\n', 'Mã sản phẩm': '\nIphone 11\n', 'Hộp máy gồm': 'Sách hướng dẫnCáp Lightning - Type CCây lấy sim', 'Công nghệ màn hình': 'Retina', 'Độ phân giải': '1792 x 828 pixels', 'Màn hình': '6.1 inch', 'Cảm ứng': 'Đa điểm', 'Mặt kính cảm ứng': 'Kính cường lực', 'Camera sau': 'Kép 12MP + 12MP', 'Quay phim': 'Có', 'Đèn Flash': 'Có', 'Chụp ảnh nâng cao': 'Chụp chế độ ban đêmChạm lấy nétChế độ ánh sáng yếuTự động lấy nét', 'Camera trước': '12 MP', 'Videocall': 'Có', 'Thông tin khác': 'Tự động lấy nétNhận diện khuôn mặt', 'Hệ điều hành': 'iOS13', 'CPU': 'A13 Bionic', 'Số nhân': '6 nhân', 'Tốc độ tối đa': '2.66 GHz', 'RAM': '4 GB', 'Bộ nhớ': '64 GB', 'Băng tần 2G': 'Có', 'Băng tần 3G': 'Có', 'Hỗ trợ 4G': 'Có hỗ trợ 4G', 'Số khe sim': '1 Nano SIM & 1 eSIM', 'Wifi': 'Có', 'GPS': 'Có', 'Bluetooth': 'Có', 'NFC': 'Có', 'Cổng kết nối/sạc': 'Lightning', 'Kết nối khác': 'NFC', 'Thiết kế': 'Nguyên khối', 'Chất liệu': 'Khung nhôm, mặt lưng kính', 'Dung lượng pin': '3110 mAh', 'Tính năng đặc biệt': 'Bảo mật vân tayMở khóa bằng khuôn mặt', 'Xem phim': 'Có', 'Nghe nhạc': 'Có', 'Chức năng khác': 'Mặt kính 2.5DMở khóa bằng vân tayMở khóa bằng khuôn mặtSạc pin nhanh', 'Bảo hành': '\n12 tháng\n', 'price': '\n11.990.000 ₫\n21.990.000 ₫\n\r\n                Tiết kiệm (45%)\r\n            \n'}, {'name': 'Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen', 'url': 'https://mediamart.vn/smartphones/dien-thoai-galaxy-a13-4g-128g-a135f-den', 'image_link': 'https://cdn.mediamart.vn/thumb/images/product/din-thoi-galaxy-a13-4g128g-a135f-den_2b9b765c.jpg', 'Thương hiệu': '\nSamsung\n', 'Mã sản phẩm': '\nA13\n', 'Công nghệ màn hình': 'TFT LCD', 'Độ phân giải': 'Full HD+ (1080x2408 pixels)', 'Màn hình': '6.6 inch', 'Mặt kính cảm ứng': 'Kính cường lực Corning Gorilla Glass 5', 'Tần số quét': '60Hz', 'Camera sau': 'Chính 50 MP & Phụ 5 MP, 2 MP, 2 MP', 'Đèn Flash': 'Có', 'Chụp ảnh nâng cao': 'Ban đêm (Night Mode)Góc rộng (Wide)Góc siêu rộng (Ultrawide)HDRLấy nét theo pha (PDAF)Siêu cận (Macro)Toàn cảnh (Panorama)Xóa phông', 'Camera trước': '8MP', 'Hệ điều hành': 'Android 12', 'CPU': 'Exynos 850', 'Số nhân': '8 nhân', 'Nền tảng': '64-bit', 'Chip đồ họa (GPU)': 'Mali-G52', 'RAM': '4 GB', 'Bộ nhớ': '128 GB', 'Thẻ nhớ ngoài': 'MicroSD', 'Hỗ trợ 4G': 'Có', 'Số khe sim': '2 Nano Sim', 'Wifi': '802.11 a/b/g/n/ac', 'GPS': 'BEIDOU', 'Bluetooth': 'V5.0', 'Cổng kết nối/sạc': 'USB Type-C', 'Jack tai nghe': 'Jack 3.5 mm', 'Thiết kế': 'Nguyên khối', 'Dung lượng pin': '5000 mAh', 'Loại pin': 'Pin chuẩn Li-Po', 'Tính năng đặc biệt': 'Pin khủngBảo mật vân tay', 'Bảo hành': '\n12 tháng\n', 'Xuất xứ': '\nViệt Nam\n', 'price': '\n3.790.000 ₫\n5.190.000 ₫\n\r\n                Tiết kiệm (26%)\r\n            \n'}, {'name': 'Apple iphone 11 128G Black', 'url': 'https://mediamart.vn/smartphones/apple-iphone-11-128g-black', 'image_link': 'https://cdn.mediamart.vn/thumb/images/product/-kx3E3U.jpg', 'Thương hiệu': '\nApple\n', 'Mã sản phẩm': '\niphone 11\n', 'Hộp máy gồm': 'Sách hướng dẫnCáp Lightning - Type CCây lấy sim', 'Công nghệ màn hình': 'Retina', 'Độ phân giải': '1792 x 828 pixels', 'Màn hình': '6.1 inch', 'Cảm ứng': 'Đa điểm', 'Mặt kính cảm ứng': 'Kính cường lực', 'Camera sau': 'Kép 12MP + 12MP', 'Quay phim': 'Có', 'Đèn Flash': 'Có', 'Chụp ảnh nâng cao': 'Chụp chế độ ban đêmChạm lấy nétChế độ ánh sáng yếuTự động lấy nét', 'Camera trước': '12 MP', 'Videocall': 'Có', 'Thông tin khác': 'Tự động lấy nétNhận diện khuôn mặt', 'Hệ điều hành': 'iOS13', 'CPU': 'A13 Bionic', 'Số nhân': '6 nhân', 'Tốc độ tối đa': '2.66 GHz', 'RAM': '4 GB', 'Bộ nhớ': '128 GB', 'Băng tần 2G': 'Có', 'Băng tần 3G': 'Có', 'Hỗ trợ 4G': 'Có hỗ trợ 4G', 'Số khe sim': '1 Nano SIM & 1 eSIM', 'Wifi': 'Có', 'GPS': 'Có', 'Bluetooth': 'Có', 'NFC': 'Có', 'Cổng kết nối/sạc': 'Lightning', 'Kết nối khác': 'NFC' ...

# %%
pd.DataFrame(data_to_csv).to_csv('mediamart.csv', index = False)

# %%
df = pd.read_csv("/content/mediamart.csv", index_col=0)

# %%
df.iloc[:,60:80]
# Out:
#                                                   Chipset Số nhân CPU  \
# name
# Apple Iphone 11 64G White                             NaN          NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen     NaN          NaN
# Apple iphone 11 128G Black                            NaN          NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ             NaN          NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá             NaN          NaN
# ...                                                   ...          ...
# Apple Iphone 13 Pro 512G Blue                         NaN          NaN
# Apple Iphone 13 Pro 1TB Gold                          NaN          NaN
# Apple Iphone 13 mini 256G White                       NaN          NaN
# Apple Iphone 13 mini 512G Black                       NaN          NaN
# Apple Iphone 13 Pro Max 1TB Gray                      NaN          NaN
#
#                                                   Chip đồ họa (GPU)  \
# name
# Apple Iphone 11 64G White                                         NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen                 NaN
# Apple iphone 11 128G Black                                        NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                         NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                         NaN
# ...                                                               ...
# Apple Iphone 13 Pro 512G Blue                                     NaN
# Apple Iphone 13 Pro 1TB Gold                                      NaN
# Apple Iphone 13 mini 256G White                                   NaN
# Apple Iphone 13 mini 512G Black                                   NaN
# Apple Iphone 13 Pro Max 1TB Gray                                  NaN
#
#                                                   \nCamera\n 5 MP 2 MP  \
# name
# Apple Iphone 11 64G White                                NaN  NaN  NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen        NaN  NaN  NaN
# Apple iphone 11 128G Black                               NaN  NaN  NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                NaN  NaN  NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                NaN  NaN  NaN
# ...                                                      ...  ...  ...
# Apple Iphone 13 Pro 512G Blue                            NaN  NaN  NaN
# Apple Iphone 13 Pro 1TB Gold                             NaN  NaN  NaN
# Apple Iphone 13 mini 256G White                          NaN  NaN  NaN
# Apple Iphone 13 mini 512G Black                          NaN  NaN  NaN
# Apple Iphone 13 Pro Max 1TB Gray                         NaN  NaN  NaN
#
#                                                   Bộ nhớ trong  \
# name
# Apple Iphone 11 64G White                                  NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen          NaN
# Apple iphone 11 128G Black                                 NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                  NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                  NaN
# ...                                                        ...
# Apple Iphone 13 Pro 512G Blue                              NaN
# Apple Iphone 13 Pro 1TB Gold                               NaN
# Apple Iphone 13 mini 256G White                            NaN
# Apple Iphone 13 mini 512G Black                            NaN
# Apple Iphone 13 Pro Max 1TB Gray                           NaN
#
#                                                   Hỗ trợ thẻ nhớ tối đa  \
# name
# Apple Iphone 11 64G White                                           NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen                   NaN
# Apple iphone 11 128G Black                                          NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                           NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                           NaN
# ...                                                                 ...
# Apple Iphone 13 Pro 512G Blue                                       NaN
# Apple Iphone 13 Pro 1TB Gold                                        NaN
# Apple Iphone 13 mini 256G White                                     NaN
# Apple Iphone 13 mini 512G Black                                     NaN
# Apple Iphone 13 Pro Max 1TB Gray                                    NaN
#
#                                                   \nSIM\n Nano + Micro    2  \
# name
# Apple Iphone 11 64G White                             NaN          NaN  NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen     NaN          NaN  NaN
# Apple iphone 11 128G Black                            NaN          NaN  NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ             NaN          NaN  NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá             NaN          NaN  NaN
# ...                                                   ...          ...  ...
# Apple Iphone 13 Pro 512G Blue                         NaN          NaN  NaN
# Apple Iphone 13 Pro 1TB Gold                          NaN          NaN  NaN
# Apple Iphone 13 mini 256G White                       NaN          NaN  NaN
# Apple Iphone 13 mini 512G Black                       NaN          NaN  NaN
# Apple Iphone 13 Pro Max 1TB Gray                      NaN          NaN  NaN
#
#                                                     2G   3G   4G  \
# name
# Apple Iphone 11 64G White                          NaN  NaN  NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen  NaN  NaN  NaN
# Apple iphone 11 128G Black                         NaN  NaN  NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ          NaN  NaN  NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá          NaN  NaN  NaN
# ...                                                ...  ...  ...
# Apple Iphone 13 Pro 512G Blue                      NaN  NaN  NaN
# Apple Iphone 13 Pro 1TB Gold                       NaN  NaN  NaN
# Apple Iphone 13 mini 256G White                    NaN  NaN  NaN
# Apple Iphone 13 mini 512G Black                    NaN  NaN  NaN
# Apple Iphone 13 Pro Max 1TB Gray                   NaN  NaN  NaN
#
#                                                   Kết nối USB  \
# name
# Apple Iphone 11 64G White                                   NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen           NaN
# Apple iphone 11 128G Black                                  NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                   NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                   NaN
# ...                                                         ...
# Apple Iphone 13 Pro 512G Blue                               NaN
# Apple Iphone 13 Pro 1TB Gold                                NaN
# Apple Iphone 13 mini 256G White                             NaN
# Apple Iphone 13 mini 512G Black                             NaN
# Apple Iphone 13 Pro Max 1TB Gray                            NaN
#
#                                                   \nGiải trí & Ứng dụng\n  \
# name
# Apple Iphone 11 64G White                                             NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen                     NaN
# Apple iphone 11 128G Black                                            NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                             NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                             NaN
# ...                                                                   ...
# Apple Iphone 13 Pro 512G Blue                                         NaN
# Apple Iphone 13 Pro 1TB Gold                                          NaN
# Apple Iphone 13 mini 256G White                                       NaN
# Apple Iphone 13 mini 512G Black                                       NaN
# Apple Iphone 13 Pro Max 1TB Gray                                      NaN
#
#                                                   3GP, Mp4, MPEG4, H.263, H.264 player  \
# name
# Apple Iphone 11 64G White                                                          NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen                                  NaN
# Apple iphone 11 128G Black                                                         NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                                          NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                                          NaN
# ...                                                                                ...
# Apple Iphone 13 Pro 512G Blue                                                      NaN
# Apple Iphone 13 Pro 1TB Gold                                                       NaN
# Apple Iphone 13 mini 256G White                                                    NaN
# Apple Iphone 13 mini 512G Black                                                    NaN
# Apple Iphone 13 Pro Max 1TB Gray                                                   NaN
#
#                                                   MP3, AAC, AAC+, eAAC+, WMA, MIDI, WAV, AC3, FLAC  \
# name
# Apple Iphone 11 64G White                                                                      NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen                                              NaN
# Apple iphone 11 128G Black                                                                     NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                                                      NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                                                      NaN
# ...                                                                                            ...
# Apple Iphone 13 Pro 512G Blue                                                                  NaN
# Apple Iphone 13 Pro 1TB Gold                                                                   NaN
# Apple Iphone 13 mini 256G White                                                                NaN
# Apple Iphone 13 mini 512G Black                                                                NaN
# Apple Iphone 13 Pro Max 1TB Gray                                                               NaN
#
#                                                   Kích thước \nPIN\n
# name
# Apple Iphone 11 64G White                                  NaN     NaN
# Điện thoại Samsung Galaxy A13 (4G+128G) A135F Đen          NaN     NaN
# Apple iphone 11 128G Black                                 NaN     NaN
# Điện thoại OPPO CPH2325 - A55 Đen Mạnh Mẽ                  NaN     NaN
# Điện thoại Xiaomi REDMI 9A (2+32) Xanh lá                  NaN     NaN
# ...                                                        ...     ...
# Apple Iphone 13 Pro 512G Blue                              NaN     NaN
# Apple Iphone 13 Pro 1TB Gold                               NaN     NaN
# Apple Iphone 13 mini 256G White                            NaN     NaN
# Apple Iphone 13 mini 512G Black                            NaN     NaN
# Apple Iphone 13 Pro Max 1TB Gray                           NaN     NaN
#
# [147 rows x 20 columns]

# %%
df["Tần số quét"].isnull().sum()
# Out:
# 94

# %%
obj = df.isnull().sum()
for key,value in obj.iteritems():
    print(key.strip(),",",value)
# Out:
# url , 0
# image_link , 0
# Thương hiệu , 3
# Mã sản phẩm , 3
# Hộp máy gồm , 65
# Công nghệ màn hình , 5
# Độ phân giải , 5
# Màn hình , 6
# Cảm ứng , 108
# Mặt kính cảm ứng , 24
# Camera sau , 7
# Quay phim , 16
# Đèn Flash , 29
# Chụp ảnh nâng cao , 11
# Camera trước , 5
# Videocall , 26
# Thông tin khác , 24
# Hệ điều hành , 5
# CPU , 11
# Số nhân , 7
# Tốc độ tối đa , 60
# RAM , 2
# Bộ nhớ , 4
# Băng tần 2G , 123
# Băng tần 3G , 120
# Hỗ trợ 4G , 73
# Số khe sim , 5
# Wifi , 6
# GPS , 3
# Bluetooth , 6
# NFC , 134
# Cổng kết nối/sạc , 9
# Kết nối khác , 29
# Thiết kế , 7
# Chất liệu , 40
# Dung lượng pin , 27
# Tính năng đặc biệt , 22
# Xem phim , 112
# Nghe nhạc , 112
# Chức năng khác , 29
# Bảo hành , 5
# price , 0
# Tần số quét , 94
# Nền tảng , 27
# Chip đồ họa (GPU) , 33
# Thẻ nhớ ngoài , 82
# Jack tai nghe , 23
# Loại pin , 30
# Xuất xứ , 90
# Hỗ trợ thẻ tối đa , 99
# Ghi âm , 96
# Radio , 122
# Hỗ Trợ 5G , 88
# Chống nước , 106
# Loại Sim , 105
# Màn hình , 144
# IPS LCD , 144
# 16M colors , 144
# 640 x 480 pixels , 144
# 5 inch , 144
# Chipset , 144
# Số nhân CPU , 144
# Chip đồ họa (GPU) , 144
# Camera , 144
# 5 MP , 144
# 2 MP , 144
# Bộ nhớ trong , 144
# Hỗ trợ thẻ nhớ tối đa , 144
# SIM , 144
# Nano + Micro , 144
# 2 , 144
# 2G , 144
# 3G , 144
# 4G , 144
# Kết nối USB , 144
# Giải trí & Ứng dụng , 144
# 3GP, Mp4, MPEG4, H.263, H.264 player , 144
# MP3, AAC, AAC+, eAAC+, WMA, MIDI, WAV, AC3, FLAC , 144
# Kích thước , 144
# PIN , 144
# 2050mAh , 144
# Li-ion , 144
# Itel , 144
# Itel A32F , 144
# CápTai ngheSạcỐp lưng , 144
# 5.0 inch , 144
# Cảm ứng điện dung , 144
# 5.0 MP , 144
# Android 8.1 Oreo , 144
# MT6737 , 144
# 1.3 GHz , 144
# Mali-T720MP2 , 144
# 1 GB , 144
# 8 GB , 144
# 32 GB , 144
# 1 Nano + 1 Micro , 144
# Có , 144
# CóA-GPS , 144
# Micro USB , 144
# 2050 mAh , 144
# Pin chuẩn Li-Ion , 144

# %%
import pandas as pd

# %%
df = pd.read_csv("./mediamart.csv", index_col=0)

# %%
for key, value in df.isnull().sum().sort_values().items():
    print(key.strip(),"\t", value)
# Out:
# url 	 0
# image_link 	 0
# price 	 0
# RAM 	 2
# GPS 	 3
# Thương hiệu 	 3
# Mã sản phẩm 	 3
# Bộ nhớ 	 4
# Công nghệ màn hình 	 5
# Độ phân giải 	 5
# Số khe sim 	 5
# Bảo hành 	 5
# Camera trước 	 5
# Hệ điều hành 	 5
# Màn hình 	 6
# Bluetooth 	 6
# Wifi 	 6
# Thiết kế 	 7
# Số nhân 	 7
# Camera sau 	 7
# Cổng kết nối/sạc 	 9
# Chụp ảnh nâng cao 	 11
# CPU 	 11
# Quay phim 	 16
# Tính năng đặc biệt 	 22
# Jack tai nghe 	 23
# Mặt kính cảm ứng 	 24
# Thông tin khác 	 24
# Videocall 	 26
# Nền tảng 	 27
# Dung lượng pin 	 27
# Đèn Flash 	 29
# Kết nối khác 	 29
# Chức năng khác 	 29
# Loại pin 	 30
# Chip đồ họa (GPU) 	 33
# Chất liệu 	 40
# Tốc độ tối đa 	 60
# Hộp máy gồm 	 65
# Hỗ trợ 4G 	 73
# Thẻ nhớ ngoài 	 82
# Hỗ Trợ 5G 	 88
# Xuất xứ 	 90
# Tần số quét 	 94
# Ghi âm 	 96
# Hỗ trợ thẻ tối đa 	 99
# Loại Sim 	 105
# Chống nước 	 106
# Cảm ứng 	 108
# Nghe nhạc 	 112
# Xem phim 	 112
# Băng tần 3G 	 120
# Radio 	 122
# Băng tần 2G 	 123
# NFC 	 134
# Cảm ứng điện dung 	 144
# 2050mAh 	 144
# Li-ion 	 144
# Itel 	 144
# Itel A32F 	 144
# CápTai ngheSạcỐp lưng 	 144
# 5.0 inch 	 144
# PIN 	 144
# 5.0 MP 	 144
# 1 GB 	 144
# MT6737 	 144
# 1.3 GHz 	 144
# Mali-T720MP2 	 144
# Kích thước 	 144
# 8 GB 	 144
# 32 GB 	 144
# 1 Nano + 1 Micro 	 144
# Có 	 144
# CóA-GPS 	 144
# Micro USB 	 144
# Android 8.1 Oreo 	 144
# MP3, AAC, AAC+, eAAC+, WMA, MIDI, WAV, AC3, FLAC 	 144
# 3G 	 144
# Giải trí & Ứng dụng 	 144
# 2050 mAh 	 144
# Màn hình 	 144
# IPS LCD 	 144
# 16M colors 	 144
# 640 x 480 pixels 	 144
# 5 inch 	 144
# Chipset 	 144
# Số nhân CPU 	 144
# Chip đồ họa (GPU) 	 144
# 3GP, Mp4, MPEG4, H.263, H.264 player 	 144
# Camera 	 144
# 2 MP 	 144
# Bộ nhớ trong 	 144
# Hỗ trợ thẻ nhớ tối đa 	 144
# SIM 	 144
# Nano + Micro 	 144
# 2 	 144
# 2G 	 144
# 4G 	 144
# Kết nối USB 	 144
# 5 MP 	 144
# Pin chuẩn Li-Ion 	 144
