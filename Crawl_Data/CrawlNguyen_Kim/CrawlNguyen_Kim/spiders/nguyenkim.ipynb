# %%
import json
import pandas as pd

# %%
with open("./details.json", mode = "r", encoding="utf8") as f:
    data = json.load(f)

# %%
pd.DataFrame(data).to_csv('nguyenkim.csv', index = False)

# %%
df = pd.read_csv("./nguyenkim.csv", index_col=0)

# %%
df
# Out:
#                                                                                       Tên sản phẩm  \
# Url
# https://www.nguyenkim.com/dien-thoai-oppo-reno6...        Điện thoại OPPO Reno6 Z 5G 8GB/128GB Bạc
# https://www.nguyenkim.com/dien-thoai-samsung-ga...     Điện thoại Samsung Galaxy A23 4GB/128GB Đen
# https://www.nguyenkim.com/dien-thoai-samsung-ga...         Điện thoại Samsung Galaxy A03s 64GB Đen
# https://www.nguyenkim.com/dien-thoai-samsung-a3...         Điện thoại Samsung A33 5G 6GB/128GB Đen
# https://www.nguyenkim.com/dien-thoai-samsung-ga...          Điện thoại Samsung Galaxy A03 32GB Đen
# ...                                                                                            ...
# https://www.nguyenkim.com/dien-thoai-samsung-ga...     Điện thoại Samsung Galaxy A22 6GB/128GB Tím
# https://www.nguyenkim.com/dien-thoai-nokia-c21-...  Điện thoại Nokia C21 Plus 3GB/32GB Xám Ánh Kim
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# Tên sản phẩm                 0
# Giá                          0
# Ảnh                          0
# Model:                       0
# Màu sắc:                     0
# Nhà sản xuất:                0
# Xuất xứ:                     0
# Thời gian bảo hành:          0
# Địa điểm bảo hành:           0
# Bộ nhớ trong:                0
# Kích thước màn hình:         1
# RAM:                         3
# Camera trước:                4
# Camera sau:                  8
# Chipset:                    16
# Loại màn hình:              20
# Dung lượng Pin:             27
# Hệ điều hành:               52
# Độ phân giải màn hình:      53
# Mở khóa nhanh:              73
# Kích thước sản phẩm:        79
# WIFI:                       81
# Bluetooth:                  83
# Đèn Flash:                  88
# GPS:                        92
# Chống nước:                 98
# USB:                        98
# Năm ra mắt :               101
# Loại SIM:                  101
# Cảm ứng:                   102
# ...
