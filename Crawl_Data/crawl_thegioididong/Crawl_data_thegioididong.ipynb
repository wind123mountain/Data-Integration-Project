# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab/20212/Data_Intergation
# Out:
# /content/drive/MyDrive/Colab/20212/Data_Intergation

# %%
import requests
from bs4 import BeautifulSoup
import lxml
import json
import csv
import pandas as pd

URL = 'https://www.thegioididong.com/dtdd/samsung-galaxy-s22-ultra'
headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}
webpage = requests.get(URL,headers=headers).content

soup = BeautifulSoup(webpage, 'html.parser')
data = json.loads(soup.find('script', id="productld").get_text()).get("additionalProperty")
name = json.loads(soup.find('script', id="productld").get_text()).get('name')

data1=json.loads(soup.find('script', id="productld").text).get("offers").get('price')
data2=json.loads(soup.find('script', id="productld").text).get("offers").get('priceValidUntil')
print(data)
print('Price :',data1)
print('priceValidUntil :',data2)

print(name)
A=[]
B=[]
i=1
for entry in data:
    #A.append(entry['name'])
    print(entry['name'],':',entry['value'])
# Out:
# [{'@type': 'PropertyValue', 'name': 'Công nghệ màn hình', 'value': 'Dynamic AMOLED 2X'}, {'@type': 'PropertyValue', 'name': 'Độ phân giải', 'value': '2K+ (1440 x 3088 Pixels)'}, {'@type': 'PropertyValue', 'name': 'Màn hình rộng', 'value': '6.8" - Tần số quét 120 Hz'}, {'@type': 'PropertyValue', 'name': 'Độ sáng tối đa', 'value': '1750 nits'}, {'@type': 'PropertyValue', 'name': 'Mặt kính cảm ứng', 'value': 'Kính cường lực Corning Gorilla Glass Victus+'}, {'@type': 'PropertyValue', 'name': 'Độ phân giải', 'value': 'Chính 108 MP & Phụ 12 MP, 10 MP, 10 MP'}, {'@type': 'PropertyValue', 'name': 'Quay phim', 'value': '4K 2160p@30fps'}, {'@type': 'PropertyValue', 'name': 'Đèn Flash', 'value': 'Đèn LED kép'}, {'@type': 'PropertyValue', 'name': 'Tính năng', 'value': 'AI Camera'}, {'@type': 'PropertyValue', 'name': 'Độ phân giải', 'value': '40 MP'}, {'@type': 'PropertyValue', 'name': 'Tính năng', 'value': 'Bộ lọc màu'}, {'@type': 'PropertyValue', 'name': 'Hệ điều hành', 'value': 'Android 12'}, {'@type': 'PropertyValue', 'name': 'Chip xử lý (CPU)', 'value': 'Snapdragon 8 Gen 1 8 nhân'}, {'@type': 'PropertyValue', 'name': 'Tốc độ CPU', 'value': '1 nhân 3 GHz, 3 nhân 2.5 GHz & 4 nhân 1.79 GHz'}, {'@type': 'PropertyValue', 'name': 'Chip đồ họa (GPU)', 'value': 'Adreno 730'}, {'@type': 'PropertyValue', 'name': 'RAM', 'value': '8 GB'}, {'@type': 'PropertyValue', 'name': 'Bộ nhớ trong', 'value': '128 GB'}, {'@type': 'PropertyValue', 'name': 'Bộ nhớ còn lại (khả dụng) khoảng', 'value': '100 GB'}, {'@type': 'PropertyValue', 'name': 'Danh bạ', 'value': 'Không giới hạn'}, {'@type': 'PropertyValue', 'name': 'Mạng di động', 'value': 'Hỗ trợ 5G'}, {'@type': 'PropertyValue', 'name': 'SIM', 'value': '2 Nano SIM hoặc 1 Nano SIM + 1 eSIM'}, {'@type': 'PropertyValue', 'name': 'Wifi', 'value': 'Dual-band (2.4 GHz/5 GHz)'}, {'@type': 'PropertyValue', 'name': 'GPS', 'value': 'BEIDOU'}, {'@type': 'PropertyValue', 'name': 'Bluetooth', 'value': 'v5.2'}, {'@type': 'PropertyValue', 'name': 'Cổng kết nối/sạc', 'value': 'Type-C'}, {'@type': 'PropertyValue', 'name': 'Jack tai nghe', 'value': 'Type-C'}, {'@type': 'PropertyValue', 'name': 'Kết nối khác', 'value': 'NFC'}, {'@type': 'PropertyValue', 'name': 'Dung lượng pin', 'value': '5000 mAh'}, {'@type': 'PropertyValue', 'name': 'Loại pin', 'value': 'Li-Ion'}, {'@type': 'PropertyValue', 'name': 'Hỗ trợ sạc tối đa', 'value': '45 W'}, {'@type': 'PropertyValue', 'name': 'Công nghệ pin', 'value': 'Sạc không dây'}, {'@type': 'PropertyValue', 'name': 'Bảo mật nâng cao', 'value': 'Mở khoá khuôn mặt'}, {'@type': 'PropertyValue', 'name': 'Tính năng đặc biệt', 'value': 'Chạm 2 lần sáng màn hình'}, {'@type': 'PropertyValue', 'name': 'Kháng nước, bụi', 'value': 'IP68'}, {'@type': 'PropertyValue', 'name': 'Ghi âm', 'value': 'Ghi âm cuộc gọi'}, {'@type': 'PropertyValue', 'name': 'Xem phim', 'value': '3GP'}, {'@type': 'PropertyValue', 'name': 'Nghe nhạc', 'value': 'AAC'}, {'@type': 'PropertyValue', 'name': 'Thiết kế', 'value': 'Nguyên khối'}, {'@type': 'PropertyValue', 'name': 'Chất liệu', 'value': 'Khung kim loại & Mặt lưng kính'}, {'@type': 'PropertyValue', 'name': 'Kích thước, khối lượng', 'value': 'Dài 163.3 mm - Ngang 77.9 mm - Dày 8.9 mm - Nặng 228 g'}, {'@type': 'PropertyValue', 'name': 'Thời điểm ra mắt', 'value': '02/2022'}]
# Price : 28990000.0
# priceValidUntil : 03/03/2022
# Điện thoại Samsung Galaxy S22 Ultra 5G 128GB
# Công nghệ màn hình : Dynamic AMOLED 2X
# Độ phân giải : 2K+ (1440 x 3088 Pixels)
# Màn hình rộng : 6.8" - Tần số quét 120 Hz
# Độ sáng tối đa : 1750 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass Victus+
# Độ phân giải : Chính 108 MP & Phụ 12 MP, 10 MP, 10 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Đèn LED kép
# Tính năng : AI Camera
# Độ phân giải : 40 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Snapdragon 8 Gen 1 8 nhân
# Tốc độ CPU : 1 nhân 3 GHz, 3 nhân 2.5 GHz & 4 nhân 1.79 GHz
# Chip đồ họa (GPU) : Adreno 730
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 100 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM hoặc 1 Nano SIM + 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : v5.2
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 45 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chạm 2 lần sáng màn hình
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng kính
# Kích thước, khối lượng : Dài 163.3 mm - Ngang 77.9 mm - Dày 8.9 mm - Nặng 228 g
# Thời điểm ra mắt : 02/2022

# %%
from typing import Text
import requests
from bs4 import BeautifulSoup
import lxml
import json
import csv
import pandas as pd

data_phones = []

Devices=["apple-iphone","samsung","oppo","xiaomi","vivo","realme","nokia","itel","masstel"]
ID=1
for i in range(len(Devices)):
  URL = 'https://www.thegioididong.com/dtdd-'+Devices[i]
  

  headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}
  webpage = requests.get(URL,headers=headers).text
  A=[]
  soup = BeautifulSoup(webpage, 'html.parser')
  data = soup.find('ul', {"class":"listproduct"})
  
  for a in data.find_all('a',href=True):
      new_str=a['href']
      new_str=new_str.replace("javascript:void(0)","")
      new_str=new_str.replace("#","")
      if new_str=="":
        continue
      if new_str=="/dtdd/poco-c40?src=osp":   #Mẫu điện thoại đang quảng cáo
        continue
      
      URL = "https://www.thegioididong.com" + new_str
      
      
      headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}
      webpage = requests.get(URL,headers=headers).text

      soup = BeautifulSoup(webpage, 'html.parser')
      data = json.loads(soup.find('script', id="productld").get_text()).get("additionalProperty")
      name = json.loads(soup.find('script', id="productld").get_text()).get('name')

      data1=json.loads(soup.find('script', id="productld").text).get("offers").get('price')
      data2=json.loads(soup.find('script', id="productld").text).get("offers").get('priceValidUntil')
      print('ID = ',ID)
      print(name)
      ID=ID+1
      print('Price :',data1)
      print('priceValidUntil :',data2)
      
      item = {}
      item['Name'] = name
      item['Price'] = data1
      item['priceValidUntil']=data2

      for entry in data:
          print(entry['name'],':',entry['value'])   
          item[entry['name']] = entry['value']

      data_phones.append(item)
# Out:
# ID =  1
# Điện thoại iPhone 11 64GB
# Price : 13790000.0
# priceValidUntil : 02/10/2019
# Công nghệ màn hình : IPS LCD
# Độ phân giải : 828 x 1792 Pixels
# Màn hình rộng : 6.1" - Tần số quét 60 Hz
# Độ sáng tối đa : 625 nits
# Mặt kính cảm ứng : Kính cường lực Oleophobic (ion cường lực)
# Độ phân giải : 2 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : 3 đèn LED 2 tông màu
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A13 Bionic
# Tốc độ CPU : 2 nhân 2.65 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 4 GB
# Bộ nhớ trong : 64 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 59 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 3110 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 18 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Tính năng đặc biệt : Apple Pay
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 150.9 mm - Ngang 75.7 mm - Dày 8.3 mm - Nặng 194 g
# Thời điểm ra mắt : 11/2019
# ID =  2
# Điện thoại iPhone 13 Pro Max 128GB
# Price : 31990000.0
# priceValidUntil : 10/18/2022
# Công nghệ màn hình : OLED
# Độ phân giải : 1284 x 2778 Pixels
# Màn hình rộng : 6.7" - Tần số quét 120 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Ceramic Shield
# Độ phân giải : 3 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A15 Bionic
# Tốc độ CPU : 3.22 GHz
# Chip đồ họa (GPU) : Apple GPU 5 nhân
# RAM : 6 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 113 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 4352 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Siêu tiết kiệm pin
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung thép không gỉ & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 160.8 mm - Ngang 78.1 mm - Dày 7.65 mm - Nặng 240 g
# Thời điểm ra mắt : 09/2021
# ID =  3
# Điện thoại iPhone 12 Pro Max 512GB
# Price : 0.0
# priceValidUntil : 09/14/2021
# Công nghệ màn hình : OLED
# Độ phân giải : 1284 x 2778 Pixels
# Màn hình rộng : 6.7" - Tần số quét 60 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Ceramic Shield
# Độ phân giải : 3 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Đèn LED kép
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A14 Bionic
# Tốc độ CPU : 2 nhân 3.1 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 6 GB
# Bộ nhớ trong : 512 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 497 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GLONASS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 3687 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung thép không gỉ & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 160.8 mm - Ngang 78.1 mm - Dày 7.4 mm - Nặng 228 g
# Thời điểm ra mắt : 10/2020
# ID =  4
# Điện thoại iPhone 13 Pro 128GB
# Price : 28790000.0
# priceValidUntil : 10/18/2022
# Công nghệ màn hình : OLED
# Độ phân giải : 1170 x 2532 Pixels
# Màn hình rộng : 6.1" - Tần số quét 120 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Ceramic Shield
# Độ phân giải : 3 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A15 Bionic
# Tốc độ CPU : 3.22 GHz
# Chip đồ họa (GPU) : Apple GPU 5 nhân
# RAM : 6 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 113 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GPS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 3095 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung thép không gỉ & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 146.7 mm - Ngang 71.5 mm - Dày 7.65 mm - Nặng 204 g
# Thời điểm ra mắt : 09/2021
# ID =  5
# Điện thoại iPhone 12 Pro 256GB
# Price : 26290000.0
# priceValidUntil : 09/14/2021
# Công nghệ màn hình : OLED
# Độ phân giải : 1170 x 2532 Pixels
# Màn hình rộng : 6.1" - Tần số quét 60 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Ceramic Shield
# Độ phân giải : 3 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Đèn LED kép
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A14 Bionic
# Tốc độ CPU : 2 nhân 3.1 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 6 GB
# Bộ nhớ trong : 256 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 241 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GPS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 2815 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung thép không gỉ & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 146.7 mm - Ngang 71.5 mm - Dày 7.4 mm - Nặng 189 g
# Thời điểm ra mắt : 10/2020
# ID =  6
# Điện thoại iPhone 13 128GB
# Price : 22590000.0
# priceValidUntil : 10/18/2022
# Công nghệ màn hình : OLED
# Độ phân giải : 1170 x 2532 Pixels
# Màn hình rộng : 6.1" - Tần số quét 60 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Ceramic Shield
# Độ phân giải : 2 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A15 Bionic
# Tốc độ CPU : 3.22 GHz
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 4 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 113 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : iBeacon
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 3240 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 146.7 mm - Ngang 71.5 mm - Dày 7.65 mm - Nặng 174 g
# Thời điểm ra mắt : 09/2021
# ID =  7
# Điện thoại iPhone 13 mini 128GB
# Price : 20090000.0
# priceValidUntil : 10/18/2022
# Công nghệ màn hình : OLED
# Độ phân giải : Full HD+ (1080 x 2340 Pixels)
# Màn hình rộng : 5.4" - Tần số quét 60 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Ceramic Shield
# Độ phân giải : 2 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A15 Bionic
# Tốc độ CPU : 3.22 GHz
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 4 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 113 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GALILEO
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 2438 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 131.5 mm - Ngang 64.2 mm - Dày 7.65 mm - Nặng 141 g
# Thời điểm ra mắt : 09/2021
# ID =  8
# Điện thoại iPhone 12 mini 64GB
# Price : 18390000.0
# priceValidUntil : 06/30/2021
# Công nghệ màn hình : OLED
# Độ phân giải : Full HD+ (1080 x 2340 Pixels)
# Màn hình rộng : 5.4" - Tần số quét 60 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Ceramic Shield
# Độ phân giải : 2 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Đèn LED kép
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A14 Bionic
# Tốc độ CPU : 2 nhân 3.1 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 4 GB
# Bộ nhớ trong : 64 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 49 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : iBeacon
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 2227 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 131.5 mm - Ngang 64.2 mm - Dày 7.4 mm - Nặng 135 g
# Thời điểm ra mắt : 10/2020
# ID =  9
# Điện thoại iPhone 12 64GB
# Price : 18290000.0
# priceValidUntil : 10/23/2020
# Công nghệ màn hình : OLED
# Độ phân giải : 1170 x 2532 Pixels
# Màn hình rộng : 6.1" - Tần số quét 60 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Ceramic Shield
# Độ phân giải : 2 camera 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Đèn LED kép
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 12 MP
# Tính năng : HDR
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A14 Bionic
# Tốc độ CPU : 2 nhân 3.1 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 4 GB
# Bộ nhớ trong : 64 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 49 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Loại pin : Li-Ion
# Dung lượng pin : 2815 mAh
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt Face ID
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : H.264(MPEG4-AVC)
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 146.7 mm - Ngang 71.5 mm - Dày 7.4 mm - Nặng 164 g
# Thời điểm ra mắt : 10/2020
# ID =  10
# Điện thoại iPhone SE 64GB (2022)
# Price : 12790000.0
# priceValidUntil : 03/09/2023
# Công nghệ màn hình : IPS LCD
# Độ phân giải : HD (750 x 1334 Pixels)
# Màn hình rộng : 4.7" - Tần số quét 60 Hz
# Độ sáng tối đa : 625 nits
# Mặt kính cảm ứng : Hãng không công bố
# Độ phân giải : 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : Có
# Tính năng : Bộ lọc màu
# Độ phân giải : 7 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A15 Bionic
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 4 GB
# Bộ nhớ trong : 64 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Wi-Fi 802.11 a/b/g/n/ac/ax
# GPS : BEIDOU
# Bluetooth : v5.0
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : NFC
# Dung lượng pin : 2018 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 20 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khóa bằng vân tay
# Kháng nước, bụi : IP67
# Ghi âm : Ghi âm mặc định
# Xem phim : AVI
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng kính
# Kích thước, khối lượng : Dài 138.4 mm - Ngang 67.3 mm - Dày 7.3 mm - Nặng 144 g
# Thời điểm ra mắt : 4/2022
# ID =  11
# Điện thoại iPhone SE 64GB (2020) (Hộp mới)
# Price : 9490000.0
# priceValidUntil : 10/28/2021
# Công nghệ màn hình : IPS LCD
# Độ phân giải : HD (750 x 1334 Pixels)
# Màn hình rộng : 4.7" - Tần số quét 60 Hz
# Độ sáng tối đa : 625 nits
# Mặt kính cảm ứng : Kính cường lực Oleophobic (ion cường lực)
# Độ phân giải : 12 MP
# Quay phim : 4K 2160p@24fps
# Đèn Flash : 4 đèn LED 2 tông màu
# Tính năng : Chạm lấy nét
# Độ phân giải : 7 MP
# Tính năng : Chống rung điện tử kỹ thuật số (EIS)
# Hệ điều hành : iOS 15
# Chip xử lý (CPU) : Apple A13 Bionic
# Tốc độ CPU : 2 nhân 2.65 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Apple GPU 4 nhân
# RAM : 3 GB
# Bộ nhớ trong : 64 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 49 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GLONASS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Lightning
# Jack tai nghe : Lightning
# Kết nối khác : OTG
# Dung lượng pin : 1821 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 18 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khóa bằng vân tay
# Kháng nước, bụi : IP67
# Ghi âm : Ghi âm mặc định
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng kính
# Kích thước, khối lượng : Dài 138.4 mm - Ngang 67.3 mm - Dày 7.3 mm - Nặng 148 g
# Thời điểm ra mắt : 10/2020
# ID =  12
# Điện thoại Samsung Galaxy S22 Ultra 5G 128GB
# Price : 28990000.0
# priceValidUntil : 03/03/2022
# Công nghệ màn hình : Dynamic AMOLED 2X
# Độ phân giải : 2K+ (1440 x 3088 Pixels)
# Màn hình rộng : 6.8" - Tần số quét 120 Hz
# Độ sáng tối đa : 1750 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass Victus+
# Độ phân giải : Chính 108 MP & Phụ 12 MP, 10 MP, 10 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Đèn LED kép
# Tính năng : AI Camera
# Độ phân giải : 40 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Snapdragon 8 Gen 1 8 nhân
# Tốc độ CPU : 1 nhân 3 GHz, 3 nhân 2.5 GHz & 4 nhân 1.79 GHz
# Chip đồ họa (GPU) : Adreno 730
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 100 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM hoặc 1 Nano SIM + 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : v5.2
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 45 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chạm 2 lần sáng màn hình
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng kính
# Kích thước, khối lượng : Dài 163.3 mm - Ngang 77.9 mm - Dày 8.9 mm - Nặng 228 g
# Thời điểm ra mắt : 02/2022
# ID =  13
# Điện thoại Samsung Galaxy A03 3GB
# Price : 2890000.0
# priceValidUntil : 12/08/2022
# Công nghệ màn hình : PLS LCD
# Độ phân giải : HD+ (720 x 1600 Pixels)
# Màn hình rộng : 6.5" - Tần số quét 60 Hz
# Độ sáng tối đa : 400 nits
# Mặt kính cảm ứng : Mặt kính cong 2.5D
# Độ phân giải : Chính 48 MP & Phụ 2 MP
# Quay phim : FullHD 1080p@30fps
# Đèn Flash : Có
# Tính năng : Chạm lấy nét
# Độ phân giải : 5 MP
# Tính năng : Làm đẹp
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : Unisoc T606 8 nhân
# Tốc độ CPU : 8 nhân 1.6 GHz
# Chip đồ họa (GPU) : Mali-G57
# RAM : 3 GB
# Bộ nhớ trong : 32 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 22 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Wi-Fi 802.11 b/g/n
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Kết nối khác : OTG
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 7.8 W
# Sạc kèm theo máy : 7.8 W
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Âm thanh Dolby Atmos
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm mặc định
# Radio : Có
# Xem phim : AVI
# Nghe nhạc : FLAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 164.2 mm - Ngang 75.9 mm - Dày 9.1 mm - Nặng 196 g
# Thời điểm ra mắt : 01/2022
# ID =  14
# Điện thoại Samsung Galaxy A52s 5G 128GB
# Price : 7990000.0
# priceValidUntil : 07/29/2022
# Công nghệ màn hình : Super AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.5" - Tần số quét 120 Hz
# Độ sáng tối đa : 800 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 64 MP & Phụ 12 MP, 5 MP, 5 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 32 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : Snapdragon 778G 5G 8 nhân
# Tốc độ CPU : 2 nhân 2.4 GHz & 6 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 642L
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 115 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM (SIM 2 chung khe thẻ nhớ)
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : QZSS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : NFC
# Dung lượng pin : 4500 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 25 W
# Sạc kèm theo máy : 15 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chạm 2 lần tắt/sáng màn hình
# Kháng nước, bụi : IP67
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 159.9 mm - Ngang 75.1 mm - Dày 8.4 mm - Nặng 189 g
# Thời điểm ra mắt : 09/2021
# ID =  15
# Điện thoại Samsung Galaxy Z Fold3 5G 256GB
# Price : 34990000.0
# priceValidUntil : 08/07/2021
# Công nghệ màn hình : Dynamic AMOLED 2X
# Độ phân giải : Full HD+ (1768 x 2208 Pixels)
# Màn hình rộng : Chính 7.6" & Phụ 6.2" - Tần số quét 120 Hz
# Độ sáng tối đa : Chính 1200 nits & Phụ 1500 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass Victus
# Độ phân giải : 3 camera 12 MP
# Quay phim : 4K 2160p@60fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 10 MP & 4 MP
# Tính năng : HDR
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : Snapdragon 888
# Tốc độ CPU : 1 nhân 2.84 GHz, 3 nhân 2.4 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 660
# RAM : 12 GB
# Bộ nhớ trong : 256 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 215 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM + 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GPS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 4400 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 25 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá vân tay cạnh viền
# Tính năng đặc biệt : Samsung Pay
# Kháng nước, bụi : IPX8
# Ghi âm : Ghi âm mặc định
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 158.2 mm - Ngang 128.1 mm - Dày 6.4 mm - Nặng 271 g
# Thời điểm ra mắt : 08/2021
# ID =  16
# Điện thoại Samsung Galaxy S22+ 5G 128GB
# Price : 23990000.0
# priceValidUntil : 06/14/2022
# Công nghệ màn hình : Dynamic AMOLED 2X
# Độ phân giải : Full HD+ (1080 x 2340 Pixels)
# Màn hình rộng : 6.6" - Tần số quét 120 Hz
# Độ sáng tối đa : 1750 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass Victus+
# Độ phân giải : Chính 50 MP & Phụ 12 MP, 10 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Đèn LED kép
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 10 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Snapdragon 8 Gen 1 8 nhân
# Tốc độ CPU : 1 nhân 3 GHz, 3 nhân 2.5 GHz & 4 nhân 1.79 GHz
# Chip đồ họa (GPU) : Adreno 730
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 100.1 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM hoặc 1 Nano SIM + 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 4500 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 45 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chạm 2 lần tắt/sáng màn hình
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng kính
# Kích thước, khối lượng : Dài 157.4 mm - Ngang 75.8 mm - Dày 7.6 mm - Nặng 195 g
# Thời điểm ra mắt : 03/2022
# ID =  17
# Điện thoại Samsung Galaxy S22 5G 128GB
# Price : 19990000.0
# priceValidUntil : 11/18/2021
# Công nghệ màn hình : Dynamic AMOLED 2X
# Độ phân giải : Full HD+ (1080 x 2340 Pixels)
# Màn hình rộng : 6.1" - Tần số quét 120 Hz
# Độ sáng tối đa : 1300 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass Victus+
# Độ phân giải : Chính 50 MP & Phụ 12 MP, 10 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Đèn LED kép
# Tính năng : AI Camera
# Độ phân giải : 10 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Snapdragon 8 Gen 1 8 nhân
# Tốc độ CPU : 1 nhân 3 GHz, 3 nhân 2.5 GHz & 4 nhân 1.79 GHz
# Chip đồ họa (GPU) : Adreno 730
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 100 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM hoặc 1 Nano SIM + 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : v5.2
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 3700 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 25 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chạm 2 lần sáng màn hình
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng kính
# Kích thước, khối lượng : Dài 146 mm - Ngang 70.6 mm - Dày 7.6 mm - Nặng 167 g
# Thời điểm ra mắt : 2/2022
# ID =  18
# Điện thoại Samsung Galaxy Z Flip3 5G 128GB
# Price : 19990000.0
# priceValidUntil : 10/13/2021
# Công nghệ màn hình : Dynamic AMOLED 2X
# Độ phân giải : Full HD+ (1080 x 2640 Pixels)
# Màn hình rộng : Chính 6.7" & Phụ 1.9" - Tần số quét 120 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính siêu mỏng Ultra Thin Glass (UTG)
# Độ phân giải : 2 camera 12 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 10 MP
# Tính năng : HDR
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : Snapdragon 888
# Tốc độ CPU : 1 nhân 2.84 GHz, 3 nhân 2.4 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 660
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 100.5 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 3300 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 15 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Ghi âm cuộc gọi
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 166 mm - Ngang 72.2 mm - Dày 6.9 mm - Nặng 183 g
# Thời điểm ra mắt : 09/2021
# ID =  19
# Điện thoại Samsung Galaxy Z Flip3 5G 128GB Flex Your Way
# Price : 19990000.0
# priceValidUntil : 05/17/2023
# Công nghệ màn hình : Dynamic AMOLED 2X
# Độ phân giải : Full HD+ (1080 x 2640 Pixels)
# Màn hình rộng : Chính 6.7" & Phụ 1.9" - Tần số quét 120 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính siêu mỏng Ultra Thin Glass (UTG)
# Độ phân giải : 2 camera 12 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 10 MP
# Tính năng : HDR
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : Snapdragon 888
# Tốc độ CPU : 1 nhân 2.84 GHz, 3 nhân 2.4 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 660
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 100.5 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 1 Nano SIM & 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 3300 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 15 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Ghi âm cuộc gọi
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng kính cường lực
# Kích thước, khối lượng : Dài 166 mm - Ngang 72.2 mm - Dày 6.9 mm - Nặng 183 g
# Thời điểm ra mắt : 05/2022
# ID =  20
# Điện thoại Samsung Galaxy Note 20
# Price : 15990000.0
# priceValidUntil : 01/31/2021
# Công nghệ màn hình : Super AMOLED Plus
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.7" - Tần số quét 60 Hz
# Độ sáng tối đa : 1050 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 12 MP & Phụ 64 MP, 12 MP
# Quay phim : 8K 4320p@24fps
# Đèn Flash : Có
# Tính năng : Quay Siêu chậm (Super Slow Motion)
# Độ phân giải : 10 MP
# Tính năng : Xóa phông
# Hệ điều hành : Android 10
# Chip xử lý (CPU) : Exynos 990
# Tốc độ CPU : 2 nhân 2.73 GHz, 2 nhân 2.5 GHz & 4 nhân 2.0 Ghz
# Chip đồ họa (GPU) : Mali-G77 MP11
# RAM : 8 GB
# Bộ nhớ trong : 256 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 223 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM hoặc 1 Nano SIM + 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GLONASS
# Bluetooth : A2DP
# Cổng kết nối/sạc : 2 đầu Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 4300 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 25 W
# Sạc kèm theo máy : 18 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Âm thanh AKG
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm có microphone chuyên dụng chống ồn
# Xem phim : 3GP
# Nghe nhạc : Midi
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 161.6 mm - Ngang 72.5 mm - Dày 8.3 mm - Nặng 192 g
# Thời điểm ra mắt : 08/2020
# ID =  21
# Điện thoại Samsung Galaxy M53
# Price : 11790000.0
# priceValidUntil : 04/08/2023
# Công nghệ màn hình : Super AMOLED Plus
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.7" - Tần số quét 120 Hz
# Độ sáng tối đa : Hãng không công bố
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 108 MP & Phụ 8 MP, 2 MP, 2 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 32 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : MediaTek Dimensity 900 5G
# Tốc độ CPU : 2 nhân 2.4 GHz & 6 nhân 2 GHz
# Chip đồ họa (GPU) : Mali-G68
# RAM : 8 GB
# Bộ nhớ trong : 256 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 241 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM (SIM 2 chung khe thẻ nhớ)
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 25 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá vân tay cạnh viền
# Tính năng đặc biệt : Chế độ trẻ em (Samsung Kids)
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 164.7 mm - Ngang 77 mm - Dày 7.4 mm - Nặng 176 g
# Thời điểm ra mắt : 04/2022
# ID =  22
# Điện thoại Samsung Galaxy S21 FE 5G (6GB/128GB)
# Price : 10990000.0
# priceValidUntil : 12/28/2022
# Công nghệ màn hình : Dynamic AMOLED 2X
# Độ phân giải : Full HD+ (1080 x 2340 Pixels)
# Màn hình rộng : 6.4" - Tần số quét 120 Hz
# Độ sáng tối đa : 1200 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass Victus
# Độ phân giải : Chính 12 MP & Phụ 12 MP, 8 MP
# Quay phim : 4K 2160p@60fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 32 MP
# Tính năng : A.I Camera
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Exynos 2100
# Tốc độ CPU : 1 nhân 2.9 GHz, 3 nhân 2.8 GHz & 4 nhân 2.2 GHz
# Chip đồ họa (GPU) : Mali-G78 MP14
# RAM : 6 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 115 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : v5.0
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 4500 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 25 W
# Công nghệ pin : Siêu tiết kiệm pin
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chạm 2 lần sáng màn hình
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 155.7 mm - Ngang 74.5 mm - Dày 7.9 mm - Nặng 177 g
# Thời điểm ra mắt : 1/2022
# ID =  23
# Điện thoại Samsung Galaxy A73 5G 128GB
# Price : 10990000.0
# priceValidUntil : 03/18/2023
# Công nghệ màn hình : Super AMOLED Plus
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.7" - Tần số quét 120 Hz
# Độ sáng tối đa : 800 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 108 MP & Phụ 12 MP, 5 MP, 5 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 32 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Snapdragon 778G 5G 8 nhân
# Tốc độ CPU : 4 nhân 2.4 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 642L
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 100 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM (SIM 2 chung khe thẻ nhớ)
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 25 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá vân tay dưới màn hình
# Tính năng đặc biệt : Chạm 2 lần tắt/sáng màn hình
# Kháng nước, bụi : IP67
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 163.7 mm - Ngang 76.1 mm - Dày 7.6 mm - Nặng 181 g
# Thời điểm ra mắt : 04/2022
# ID =  24
# Điện thoại Samsung Galaxy S20 FE (8GB/256GB)
# Price : 10990000.0
# priceValidUntil : 04/29/2022
# Công nghệ màn hình : Super AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.5" - Tần số quét 120 Hz
# Độ sáng tối đa : Hãng không công bố
# Mặt kính cảm ứng : Mặt kính cong 2.5D
# Độ phân giải : Chính 12 MP & Phụ 12 MP, 8 MP
# Quay phim : 4K 2160p@60fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 32 MP
# Tính năng : Xóa phông
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : Snapdragon 865
# Tốc độ CPU : 1 nhân 2.84 GHz, 3 nhân 2.42 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 650
# RAM : 8 GB
# Bộ nhớ trong : 256 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 221 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM (SIM 2 chung khe thẻ nhớ)
# Wifi : Wi-Fi 802.11 a/b/g/n/ac/ax
# GPS : GLONASS
# Bluetooth : LE
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : OTG
# Dung lượng pin : 4500 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 25 W
# Sạc kèm theo máy : 15 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Không gian thứ hai (Thư mục bảo mật)
# Kháng nước, bụi : IP68
# Xem phim : 3GP
# Nghe nhạc : WMA
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhôm & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 159.8 mm - Ngang 74.5 mm - Dày 8.4 mm - Nặng 190 g
# Thời điểm ra mắt : 05/2021
# ID =  25
# Điện thoại Samsung Galaxy A53 5G 128GB
# Price : 8990000.0
# priceValidUntil : 07/16/2022
# Công nghệ màn hình : Super AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.5" - Tần số quét 120 Hz
# Độ sáng tối đa : 800 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 64 MP & Phụ 12 MP, 5 MP, 5 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 32 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Exynos 1280 8 nhân
# Tốc độ CPU : 2 nhân 2.4 GHz & 6 nhân 2 GHz
# Chip đồ họa (GPU) : Mali-G68
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM (SIM 2 chung khe thẻ nhớ)
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GALILEO
# Bluetooth : v5.1
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 25 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chế độ trẻ em (Samsung Kids)
# Kháng nước, bụi : IP67
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : Có
# Nghe nhạc : Có
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 159.6 mm - Ngang 74.8 mm - Dày 8.1 mm - Nặng 189 g
# Thời điểm ra mắt : 03/2022
# ID =  26
# Điện thoại Samsung Galaxy A33 5G 6GB
# Price : 7490000.0
# priceValidUntil : 03/18/2023
# Công nghệ màn hình : Super AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.4" - Tần số quét 90 Hz
# Độ sáng tối đa : 800 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 48 MP & Phụ 8 MP, 5 MP, 2 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 13 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Exynos 1280 8 nhân
# Tốc độ CPU : 2 nhân 2.4 GHz & 6 nhân 2 GHz
# Chip đồ họa (GPU) : Mali-G68
# RAM : 6 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 102 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM (SIM 2 chung khe thẻ nhớ)
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GLONASS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 25 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá vân tay dưới màn hình
# Tính năng đặc biệt : Chạm 2 lần tắt/sáng màn hình
# Kháng nước, bụi : IP67
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 159.7 mm - Ngang 74 mm - Dày 8.1 mm - Nặng 186 g
# Thời điểm ra mắt : 04/2022
# ID =  27
# Điện thoại Samsung Galaxy M33 5G
# Price : 7190000.0
# priceValidUntil : 10/28/2022
# Công nghệ màn hình : TFT LCD
# Độ phân giải : Full HD+ (1080 x 2408 Pixels)
# Màn hình rộng : 6.6" - Tần số quét 120 Hz
# Độ sáng tối đa : Hãng không công bố
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 50 MP & Phụ 5 MP, 2 MP, 2 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 8 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Exynos 1280 8 nhân
# Tốc độ CPU : 2 nhân 2.4 GHz & 6 nhân 2 GHz
# Chip đồ họa (GPU) : Mali-G68
# RAM : 6 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 101 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 25 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chế độ trẻ em (Samsung Kids)
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 165.4 mm - Ngang 76.9 mm - Dày 8.4 mm - Nặng 198 g
# Thời điểm ra mắt : 04/2022
# ID =  28
# Điện thoại Samsung Galaxy A52 128GB
# Price : 6790000.0
# priceValidUntil : 09/21/2021
# Công nghệ màn hình : Super AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.5" - Tần số quét 90 Hz
# Độ sáng tối đa : 800 nits
# Mặt kính cảm ứng : Kính cường lực
# Độ phân giải : Chính 64 MP & Phụ 12 MP, 5 MP, 5 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 32 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : Snapdragon 720G
# Tốc độ CPU : 2 nhân 2.3 GHz & 6 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 618
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 115 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : v5.0
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : NFC
# Dung lượng pin : 4500 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 25 W
# Sạc kèm theo máy : 15 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Âm thanh Dolby Audio
# Kháng nước, bụi : IP67
# Ghi âm : Ghi âm mặc định
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 159.9 mm - Ngang 75.1 mm - Dày 8.4 mm - Nặng 189 g
# Thời điểm ra mắt : 03/2021
# ID =  29
# Điện thoại Samsung Galaxy M51
# Price : 6290000.0
# priceValidUntil : 08/31/2021
# Công nghệ màn hình : Super AMOLED Plus
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.7" - Tần số quét 60 Hz
# Độ sáng tối đa : 420 nits
# Mặt kính cảm ứng : Mặt kính cong 2.5D
# Độ phân giải : Chính 64 MP & Phụ 12 MP, 5 MP, 5 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : Chạm lấy nét
# Độ phân giải : 32 MP
# Tính năng : HDR
# Hệ điều hành : Android 10
# Chip xử lý (CPU) : Snapdragon 730
# Tốc độ CPU : 2 nhân 2.2 GHz & 6 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 618
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 103 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 512 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GPS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : OTG
# Dung lượng pin : 7000 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 25 W
# Sạc kèm theo máy : 25 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chặn cuộc gọi
# Ghi âm : Ghi âm mặc định
# Radio : Có
# Xem phim : AVI
# Nghe nhạc : MP3
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 163.9 mm - Ngang 76.3 mm - Dày 9.5 mm - Nặng 213 g
# Thời điểm ra mắt : 10/2020
# ID =  30
# Điện thoại Samsung Galaxy A32
# Price : 6090000.0
# priceValidUntil : 01/18/2022
# Công nghệ màn hình : Super AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.4" - Tần số quét 90 Hz
# Độ sáng tối đa : 800 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 64 MP & Phụ 8 MP, 5MP, 5MP
# Quay phim : FullHD 1080p@30fps
# Đèn Flash : Có
# Tính năng : Góc rộng (Wide)
# Độ phân giải : 20 MP
# Tính năng : HDR
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : MediaTek Helio G80
# Tốc độ CPU : 2 nhân 2.0 GHz & 6 nhân 1.8 GHz
# Chip đồ họa (GPU) : Mali-G52 MC2
# RAM : 6 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : Khoảng 115 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GLONASS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : OTG
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 15 W
# Sạc kèm theo máy : 15 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chặn cuộc gọi
# Ghi âm : Ghi âm mặc định
# Radio : Có
# Xem phim : Có
# Nghe nhạc : Có
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 158.9 mm - Ngang 73.6 mm - Dày 8.4 mm - Nặng 184 g
# Thời điểm ra mắt : 03/2021
# ID =  31
# Điện thoại Samsung Galaxy A23 4GB
# Price : 5290000.0
# priceValidUntil : 11/30/2022
# Công nghệ màn hình : PLS TFT LCD
# Độ phân giải : Full HD+ (1080 x 2408 Pixels)
# Màn hình rộng : 6.6" - Tần số quét 90 Hz
# Độ sáng tối đa : 600 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 50 MP & Phụ 5 MP, 2 MP, 2 MP
# Quay phim : FullHD 1080p@30fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 8 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Snapdragon 680 8 nhân
# Tốc độ CPU : 4 nhân 2.4 GHz & 4 nhân 1.9 GHz
# Chip đồ họa (GPU) : Adreno 610
# RAM : 4 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 105.1 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : v5.0
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 25 W
# Sạc kèm theo máy : 15 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Smart Switch (ứng dụng chuyển đổi dữ liệu)
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 165.4 mm - Ngang 76.9 mm - Dày 8.4 mm - Nặng 195 g
# Thời điểm ra mắt : 03/2022
# ID =  32
# Điện thoại OPPO Reno7 Z 5G
# Price : 10490000.0
# priceValidUntil : 02/08/2023
# Công nghệ màn hình : AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.43" - Tần số quét 60 Hz
# Độ sáng tối đa : 600 nits
# Mặt kính cảm ứng : Kính cường lực Schott Xensation UP
# Độ phân giải : Chính 64 MP & Phụ 2 MP, 2 MP
# Quay phim : FullHD 1080p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 16 MP
# Tính năng : Bộ lọc màu
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : Snapdragon 695 5G 8 nhân
# Tốc độ CPU : 2.2 GHz
# Chip đồ họa (GPU) : Adreno 619
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 115 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 1 TB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM (SIM 2 chung khe thẻ nhớ)
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : v5.1
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : NFC
# Dung lượng pin : 4500 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 33 W
# Sạc kèm theo máy : 33 W
# Công nghệ pin : Siêu tiết kiệm pin
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chạm 2 lần tắt/sáng màn hình
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Xem phim : AVI
# Nghe nhạc : FLAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung nhựa & Mặt lưng thuỷ tinh hữu cơ
# Kích thước, khối lượng : Dài 159.85 mm - Ngang 73.17 mm - Dày 7.49 mm - Nặng 173 g
# Thời điểm ra mắt : 03/2022
# ID =  33
# Điện thoại OPPO A55
# Price : 4490000.0
# priceValidUntil : 08/31/2022
# Công nghệ màn hình : IPS LCD
# Độ phân giải : HD+ (700 x 1600 Pixels)
# Màn hình rộng : 6.5" - Tần số quét 60 Hz
# Độ sáng tối đa : 480 nits
# Mặt kính cảm ứng : Kính cường lực Dinorex™ Glass
# Độ phân giải : Chính 50 MP & Phụ 2 MP, 2 MP
# Quay phim : FullHD 1080p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 16 MP
# Tính năng : Chuyên nghiệp (Pro)
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : MediaTek Helio G35
# Tốc độ CPU : 4 nhân 2.3 GHz & 4 nhân 1.8 GHz
# Chip đồ họa (GPU) : IMG PowerVR GE8320
# RAM : 4 GB
# Bộ nhớ trong : 64 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 50 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 256 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GALILEO
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : OTG
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 18 W
# Sạc kèm theo máy : 18 W
# Công nghệ pin : Sạc pin nhanh
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Ứng dụng kép (Nhân bản ứng dụng)
# Kháng nước, bụi : IPX4
# Ghi âm : Ghi âm mặc định
# Xem phim : AVI
# Nghe nhạc : FLAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 163.6 mm - Ngang 75.7 mm - Dày 8.4 mm - Nặng 193 g
# Thời điểm ra mắt : 10/2021
# ID =  34
# Điện thoại OPPO Find X5 Pro 5G
# Price : 30990000.0
# priceValidUntil : 04/18/2023
# Công nghệ màn hình : AMOLED
# Độ phân giải : 2K+ (1440 x 3216 Pixels)
# Màn hình rộng : 6.7" - Tần số quét 120 Hz
# Độ sáng tối đa : 1300 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass Victus
# Độ phân giải : Chính 50 MP & Phụ 50 MP, 13 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 32 MP
# Tính năng : A.I Camera
# Hệ điều hành : Android 12
# Chip xử lý (CPU) : Snapdragon 8 Gen 1 8 nhân
# Tốc độ CPU : 3 GHz
# Chip đồ họa (GPU) : Adreno 730
# RAM : 12 GB
# Bộ nhớ trong : 256 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 243 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM hoặc 1 Nano SIM + 1 eSIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : BEIDOU
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : NFC
# Dung lượng pin : 5000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 80 W
# Sạc kèm theo máy : 80 W
# Công nghệ pin : Sạc không dây
# Bảo mật nâng cao : Mở khoá vân tay dưới màn hình
# Tính năng đặc biệt : Chạm 2 lần tắt/sáng màn hình
# Kháng nước, bụi : IP68
# Ghi âm : Ghi âm cuộc gọi
# Xem phim : AVI
# Nghe nhạc : FLAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng gốm
# Kích thước, khối lượng : Dài 163.7 mm - Ngang 73.9 mm - Dày 8.5 mm - Nặng 218 g
# Thời điểm ra mắt : 05/2022
# ID =  35
# Điện thoại OPPO Reno4 Pro
# Price : 10490000.0
# priceValidUntil : 05/27/2021
# Công nghệ màn hình : AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.5" - Tần số quét 90 Hz
# Độ sáng tối đa : 500 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 48 MP & Phụ 8 MP, 2 MP, 2 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 32 MP
# Tính năng : Flash màn hình
# Hệ điều hành : Android 10
# Chip xử lý (CPU) : Snapdragon 720G
# Tốc độ CPU : 2 nhân 2.3 GHz & 6 nhân 1.8 GHz
# Chip đồ họa (GPU) : Adreno 618
# RAM : 8 GB
# Bộ nhớ trong : 256 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 235 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 256 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GPS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : OTG
# Dung lượng pin : 4000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 65 W
# Sạc kèm theo máy : 65 W
# Công nghệ pin : Sạc siêu nhanh SuperVOOC
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chặn cuộc gọi
# Ghi âm : Ghi âm mặc định
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung hợp kim phủ nhựa & Mặt lưng thuỷ tinh hữu cơ
# Kích thước, khối lượng : Dài 159.6 mm - Ngang 72.5 mm - Dày 7.6 mm - Nặng 161 g
# Thời điểm ra mắt : 07/2020
# ID =  36
# Điện thoại OPPO Reno6 5G
# Price : 10390000.0
# priceValidUntil : 06/01/2022
# Công nghệ màn hình : AMOLED
# Độ phân giải : Full HD+ (1080 x 2400 Pixels)
# Màn hình rộng : 6.43" - Tần số quét 90 Hz
# Độ sáng tối đa : 750 nits
# Mặt kính cảm ứng : Kính cường lực Corning Gorilla Glass 5
# Độ phân giải : Chính 64 MP & Phụ 8 MP, 2 MP
# Quay phim : 4K 2160p@30fps
# Đèn Flash : Có
# Tính năng : AI Camera
# Độ phân giải : 32 MP
# Tính năng : HDR
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : MediaTek Dimensity 900 5G
# Tốc độ CPU : 2 nhân 2.4 GHz & 6 nhân 2 GHz
# Chip đồ họa (GPU) : Mali-G68 MC4
# RAM : 8 GB
# Bộ nhớ trong : 128 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 110 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 5G
# SIM : 2 Nano SIM
# Wifi : Dual-band (2.4 GHz/5 GHz)
# GPS : GLONASS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Type-C
# Kết nối khác : OTG
# Dung lượng pin : 4300 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 65 W
# Sạc kèm theo máy : 65 W
# Công nghệ pin : Sạc siêu nhanh SuperVOOC
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Chạm 2 lần sáng màn hình
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm mặc định
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung hợp kim & Mặt lưng kính Panda
# Kích thước, khối lượng : Dài 156.8 mm - Ngang 72.1 mm - Dày 7.59 mm - Nặng 182 g
# Thời điểm ra mắt : 07/2021
# ID =  37
# Điện thoại OPPO Reno5 5G
# Price : 8490000.0
# ...
# Màn hình rộng : 6.5" - Tần số quét 60 Hz
# Độ sáng tối đa : 400 nits
# Mặt kính cảm ứng : Kính cường lực Panda
# Độ phân giải : Chính 13 MP & Phụ 2 MP, 2 MP
# Quay phim : FullHD 1080p@30fps
# Đèn Flash : Có
# Tính năng : Ban đêm (Night Mode)
# Độ phân giải : 8 MP
# Tính năng : Làm đẹp
# Hệ điều hành : Android 11
# Chip xử lý (CPU) : MediaTek Helio G25
# Tốc độ CPU : 8 nhân 2.0 GHz
# Chip đồ họa (GPU) : IMG PowerVR GE8320
# RAM : 4 GB
# Bộ nhớ trong : 64 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 50 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 512 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Wi-Fi 802.11 b/g/n
# GPS : GPS
# Bluetooth : v5.0
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : 3.5 mm
# Kết nối khác : OTG
# Dung lượng pin : 5050 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 10 W
# Sạc kèm theo máy : 10 W
# Công nghệ pin : Không có
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Tính năng đặc biệt : Trợ lý ảo Google Assistant
# Kháng nước, bụi : IPX2
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Xem phim : AVI
# Nghe nhạc : FLAC
# Thiết kế : Nguyên khối
# Chất liệu : Khung kim loại & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 164.9 mm - Ngang 76 mm - Dày 9.2 mm - Nặng 194 g
# Thời điểm ra mắt : 12/2021
# ID =  77
# Điện thoại Nokia C30
# Price : 2850000.0
# priceValidUntil : 08/05/2022
# Công nghệ màn hình : IPS LCD
# Độ phân giải : HD+ (720 x 1600 Pixels)
# Màn hình rộng : 6.82" - Tần số quét 60 Hz
# Độ sáng tối đa : 400 nits
# Mặt kính cảm ứng : Mặt kính cong 2.5D
# Độ phân giải : Chính 13 MP & Phụ 2 MP
# Quay phim : FullHD 1080p@30fps
# Đèn Flash : Có
# Tính năng : Chạm lấy nét
# Độ phân giải : 5 MP
# Tính năng : HDR
# Hệ điều hành : Android 11 (Go Edition)
# Chip xử lý (CPU) : Spreadtrum SC9863A
# Tốc độ CPU : 4 nhân 1.6 GHz & 4 nhân 1.2 GHz
# Chip đồ họa (GPU) : IMG PowerVR GE8322
# RAM : 3 GB
# Bộ nhớ trong : 32 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 25 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 256 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Wi-Fi 802.11 a/b/g/n
# GPS : GPS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Loại pin : Li-Po
# Dung lượng pin : 6000 mAh
# Hỗ trợ sạc tối đa : 10 W
# Sạc kèm theo máy : 10 W
# Công nghệ pin : Tiết kiệm pin
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Kháng nước, bụi : Không có
# Radio : Có
# Xem phim : MP4
# Nghe nhạc : MP3
# Thiết kế : Pin liền
# Chất liệu : Khung & Mặt lưng nhựa Polycarbonate
# Kích thước, khối lượng : Dài 177.7 mm - Ngang 79.1 mm - Dày 9.9 mm - Nặng 237 g
# Thời điểm ra mắt : 08/2021
# ID =  78
# Điện thoại Nokia C20
# Price : 1990000.0
# priceValidUntil : 06/15/2022
# Công nghệ màn hình : IPS LCD
# Độ phân giải : HD+ (720 x 1600 Pixels)
# Màn hình rộng : 6.5" - Tần số quét 60 Hz
# Độ sáng tối đa : Hãng không công bố
# Mặt kính cảm ứng : Hãng không công bố
# Độ phân giải : 5 MP
# Quay phim : FullHD 1080p@30fps
# Đèn Flash : Có
# Tính năng : HDR
# Độ phân giải : 5 MP
# Tính năng : HDR
# Hệ điều hành : Android 11 (Go Edition)
# Chip xử lý (CPU) : Spreadtrum SC9863A
# Tốc độ CPU : 4 nhân 1.6 GHz & 4 nhân 1.2 GHz
# Chip đồ họa (GPU) : Mali-G52 MC2
# RAM : 2 GB
# Bộ nhớ trong : 32 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 25 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 256 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Wi-Fi 802.11 a/b/g/n
# GPS : GPS
# Bluetooth : A2DP
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Dung lượng pin : 2950 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 5 W
# Sạc kèm theo máy : 5 W
# Công nghệ pin : Tiết kiệm pin
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Radio : Có
# Xem phim : AVI
# Nghe nhạc : MP3
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa Polycarbonate
# Kích thước, khối lượng : Dài 169.9 mm - Ngang 77.9 mm - Dày 8.8 mm - Nặng 191 g
# Thời điểm ra mắt : 06/2021
# ID =  79
# Điện thoại Nokia 215 4G
# Price : 900000.0
# priceValidUntil : 11/16/2021
# Công nghệ màn hình : TFT LCD
# Độ phân giải : QVGA (240 x 320 Pixels)
# Màn hình rộng : 2.4"
# Mặt kính cảm ứng : Không có cảm ứng
# Hệ điều hành : Series 30+
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 32 GB
# Danh bạ : 2000 số
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Bluetooth : v5.0
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Dung lượng pin : 1150 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 2.75 W
# Sạc kèm theo máy : 2.75 W
# Tính năng đặc biệt : Ghi âm cuộc gọi
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Nghe nhạc : MP3
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 124.7 mm - Ngang 51 mm - Dày 13.7 mm - Nặng 90.3 g
# Thời điểm ra mắt : 11/2020
# ID =  80
# Điện thoại Nokia 110 4G
# Price : 850000.0
# priceValidUntil : 06/22/2022
# Công nghệ màn hình : TFT LCD
# Độ phân giải : QQVGA (120 x 160 Pixels)
# Màn hình rộng : 1.8"
# Mặt kính cảm ứng : Không có cảm ứng
# Độ phân giải : 0.08 MP
# Quay phim : Có quay phim
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 32 GB
# Danh bạ : 2000 số
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Dung lượng pin : 1020 mAh
# Loại pin : Li-Ion
# Sạc kèm theo máy : 2.75 W
# Ghi âm : Ghi âm cuộc gọi
# Radio : FM không cần tai nghe
# Xem phim : AVI
# Nghe nhạc : WAV
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 121 mm - Ngang 50 mm - Dày 14.5 mm - Nặng 84.5 g
# Thời điểm ra mắt : 06/2021
# ID =  81
# Điện thoại Nokia 105 4G
# Price : 750000.0
# priceValidUntil : 06/22/2022
# Công nghệ màn hình : TFT LCD
# Độ phân giải : QQVGA (120 x 160 Pixels)
# Màn hình rộng : 1.8"
# Mặt kính cảm ứng : Không có cảm ứng
# Đèn Flash : Không có
# Hệ điều hành : Series 30+
# Chip xử lý (CPU) : Unisoc T107
# RAM : 48 MB
# Bộ nhớ trong : 128 MB
# Danh bạ : 2000 số
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Dung lượng pin : 1020 mAh
# Loại pin : Li-Ion
# Sạc kèm theo máy : 2.75 W
# Tính năng đặc biệt : Chặn cuộc gọi
# Radio : FM không cần tai nghe
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 121 mm - Ngang 50 mm - Dày 14.5 mm - Nặng 80.2 g
# Thời điểm ra mắt : 06/2021
# ID =  82
# Điện thoại Nokia 105 Single SIM
# Price : 480000.0
# priceValidUntil : 10/01/2020
# Công nghệ màn hình : TFT LCD
# Độ phân giải : QQVGA (120 x 160 Pixels)
# Màn hình rộng : 1.77"
# Mặt kính cảm ứng : Không có cảm ứng
# Đèn Flash : Không có
# Hệ điều hành : Không có
# Danh bạ : 2000 số
# Mạng di động : Hỗ trợ 2G
# SIM : 1 SIM thường
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Dung lượng pin : 800 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 2.75 W
# Sạc kèm theo máy : 2.75 W
# Tính năng đặc biệt : Chặn cuộc gọi
# Radio : Có
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 111.9 mm - Ngang 49.2 mm - Dày 14.4 mm - Nặng 73 g
# Thời điểm ra mắt : 09/2019
# ID =  83
# Điện thoại Itel L6502
# Price : 2290000.0
# priceValidUntil : 10/01/2022
# Công nghệ màn hình : IPS LCD
# Độ phân giải : HD+ (720 x 1600 Pixels)
# Màn hình rộng : 6.5" - Tần số quét Hãng không công bố
# Độ sáng tối đa : Hãng không công bố
# Mặt kính cảm ứng : Mặt kính cong 2.5D
# Độ phân giải : Chính 8 MP & Phụ VGA, VGA
# Quay phim : HD 720p@24fps
# Đèn Flash : Có
# Tính năng : Chạm lấy nét
# Độ phân giải : 5 MP
# Hệ điều hành : Android 10 (Go Edition)
# Chip xử lý (CPU) : Spreadtrum SC9832E
# Tốc độ CPU : 1.4 GHz
# Chip đồ họa (GPU) : Mali-T820 MP1
# RAM : 3 GB
# Bộ nhớ trong : 32 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 22 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 128 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Nano SIM
# Wifi : Wi-Fi 802.11 b/g/n
# GPS : GPS
# Bluetooth : v4.3
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Kết nối khác : OTG
# Dung lượng pin : 4000 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 5 W
# Sạc kèm theo máy : 5 W
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Ghi âm : Ghi âm mặc định
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Pin rời
# Chất liệu : Khung nhôm & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 166 mm - Ngang 75.9 mm - Dày 8.55 mm - Nặng 179 g
# Thời điểm ra mắt : 10/2021
# ID =  84
# Điện thoại Itel L6006
# Price : 1990000.0
# priceValidUntil : 10/01/2022
# Công nghệ màn hình : IPS LCD
# Độ phân giải : HD+ (720 x 1560 Pixels)
# Màn hình rộng : 6.1" - Tần số quét Hãng không công bố
# Độ sáng tối đa : Hãng không công bố
# Mặt kính cảm ứng : Kính thường
# Độ phân giải : Chính 5 MP & Phụ VGA
# Quay phim : HD 720p@24fps
# Đèn Flash : Có
# Tính năng : Chạm lấy nét
# Độ phân giải : 5 MP
# Hệ điều hành : Android 10 (Go Edition)
# Chip xử lý (CPU) : Spreadtrum SC9832E
# Tốc độ CPU : 1.4 GHz
# Chip đồ họa (GPU) : Mali-T820 MP1
# RAM : 2 GB
# Bộ nhớ trong : 32 GB
# Bộ nhớ còn lại (khả dụng) khoảng : 22 GB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 128 GB
# Danh bạ : Không giới hạn
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Micro SIM
# Wifi : Wi-Fi 802.11 b/g/n
# GPS : GPS
# Bluetooth : v4.3
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Kết nối khác : OTG
# Dung lượng pin : 3000 mAh
# Loại pin : Li-Ion
# Hỗ trợ sạc tối đa : 5 W
# Sạc kèm theo máy : 5 W
# Bảo mật nâng cao : Mở khoá khuôn mặt
# Ghi âm : Ghi âm mặc định
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Pin rời
# Chất liệu : Khung nhôm & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 156 mm - Ngang 77.8 mm - Dày 9.46 mm - Nặng 178 g
# Thời điểm ra mắt : 10/2021
# ID =  85
# Điện thoại Itel it9210 4G
# Price : 680000.0
# priceValidUntil : 11/16/2022
# Công nghệ màn hình : LCD
# Độ phân giải : QVGA (240 x 320 Pixels)
# Màn hình rộng : 2.4"
# Mặt kính cảm ứng : Không có cảm ứng
# Độ phân giải : 0.3 MP
# Quay phim : Có quay phim
# Đèn Flash : Có
# Hệ điều hành : Không có
# RAM : 64 MB
# Bộ nhớ trong : 128 MB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 64 GB
# Danh bạ : 2000 số
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Micro SIM
# Wifi : Có
# Bluetooth : v4.2
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Dung lượng pin : 1900 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 1.75 W
# Sạc kèm theo máy : 1.75 W
# Ghi âm : Ghi âm mặc định
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : ADPCM
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 128.8 mm - Ngang 52.5 mm - Dày 13.75 mm - Nặng 108.5 g
# Thời điểm ra mắt : 11/2021
# ID =  86
# Điện thoại Itel it9010 4G
# Price : 580000.0
# priceValidUntil : 04/28/2023
# Công nghệ màn hình : LCD
# Độ phân giải : 128 x 160 Pixels
# Màn hình rộng : 1.77"
# Mặt kính cảm ứng : Không có cảm ứng
# Độ phân giải : 0.08 MP
# Quay phim : Không có
# Đèn Flash : Có
# Độ phân giải : Không có
# Hệ điều hành : Không có
# Chip xử lý (CPU) : Không có
# RAM : 48 MB
# Bộ nhớ trong : 128 MB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 64 GB
# Danh bạ : 2000 số
# Mạng di động : Hỗ trợ 4G
# SIM : 2 Micro SIM
# Wifi : Không có
# GPS : Có
# Bluetooth : v4.2
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Kết nối khác : Không có
# Dung lượng pin : 1000 mAh
# Loại pin : Li-Po
# Hỗ trợ sạc tối đa : 1.75 W
# Sạc kèm theo máy : 1.75 W
# Bảo mật nâng cao : Không có
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm cuộc gọi
# Radio : Có
# Xem phim : 3GP
# Nghe nhạc : ADPCM
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 128.8 mm - Ngang 52.5 mm - Dày 13.7 mm - Nặng 95 g
# Thời điểm ra mắt : 05/2022
# ID =  87
# Điện thoại Masstel FAMI 60 4G
# Price : 750000.0
# priceValidUntil : 12/06/2022
# Công nghệ màn hình : TFT LCD
# Độ phân giải : 176 x 220 Pixels
# Màn hình rộng : 2" - Tần số quét Không có
# Mặt kính cảm ứng : Không có cảm ứng
# Quay phim : Không có
# Đèn Flash : Không có
# Tính năng : Không có
# Độ phân giải : Không có
# Tính năng : Không có
# Hệ điều hành : Không có
# Chip xử lý (CPU) : Unisoc UIS8910
# Tốc độ CPU : Không có
# Chip đồ họa (GPU) : Không có
# RAM : 16 MB
# Bộ nhớ trong : 24 MB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 32 GB
# Danh bạ : 500 số
# Mạng di động : Hỗ trợ 4G VoLTE
# SIM : 2 Nano SIM
# Wifi : Không có
# GPS : Không có
# Bluetooth : v4.2
# Cổng kết nối/sạc : Type-C
# Jack tai nghe : Không có
# Kết nối khác : Không có
# Dung lượng pin : 2000 mAh
# Loại pin : Li-Ion
# Sạc kèm theo máy : 2.5 W
# Công nghệ pin : Không có
# Bảo mật nâng cao : Không có
# Tính năng đặc biệt : Không có
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm mặc định
# Radio : FM không cần tai nghe
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Pin rời
# Chất liệu : Khung kim loại & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 125.9 mm - Ngang 57.1 mm - Dày 15.3 mm - Nặng 146.2 g
# Thời điểm ra mắt : 12/2021
# Hãng : Masstel. <span class='parameter__manu'>Xem thông tin hãng</span>
# ID =  88
# Điện thoại Masstel IZI 55 4G
# Price : 700000.0
# priceValidUntil : 12/06/2022
# Công nghệ màn hình : TFT LCD
# Độ phân giải : QVGA (240 x 320 Pixels)
# Màn hình rộng : 2.4"
# Mặt kính cảm ứng : Không có cảm ứng
# Độ phân giải : Không có
# Độ phân giải : Không có
# Hệ điều hành : Không có
# Chip xử lý (CPU) : Unisoc SCUI8910
# RAM : 16 MB
# Bộ nhớ trong : 24 MB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 16 GB
# Danh bạ : 500 số
# Mạng di động : Hỗ trợ 4G VoLTE
# SIM : 2 Nano SIM
# Wifi : Không có
# GPS : Không có
# Bluetooth : v4.2
# Cổng kết nối/sạc : Micro USB
# Kết nối khác : Không có
# Dung lượng pin : 1800 mAh
# Loại pin : Li-Ion
# Sạc kèm theo máy : 2.5 W
# Công nghệ pin : Không có
# Bảo mật nâng cao : Không có
# Tính năng đặc biệt : Không có
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm mặc định
# Radio : FM không cần tai nghe
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Pin rời
# Chất liệu : Khung kim loại & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 121.5 mm - Ngang 53 mm - Dày 16.7 mm - Nặng 153 g
# Thời điểm ra mắt : 12/2021
# Hãng : Masstel. <span class='parameter__manu'>Xem thông tin hãng</span>
# ID =  89
# Điện thoại Masstel FAMI 12 4G
# Price : 650000.0
# priceValidUntil : 03/07/2023
# Công nghệ màn hình : TFT LCD
# Độ phân giải : 128 x 160 Pixels
# Màn hình rộng : 1.77"
# Mặt kính cảm ứng : Không có cảm ứng
# Độ phân giải : 0.08 MP
# Chip xử lý (CPU) : Unisoc T107
# RAM : 48 MB
# Bộ nhớ trong : 256 MB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 64 GB
# Danh bạ : 500 số
# Mạng di động : Hỗ trợ 4G VoLTE
# SIM : 2 Nano SIM
# Wifi : Không có
# GPS : Không có
# Bluetooth : v5.0
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Kết nối khác : Không có
# Dung lượng pin : 1400 mAh
# Loại pin : Li-Ion
# Sạc kèm theo máy : 2.5 W
# Công nghệ pin : Không có
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm cuộc gọi
# Radio : FM không cần tai nghe
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Pin rời
# Chất liệu : Khung kim loại & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 118.3 mm - Ngang 54.5 mm - Dày 15.3 mm - Nặng 124 g
# Thời điểm ra mắt : 03/2022
# Hãng : Masstel. <span class='parameter__manu'>Xem thông tin hãng</span>
# ID =  90
# Điện thoại Masstel IZI 20 4G
# Price : 550000.0
# priceValidUntil : 12/16/2022
# Công nghệ màn hình : TFT LCD
# Độ phân giải : 128 x 160 Pixels
# Màn hình rộng : 1.77"
# Mặt kính cảm ứng : Không có cảm ứng
# Độ phân giải : 0.08 MP
# Quay phim : Có quay phim
# Đèn Flash : Không có
# Độ phân giải : Không có
# Chip xử lý (CPU) : Unisoc UMS9117
# RAM : 48 MB
# Bộ nhớ trong : 128 MB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 32 GB
# Danh bạ : 500 số
# Mạng di động : Hỗ trợ 4G VoLTE
# SIM : 2 Nano SIM
# Wifi : Không có
# GPS : Không có
# Bluetooth : v4.1
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Dung lượng pin : 1700 mAh
# Loại pin : Li-Ion
# Sạc kèm theo máy : 2.5 W
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm mặc định
# Radio : FM không cần tai nghe
# Xem phim : 3GP
# Nghe nhạc : AAC
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 117.5 mm - Ngang 49.7 mm - Dày 16.5 mm - Nặng 100 g
# Thời điểm ra mắt : 12/2021
# Hãng : Masstel. <span class='parameter__manu'>Xem thông tin hãng</span>
# ID =  91
# Điện thoại Masstel IZI 10 4G
# Price : 500000.0
# priceValidUntil : 12/16/2022
# Công nghệ màn hình : TFT LCD
# Độ phân giải : 128 x 160 Pixels
# Màn hình rộng : 1.77"
# Mặt kính cảm ứng : Không có cảm ứng
# Độ phân giải : Không có
# Độ phân giải : Không có
# Hệ điều hành : Không có
# Chip xử lý (CPU) : Unisoc UMS9117
# RAM : 48 MB
# Bộ nhớ trong : 128 MB
# Thẻ nhớ : MicroSD, hỗ trợ tối đa 32 GB
# Danh bạ : 2000 số
# Mạng di động : Hỗ trợ 4G VoLTE
# SIM : 2 Nano SIM
# Wifi : Không có
# GPS : Không có
# Bluetooth : v4.2
# Cổng kết nối/sạc : Micro USB
# Jack tai nghe : 3.5 mm
# Kết nối khác : Không có
# Dung lượng pin : 1000 mAh
# Loại pin : Li-Ion
# Sạc kèm theo máy : 2.5 W
# Công nghệ pin : Không có
# Kháng nước, bụi : Không có
# Ghi âm : Ghi âm mặc định
# Radio : FM không cần tai nghe
# Xem phim : 3GP
# Nghe nhạc : AMR
# Thiết kế : Pin rời
# Chất liệu : Khung & Mặt lưng nhựa
# Kích thước, khối lượng : Dài 121 mm - Ngang 50 mm - Dày 12.8 mm - Nặng 75 g
# Thời điểm ra mắt : 12/2021
# Hãng : Masstel. <span class='parameter__manu'>Xem thông tin hãng</span>

# %%
df = pd.DataFrame.from_dict(data_phones)
df.to_csv("data_phones.csv", encoding="utf-8")

# %%
import pandas as pd

# %%
df = pd.read_csv("./data_phones_tgdd.csv", index_col=0)

# %%
df.head()
# Out:
#                                  Name       Price priceValidUntil  \
# 0           Điện thoại iPhone 11 64GB  13790000.0      02/10/2019
# 1  Điện thoại iPhone 13 Pro Max 128GB  31990000.0      10/18/2022
# 2  Điện thoại iPhone 12 Pro Max 512GB         0.0      09/14/2021
# 3      Điện thoại iPhone 13 Pro 128GB  28790000.0      10/18/2022
# 4      Điện thoại iPhone 12 Pro 256GB  26290000.0      09/14/2021
#
#   Công nghệ màn hình Độ phân giải              Màn hình rộng Độ sáng tối đa  \
# 0            IPS LCD        12 MP   6.1" - Tần số quét 60 Hz       625 nits
# 1               OLED        12 MP  6.7" - Tần số quét 120 Hz      1200 nits
# 2               OLED        12 MP   6.7" - Tần số quét 60 Hz      1200 nits
# 3               OLED        12 MP  6.1" - Tần số quét 120 Hz      1200 nits
# 4               OLED        12 MP   6.1" - Tần số quét 60 Hz      1200 nits
#
#                             Mặt kính cảm ứng       Quay phim  \
# 0  Kính cường lực Oleophobic (ion cường lực)  4K 2160p@24fps
# 1              Kính cường lực Ceramic Shield  4K 2160p@24fps
# 2              Kính cường lực Ceramic Shield  4K 2160p@24fps
# 3              Kính cường lực Ceramic Shield  4K 2160p@24fps
# 4              Kính cường lực Ceramic Shield  4K 2160p@24fps
#
#               Đèn Flash  ...          Xem phim Nghe nhạc     Thiết kế  \
# 0  3 đèn LED 2 tông màu  ...  H.264(MPEG4-AVC)       AAC  Nguyên khối
# 1                    Có  ...  H.264(MPEG4-AVC)       AAC  Nguyên khối
# 2           Đèn LED kép  ...  H.264(MPEG4-AVC)       AAC  Nguyên khối
# 3                    Có  ...  H.264(MPEG4-AVC)       AAC  Nguyên khối
# 4           Đèn LED kép  ...  H.264(MPEG4-AVC)       AAC  Nguyên khối
#
#                                        Chất liệu  \
# 0           Khung nhôm & Mặt lưng kính cường lực
# 1  Khung thép không gỉ & Mặt lưng kính cường lực
# 2  Khung thép không gỉ & Mặt lưng kính cường lực
# 3  Khung thép không gỉ & Mặt lưng kính cường lực
# 4  Khung thép không gỉ & Mặt lưng kính cường lực
#
#                               Kích thước, khối lượng Thời điểm ra mắt Thẻ nhớ  \
# 0  Dài 150.9 mm - Ngang 75.7 mm - Dày 8.3 mm - Nặ...          11/2019     NaN
# 1  Dài 160.8 mm - Ngang 78.1 mm - Dày 7.65 mm - N...          09/2021     NaN
# 2  Dài 160.8 mm - Ngang 78.1 mm - Dày 7.4 mm - Nặ...          10/2020     NaN
# 3  Dài 146.7 mm - Ngang 71.5 mm - Dày 7.65 mm - N...          09/2021     NaN
# 4  Dài 146.7 mm - Ngang 71.5 mm - Dày 7.4 mm - Nặ...          10/2020     NaN
#
#   Sạc kèm theo máy Radio Hãng
# 0              NaN   NaN  NaN
# 1              NaN   NaN  NaN
# 2              NaN   NaN  NaN
# 3              NaN   NaN  NaN
# 4              NaN   NaN  NaN
#
# [5 rows x 45 columns]

# %%
mhr = []
tsq = []
for line in df["Màn hình rộng"]:
    if len(line.split("-")) < 2:
        x = line
        mhr.append(x.strip())
        tsq.append(None)
    else:
        x, y = line.split("-")
        mhr.append(x.strip())
        tsq.append(y.strip())

# %%
df.drop("Màn hình rộng", axis=1, inplace = True)

# %%
df["Màn hình rộng"] = mhr
df["Tần số quét"] = tsq

# %%
kichthuoc  = []
khoiluong = []
for line in df["Kích thước, khối lượng"]:
    kt = "-".join(line.split("-")[:-1])
    kl = line.split("-")[-1]
    kichthuoc.append(kt)
    khoiluong.append(kl)

# %%
df.drop("Kích thước, khối lượng", axis=1, inplace = True)

# %%
df["Kích thước"] = kichthuoc
df["Khối lượng"] = khoiluong

# %%
df.to_csv("data_phones_tgdd.csv", index=0)
